# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
bucket = "bronze"
datamart = "caravelal"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-10-25 14:08:06,240 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Realiza extração e gravação no datalake

# %%
extrator_bronze.extrair_dados_bronze()
# Out:
# 2024-10-25 14:08:09,381 - INFO - Aguarde... Iniciando extração de dados camada Bronze
# 2024-10-25 14:08:09,383 - INFO - Lista de yaml carregada com sucesso
# 2024-10-25 14:08:09,383 - INFO -
# Extraindo dados api
# 2024-10-25 14:08:09,996 - ERROR - Erro ao extrair_dados_bronze: Autenticação na API falhou! {"detail":[{"loc":["body","password"],"msg":"none is not an allowed value","type":"type_error.none.not_allowed"}]}
# 2024-10-25 14:08:10,189 - INFO - Sessão Spark finalizada.
# 2024-10-25 14:08:10,190 - ERROR - Erro ao extrair dados camada bronze
# 2024-10-25 14:08:10,191 - ERROR - Autenticação na API falhou! {"detail":[{"loc":["body","password"],"msg":"none is not an allowed value","type":"type_error.none.not_allowed"}]}
# 2024-10-25 14:08:10,194 - INFO - Sessão Spark finalizada.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 extrator_bronze.extrair_dados_bronze()
#
# File ~/work/utils/AlinharETL.py:244, in AlinharETL.extrair_dados_bronze(self, arquivo)
#     242 if self.type == 'api':
#     243     print('Extraindo dados api')
# --> 244     self.extrair_api(consulta)
#     245 if self.type == 'arquivo':
#     246     print('Extraindo dados arquivos')
#
# File ~/work/utils/AlinharETL.py:276, in AlinharETL.extrair_api(self, consulta)
#     266 if self.type == 'api' and self.origin_api == 'caravel_al':
#     267     caravel_extractor = ApiExtractor(
#     268     caravel_host=self.url_api,
#     269     caravel_user=os.getenv("CARAVEL_FE_USERNAME"),
#    (...)
#     274     included_endpoint=self.endpoint
#     275     )
# --> 276     df = caravel_extractor.extract_caravel()
#     277     self.salvar_delta(df,'overwrite')
#     278 elif self.type == 'api' and self.origin_api == 'cnae':
#
# File ~/work/utils/UtilsApiExtractor.py:135, in ApiExtractor.extract_caravel(self)
#     134 def extract_caravel(self) -> pd.DataFrame:
# --> 135     self.access_token = self.authenticate()
#     136     success, dataframe = self.fetch_data_from_endpoint(endpoint=self.included_endpoint)
#     138     if success:
#
# File ~/work/utils/UtilsApiExtractor.py:58, in ApiExtractor.authenticate(self)
#      55 response = requests.post(auth_url, json=auth_data, headers=headers, verify=True) #caravel
#      57 if response.status_code != 200:
# ---> 58     raise Exception(f"Autenticação na API falhou! {response.text}")
#      60 json_response = response.json()
#      61 access_token = json_response.get('access_token')
#
# Exception: Autenticação na API falhou! {"detail":[{"loc":["body","password"],"msg":"none is not an allowed value","type":"type_error.none.not_allowed"}]}
