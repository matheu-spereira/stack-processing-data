# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "bronze"
datamart = "corporerm/suprimentos"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 08:05:52,113 - INFO - Iniciando Sessão Spark.

# %%
extrator_bronze.conexao_banco_de_dados('sqlserver',
                                       'hml-bdrm',
                                       '1433',
                                       'pwbi.alinhar',
                                       '9@wY1(40',
                                       'CorporeRM_2402',
                                       '')
# Out:
# 2024-10-21 08:05:57,730 - INFO - Aguarde... Configurando conexao banco de dados

# %%
extrator_bronze.extrair_dados_bronze()
# Out:
# 2024-10-21 08:05:57,738 - INFO - Aguarde... Iniciando extração de dados camada Bronze
# 2024-10-21 08:05:57,740 - INFO - Lista de yaml carregada com sucesso
# 2024-10-21 08:05:57,741 - INFO -
# 2024-10-21 08:05:57,747 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:05:57,749 - INFO - Validando extração completa (True)
# 2024-10-21 08:05:57,749 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:05:57,750 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:05:57,750 - INFO - (select codcoligada, codigo, descricao, databasehor, horarioturno, inativo, hornoturno, consferiado, horariojor, temphorario, tipohor, consferdiaant, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, considerareducaojornadaadnot, pagaadnoturno, jordozetrintaseis, tipojoresocial, inicioreduzidaesocial, fimreduzidaesocial, consdtfimjornadacomodtref from dbo.ahorario)temp
# 2024-10-21 08:06:00,546 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:06:04,562 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-21 08:06:19,249 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:06:19,250 - INFO - s3a://bronze/corporerm/ahorario
# 2024-10-21 08:06:19,251 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:06:32,337 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:06:32,339 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:07:12,727 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:07:12,730 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:07:12,730 - INFO - s3a://bronze/corporerm/ahorario
# 2024-10-21 08:07:12,731 - INFO -
# 2024-10-21 08:07:12,737 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:07:12,738 - INFO - Validando extração completa (False)
# 2024-10-21 08:07:13,359 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:07:13,464 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:07:13,465 - INFO -
# 2024-10-21 08:07:13,466 - INFO - 001-dbo.gccusto
# 2024-10-21 08:07:13,468 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:07:13,469 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:07:13,470 - INFO - (select codcoligada, codccusto, nome, codcolcontager, codcontager, codcolconta, codconta, codreduzido, campolivre, ativo, permitelanc, codclassifica, enviasped, id, datainclusao, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, responsavel from dbo.gccusto order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:07:13,571 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:07:13,754 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:07:15,091 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:07:15,092 - INFO - s3a://bronze/corporerm/gccusto
# 2024-10-21 08:07:15,093 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:07:17,260 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:07:17,261 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:07:44,562 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:07:44,565 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:07:44,567 - INFO - s3a://bronze/corporerm/gccusto
# 2024-10-21 08:07:44,568 - INFO -
# 2024-10-21 08:07:44,575 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:07:44,578 - INFO - Validando extração completa (False)
# 2024-10-21 08:07:44,648 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:07:44,689 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:07:44,690 - INFO -
# 2024-10-21 08:07:44,691 - INFO - 001-dbo.gcoligada
# 2024-10-21 08:07:44,693 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:07:44,693 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:07:44,694 - INFO - (select codcoligada, nomefantasia, cgc, nome, inscricaoestadual, telefone, fax, email, rua, numero, complemento, bairro, cidade, estado, pais, cep, controlacgc, controle1, controle2, controle3, idimagem, produtorrural, ativo, codexterno, importada, datalimitelicencas, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon from dbo.gcoligada order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:07:44,835 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:07:44,972 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:07:46,231 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:07:46,233 - INFO - s3a://bronze/corporerm/gcoligada
# 2024-10-21 08:07:46,234 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:07:49,560 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:07:49,561 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:08:13,781 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:08:13,784 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:08:13,784 - INFO - s3a://bronze/corporerm/gcoligada
# 2024-10-21 08:08:13,785 - INFO -
# 2024-10-21 08:08:13,790 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:08:13,791 - INFO - Validando extração completa (False)
# 2024-10-21 08:08:13,819 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:08:13,841 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:08:13,842 - INFO -
# 2024-10-21 08:08:13,843 - INFO - 001-dbo.gdepto
# 2024-10-21 08:08:13,844 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:08:13,844 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:08:13,845 - INFO - (select codcoligada, codfilial, coddepartamento, nome, contato, localizacao, telefone, fax, ramal, codcolcontager, codcontager, ativo, email, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon from .dbo.gdepto order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:08:13,897 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:08:13,996 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:08:14,658 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:08:14,659 - INFO - s3a://bronze/corporerm/gdepto
# 2024-10-21 08:08:14,659 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:08:16,425 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:08:16,426 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:08:37,799 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:08:37,802 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:08:37,819 - INFO - s3a://bronze/corporerm/gdepto
# 2024-10-21 08:08:37,820 - INFO -
# 2024-10-21 08:08:37,827 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:08:37,829 - INFO - Validando extração completa (False)
# 2024-10-21 08:08:37,874 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:08:37,939 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:08:37,940 - INFO -
# 2024-10-21 08:08:37,941 - INFO - 001-dbo.gfilial
# 2024-10-21 08:08:37,942 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:08:37,943 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:08:37,944 - INFO - (select codcoligada, codfilial, nomefantasia, cgc, nome, inscricaoestadual, telefone, fax, email, rua, numero, complemento, bairro, cidade, estado, pais, cep, contato, produtorrural, tiporua, tipobairro, codcalendario, idimagem, codmunicipio, localidade, ramoatividade, inscmun, codativfed, codatividprinc, descatividprinc, numregjunta, caixapostal, cepcaixapostal, dataregjunta, idpais, suframa, id, idintegracao, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, ddd, dddfax, propriedaderural, cafir, cadativeconomicapf, tipoexploracaoimovel, percexploracaoimovel, ativo from dbo.gfilial order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:08:38,040 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:08:38,168 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:08:39,533 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:08:39,535 - INFO - s3a://bronze/corporerm/gfilial
# 2024-10-21 08:08:39,536 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:08:42,356 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:08:42,357 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:09:02,815 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:09:02,817 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:09:02,818 - INFO - s3a://bronze/corporerm/gfilial
# 2024-10-21 08:09:02,818 - INFO -
# 2024-10-21 08:09:02,824 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:09:02,825 - INFO - Validando extração completa (False)
# 2024-10-21 08:09:02,857 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:09:02,882 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:09:02,883 - INFO -
# 2024-10-21 08:09:02,883 - INFO - 001-dbo.pcodinstrucao
# 2024-10-21 08:09:02,884 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:09:02,885 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:09:02,885 - INFO - (select codcliente, codinterno, descricao, podealterar, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon from dbo.pcodinstrucao order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:09:02,929 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:09:03,037 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:09:03,518 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:09:03,519 - INFO - s3a://bronze/corporerm/pcodinstrucao
# 2024-10-21 08:09:03,519 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:09:05,358 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:09:05,359 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:09:25,480 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:09:25,482 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:09:25,483 - INFO - s3a://bronze/corporerm/pcodinstrucao
# 2024-10-21 08:09:25,483 - INFO -
# 2024-10-21 08:09:25,488 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:09:25,489 - INFO - Validando extração completa (False)
# 2024-10-21 08:09:25,517 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:09:25,541 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:09:25,542 - INFO -
# 2024-10-21 08:09:25,542 - INFO - 001-dbo.pcodsexo
# 2024-10-21 08:09:25,543 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:09:25,544 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:09:25,544 - INFO - (select descricao, podealterar, codcliente, codinterno, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon from dbo.pcodsexo order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:09:25,585 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:09:25,675 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:09:26,117 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:09:26,118 - INFO - s3a://bronze/corporerm/pcodsexo
# 2024-10-21 08:09:26,119 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:09:27,743 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:09:27,744 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:09:48,833 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:09:48,837 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:09:48,838 - INFO - s3a://bronze/corporerm/pcodsexo
# 2024-10-21 08:09:48,839 - INFO -
# 2024-10-21 08:09:48,845 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:09:48,847 - INFO - Validando extração completa (False)
# 2024-10-21 08:09:48,897 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:09:48,962 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:09:48,965 - INFO -
# 2024-10-21 08:09:48,967 - INFO - 001-dbo.pcodsituacao
# 2024-10-21 08:09:48,968 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:09:48,969 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:09:48,970 - INFO - (select codcliente, codinterno, descricao, podealterar, reccreatedby, reccreatedon,recmodifiedby, recmodifiedon from dbo.pcodsituacao order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:09:49,031 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:09:49,160 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:09:49,979 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:09:49,980 - INFO - s3a://bronze/corporerm/pcodsituacao
# 2024-10-21 08:09:49,981 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:09:52,129 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:09:52,132 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:10:13,638 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:10:13,640 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:10:13,641 - INFO - s3a://bronze/corporerm/pcodsituacao
# 2024-10-21 08:10:13,642 - INFO -
# 2024-10-21 08:10:13,657 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:10:13,658 - INFO - Validando extração completa (False)
# 2024-10-21 08:10:13,692 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:10:13,727 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:10:13,728 - INFO -
# 2024-10-21 08:10:13,729 - INFO - 001-dbo.pfunc
# 2024-10-21 08:10:13,729 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:10:13,730 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:10:13,730 - INFO - (select codcoligada, chapa, nrofichareg, codrecebimento, codsituacao, codtipo, codsecao, codfuncao, codsindicato, jornada, codhorario, nrodepirrf, nrodepsalfam, dtbase, salario, situacaofgts, dtopcaofgts, contafgts, saldofgts, dtsaldofgts, contribsindical, aposentado, temmais65anos, ajudacusto, percentadiant, arredondamento, dataadmissao, tipoadmissao, dttransferencia, motivoadmissao, temprazocontr, fimprazocontr, datademissao, tipodemissao, motivodemissao, dtdesligamento, dtultimomovim, dtpagtorescisao, codsaquefgts, temavisoprevio, dtavisoprevio, nrodiasaviso, dtvencferias, inicprogferias1, fimprogferias1, querabono, quer1aparc13o, nrodiasadiantfer, evtadiantferias, feriascoletivas, nrodiasferias, nrodiasabono, inicprogferias2, fimprogferias2, saldoferias, saldoferiasant, saldoferantaux, obsferias, dtpagtoferias, dtavisoferias, ndiaslicrem1, ndiaslicrem2, dtiniciolicenca, mediasalmatern, situacaorais, contapagamento, membrosindical, vinculorais, usavaletransp, diasuteismes, diasutmeioexp, diasutproxmes, diasutproxmeio, diasutrestantes, diasutrestmeio, mudouendereco, mudoucarttrab, antigacarttrab, antigaseriecart, mudounome, antigonome, mudoupis, antigopis, mudouchapa, antigachapa, mudouadmissao, antigadtadm, antigovinculo, antigotipofunc, antigotipoadm, mudoudtopcao, antigadtopcao, mudousecao, antigasecao, mudoudtnascim, antigadtnascim, faltaalterfgts, deduzirrf65, pisparafgts, ultimorecalculodata, ultimorecalculohora, descontaavisoprevio, codfilial, nome, indiniciohor, pispasep, dtcadastropis, codpessoa, codbancofgts, codbancopagto, codagenciapagto, codbancopis, rescisaocalculada, opbancaria, membrocipa, usasalcomposto, regatual, numvezesdescemprestimo, datainiciodescemprestimo, gruposalarial, jornadamensal, prevdisp, codocorrencia, codcategoria, classecontrib, codequipe, esupervisor, integrcontabil, integrgerencial, usacontroledesaldo, ci, mudouci, antigoci, periodorescisao, codgrpquiosque, fgtsmesantrecolgrfp, codnivelsal, trabalhounademissao, nrodiasferiasjornred, possuialvaramenor16, datarescisao, situacaoinss, dtaposentadoria, codtabelasalarial, temdeducaocpmf, nrodiasferiascorridos, nrodiasabonocorridos, posicaoabono, regimerevezamento, queradiantamento, dtproxaquisferias, codcolfornec, codfornecedor, isentoirrf, anocomptransf, mescomptransf, nroperiodotransf, tipoaposentadoria, repoevaga, saldofgtsreal, rescisaoprecisarecalc, id, benefpontos, contribassoc1ocorrcnpj, contribassoc2ocorrcnpj, contribassistcnpj, contribconfedcnpj, contribassoc1ocorrvalor, contribassoc2ocorrvalor, contribassistvalor, contribconfedvalor, localtrabcodmuncipio, meseshoraextras, mesesgratificacao, mesesdissidiocoletivo, indicadorsindicalizado, dtultimomovimpgtoextras, fimprazoprorrogcontr, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, codcoligadaorigem, chapaorigem, numerocartaosus, feriasfinalizadasproxmes, indsimples, tpcontabancaria, nrprocjud, residenciapropria, residenciarecursosfgts, tpregimeprev, indadmissao, tiporeintegracao, datareintegracao, dataretornoefetivo, nroleianistia, nroprocessojudicial, naturezaestagio, codnivelestagio, areaatuacaoestagio, numeroapoliceestagio, dtprevterminoestagio, codinstituicaoensinoestagio, codagenteintegracaoestagio, cpfcoordenadorestagio, nomecoordenadorestagio, cnpjempresaorigem, dtadmissaoempresaorigem, matriculaempresaorigem, codcategoriaempresaorigem, tiporeducaoaviso, formareducaoaviso, recebsegdesemp, motivotrabtemp, chapasubstrabtemp, motivocancelamentoaviso, dtcancelamentoaviso, nroatestadoobito, nroprocessotrab, observacaorescisao, observacaoavisoprevio, carregouavisoprevio, descricaosalvariavel, obscancelamentoaviso, sucessaovinculo, cnpjempresaanterior, matriculaanterior, dtiniciovinculo, observacaosucessao, transferenciasucessao, situacaoirrf, indpagtojuizo, dtdesligamentoreint, apmisto_dtavtrab, apmisto, feriasdiasuteis, feriassaldodiasuteis, iddadosresid, sequenciatransf, codbancopagto2, codagenciapagto2, contapagamento2, opbancaria2, tpconta ...
# 2024-10-21 08:10:13,872 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:10:14,523 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:10:25,000 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:10:25,001 - INFO - s3a://bronze/corporerm/pfunc
# 2024-10-21 08:10:25,002 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:10:30,460 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:10:30,462 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:10:40,134 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:10:40,136 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:10:40,137 - INFO - s3a://bronze/corporerm/pfunc
# 2024-10-21 08:10:40,137 - INFO -
# 2024-10-21 08:10:40,142 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:10:40,143 - INFO - Validando extração completa (False)
# 2024-10-21 08:10:40,174 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:10:40,202 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:10:40,203 - INFO -
# 2024-10-21 08:10:40,204 - INFO - 001-dbo.pfuncao
# 2024-10-21 08:10:40,204 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:10:40,205 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:10:40,205 - INFO - (select codcoligada, codigo, nome, numpontos, cbo, cargo, inativa, ativtransp, descricao, faixasalarial, limitefunc, verbaquadrovagas, percquadrovagas, dataultimarevisao, numrevisao, cbo2002, codtabela, codperfilcand, id, benefpontos, objetivo, descricaoppp, exibeorganograma, codfuncaochefia, jornadaref, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, codtipofuncao, sigla, codclassfuncao, esocialfuncaoconf, similaridadeintegracaogupy from dbo.pfuncao  order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:10:40,254 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:10:40,361 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:10:44,462 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:10:44,463 - INFO - s3a://bronze/corporerm/pfuncao
# 2024-10-21 08:10:44,464 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:10:46,440 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:10:46,441 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:10:53,434 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:10:53,437 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:10:53,438 - INFO - s3a://bronze/corporerm/pfuncao
# 2024-10-21 08:10:53,438 - INFO -
# 2024-10-21 08:10:53,445 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:10:53,445 - INFO - Validando extração completa (False)
# 2024-10-21 08:10:53,473 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:10:53,495 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:10:53,496 - INFO -
# 2024-10-21 08:10:53,496 - INFO - 001-dbo.ppessoa
# 2024-10-21 08:10:53,497 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:10:53,498 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:10:53,498 - INFO - (select codigo, nome, apelido, dtnascimento, estadocivil, sexo, nacionalidade, grauinstrucao, rua, numero, complemento, bairro, estado, cidade, cep, pais, regprofissional, cpf, idimagem, telefone1, telefone2, cartidentidade, ufcartident, orgemissorident, dtemissaoident, tituloeleitor, zonatiteleitor, secaotiteleitor, carteiratrab, seriecarttrab, ufcarttrab, dtcarttrab, nit, cartmotorista, tipocarthabilit, dtvenchabilit, certifreserv, categmilitar, naturalidade, estadonatal, datachegada, cartmodelo19, conjugebrasil, naturalizado, filhosbrasil, nrofilhosbrasil, nroreggeral, nrodecreto, dtvencident, dtvenccarttrab, tipovisto, email, investtreinant, corraca, deficientefisico, codusuario, telefone3, fax, empresa, codprofissao, codocupacao, codmemoobs, brpdh, npassaporte, fumante, paisorigem, dtemisspassaporte, dtvalpassaporte, obspessoa, idimagemdoc, idimagemdocv, ajustatamanhofoto, deficienteauditivo, deficientefala, deficientevisual, deficientemental, recursorealizacaotrab, recursoacessibilidade, dataaprovacaocurr, codmunicipio, localidade, csm, dtexpcml, exped, rm, sitmilitar, dttiteleitor, esteleit, tiposang, idbiometria, aluno, professor, usuariobiblios, funcionario, exfuncionario, candidato, tagscript, fiador_sgi, conjuge_sgi, deficientemobreduzida, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, dtvencidentpt, codtiporua, codtipobairro, idpais, codnaturalidade, numeroric, orgemissorric, dtemissaoric, dtemissaocnh, orgemissorcnh, datanaturalizacao, orgemissorrne, dtemissaorne, nomesocial, deficienteintelectual, deficienteobservacao, codclassiftrabestrang, ufcnh, dataprimeiracnh, dataobito, matriculaobito, falecido, portarianaturalizacao, ano1emprego, emailpessoal, tipoprazoresidencia, mudoucpf from dbo.ppessoa order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:10:53,555 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:10:54,286 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:11:24,891 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:11:24,892 - INFO - s3a://bronze/corporerm/ppessoa
# 2024-10-21 08:11:24,893 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:11:26,432 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:11:26,432 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:11:32,915 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:11:32,917 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:11:32,918 - INFO - s3a://bronze/corporerm/ppessoa
# 2024-10-21 08:11:32,918 - INFO -
# 2024-10-21 08:11:32,925 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:11:32,926 - INFO - Validando extração completa (False)
# 2024-10-21 08:11:32,955 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:11:32,980 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:11:32,981 - INFO -
# 2024-10-21 08:11:32,981 - INFO - 001-dbo.psecao
# 2024-10-21 08:11:32,982 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:11:32,983 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:11:32,983 - INFO - (select codcoligada, codigo, descricao, cgc, cgcanterior, cei, fpas, sat, ativeconomica, inscrestadual, inscrmunicipal, rua, numero, complemento, bairro, estado, cidade, cep, pais, telefone, codigocef, naoempregpropr, prefixorais, categoria, integrcontabil, integrgerencial, nrofilialcont, nrocencustocont, codterceirosinss, percentterceiros, percentacidtrab, faturamentobruto, valorfrete, complementogrps1, complementogrps2, complementogrps3, codunidentrega, contato, ramal, vtcoddepto, iniperrecpropr1, fimperrecpropr1, proprantes5dia1, iniperrecpropr2, fimperrecpropr2, proprantes5dia2, iniperreccentr1, fimperreccentr1, centrantes5dia1, iniperreccentr2, fimperreccentr2, centrantes5dia2, secaocentraliz, contribsesiesenai, distribpetroleo, pessoafisica, secaodesativada, identificacaocgc, enderecoalterou, enderecopagto, vtidentpedido, vtidentpersonal, vtcodcliente, vtcodlocal, vtcodsecfaturam, vtcodsecpedido, vtcodseccobranca, vtcodsecentrega, vtcodcentrocusto, causamudancacgc, codmunicipio, mesdatabase, naturezajuridica, codcalendario, prefixoinscrfgts, primeiradeclcaged, encerramento, codfilial, coddepto, limitefunc, optasimples, mudoucnae, chapachefe, percent15anosgrps, percent20anosgrps, percent25anosgrps, alteracaocaged, codpagtogps, percisencaofilantropia, participapat, porteempresa, coddeptocont, ddd, verbaquadrovagas, percquadrovagas, isentocontribsocial, vincpat5sal, vincpatmaior5sal, porcservprop, porcadmcozinha, porcrefeicaoconv, porcrefeicaotransp, porccestaalimento, porcalimconvenio, dtencerrativ, codplano, descricaoppp, codtabela, email, cnaerais, valorinssacumulado, valorentidadesacumulado, idmemoambtrab, visivelorganograma, localidade, capitalsocemp, capitalsocestab, codigopai, id, benefpontos, codpagtogpsterceiros, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, tplotacao, cno, codtiporua, caepf, secaoautonomos, tpprocessorat, nrprocessorat, tpprocessofap, nrprocessofap, tipocontroleponto, tipotarefa, codareaatuacao, iditemcontabil, idclassevalor, contapr, nrprocjudapr, contentedapr, contpcd, nrprocjudpcd, tpprocjudapr, codsuspprocjudapr, tpprocjudpcd, codsuspprocjudpcd, codsuspprocjudrat, codsuspprocjudfap, codtercssusp, aliqratisento, tipocaepf, cnaepreponderante, percentempresa, cnaesefip, similaridadeintegracaogupy from dbo.psecao order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:11:33,064 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:11:33,192 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:11:34,504 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:11:34,505 - INFO - s3a://bronze/corporerm/psecao
# 2024-10-21 08:11:34,506 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:11:35,586 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:11:35,587 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:11:42,792 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:11:42,794 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:11:42,795 - INFO - s3a://bronze/corporerm/psecao
# 2024-10-21 08:11:42,795 - INFO -
# 2024-10-21 08:11:42,801 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:11:42,801 - INFO - Validando extração completa (False)
# 2024-10-21 08:11:42,828 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:11:42,853 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:11:42,854 - INFO -
# 2024-10-21 08:11:42,854 - INFO - 001-dbo.saluno
# 2024-10-21 08:11:42,855 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:11:42,856 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:11:42,856 - INFO - (select codcoligada, ra, codarea, codcarreira, codidioma, codtipoaluno, codinstdestino, codinstorigem, codcolcfo, codcfo, codparentcfo, codpessoaraca, codparentraca, codpessoa, codcursohist, codseriehist, obshist, identificador2, identificador3, anoingresso, anotacoes, codtipocurso, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, racad, ufracad, codsistec, pronatec, dadosacademicoscfo from dbo.saluno order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:11:42,898 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:11:43,062 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:11:47,572 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:11:47,573 - INFO - s3a://bronze/corporerm/saluno
# 2024-10-21 08:11:47,573 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:11:48,676 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:11:48,677 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:11:54,632 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:11:54,634 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:11:54,635 - INFO - s3a://bronze/corporerm/saluno
# 2024-10-21 08:11:54,635 - INFO -
# 2024-10-21 08:11:54,640 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:11:54,641 - INFO - Validando extração completa (False)
# 2024-10-21 08:11:54,669 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:11:54,694 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:11:54,695 - INFO -
# 2024-10-21 08:11:54,695 - INFO - 001-dbo.sarea
# 2024-10-21 08:11:54,697 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:11:54,697 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:11:54,698 - INFO - (select codcoligada, codarea, nome, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon from dbo.sarea order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:11:54,737 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:11:54,843 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:11:55,343 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:11:55,344 - INFO - s3a://bronze/corporerm/sarea
# 2024-10-21 08:11:55,345 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:11:56,431 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:11:56,432 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:12:01,987 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:12:01,989 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:12:01,989 - INFO - s3a://bronze/corporerm/sarea
# 2024-10-21 08:12:01,990 - INFO -
# 2024-10-21 08:12:01,995 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:12:01,996 - INFO - Validando extração completa (False)
# 2024-10-21 08:12:02,024 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:12:02,048 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:12:02,049 - INFO -
# 2024-10-21 08:12:02,049 - INFO - 001-dbo.scurso
# 2024-10-21 08:12:02,050 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:12:02,051 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:12:02,051 - INFO - (select codcoligada, codcurso, codescola, codarea, nome, complemento, codcurinep, decreto, regcontrato, descricao, codtipocurso, cfgmatricula, habilitacao, capes, curpresdist, codmodalidadecurso, mascaraturma, idft, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, ideixotecnologico, tipooferta, enviarcenso from dbo.scurso order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:12:02,107 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:12:02,653 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:12:03,279 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:12:03,280 - INFO - s3a://bronze/corporerm/scurso
# 2024-10-21 08:12:03,280 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:12:04,744 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:12:04,745 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:12:10,321 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:12:10,323 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:12:10,324 - INFO - s3a://bronze/corporerm/scurso
# 2024-10-21 08:12:10,324 - INFO -
# 2024-10-21 08:12:10,329 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:12:10,330 - INFO - Validando extração completa (False)
# 2024-10-21 08:12:10,358 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:12:10,380 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:12:10,381 - INFO -
# 2024-10-21 08:12:10,381 - INFO - 001-dbo.sdisciplina
# 2024-10-21 08:12:10,383 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:12:10,383 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:12:10,384 - INFO - (select codcoligada, coddisc, coddischist, nome, nomereduzido, complemento, ch, numcreditos, objetivo, decimais, codtipocurso, chestagio, cursolivre, tipoaula, tipodiscprovao, tiponota, chteorica, chpratica, chlaboratorial, codevento, idft, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, idgrupocomplemento, estagio, chtrabalhocampo, chseminario, chorientacaotutorial, chteoricopratica, integralms, itinerarioformativo, coddisccenso, chextensao from dbo.sdisciplina order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:12:10,437 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:12:10,543 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:12:13,160 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:12:13,161 - INFO - s3a://bronze/corporerm/sdisciplina
# 2024-10-21 08:12:13,162 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:12:14,279 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:12:14,280 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:12:19,764 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:12:19,767 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:12:19,767 - INFO - s3a://bronze/corporerm/sdisciplina
# 2024-10-21 08:12:19,768 - INFO -
# 2024-10-21 08:12:19,774 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:12:19,774 - INFO - Validando extração completa (False)
# 2024-10-21 08:12:19,802 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:12:19,826 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:12:19,827 - INFO -
# 2024-10-21 08:12:19,828 - INFO - 001-dbo.sfrequencia
# 2024-10-21 08:12:19,829 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:12:19,830 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:12:19,831 - INFO - (select codcoligada, idhorarioturma, idturmadisc, ra, [data], presenca, justificada, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, idjustificativafalta from dbo.sfrequencia order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:12:19,871 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:12:20,171 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:12:27,829 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:12:27,830 - INFO - s3a://bronze/corporerm/sfrequencia
# 2024-10-21 08:12:27,831 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:12:29,042 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:12:29,043 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:12:34,349 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:12:34,351 - INFO -
# 2024-10-21 08:12:34,351 - INFO - 002-dbo.sfrequencia
# 2024-10-21 08:12:34,352 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:12:34,353 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:12:34,353 - INFO - (select codcoligada, idhorarioturma, idturmadisc, ra, [data], presenca, justificada, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, idjustificativafalta from dbo.sfrequencia order by 1 offset 1000001 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:12:34,386 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:12:34,787 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:12:44,949 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:12:44,951 - INFO - s3a://bronze/corporerm/sfrequencia
# 2024-10-21 08:12:44,951 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:12:56,671 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:12:56,672 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:13:02,547 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:13:02,548 - INFO -
# 2024-10-21 08:13:02,549 - INFO - 003-dbo.sfrequencia
# 2024-10-21 08:13:02,550 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:13:02,550 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:13:02,550 - INFO - (select codcoligada, idhorarioturma, idturmadisc, ra, [data], presenca, justificada, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, idjustificativafalta from dbo.sfrequencia order by 1 offset 2000001 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:13:02,590 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:13:03,033 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:13:12,273 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:13:12,274 - INFO - s3a://bronze/corporerm/sfrequencia
# 2024-10-21 08:13:12,275 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:13:26,775 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:13:26,776 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:13:32,935 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:13:32,937 - INFO -
# 2024-10-21 08:13:32,937 - INFO - 004-dbo.sfrequencia
# 2024-10-21 08:13:32,938 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:13:32,938 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:13:32,939 - INFO - (select codcoligada, idhorarioturma, idturmadisc, ra, [data], presenca, justificada, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, idjustificativafalta from dbo.sfrequencia order by 1 offset 3000001 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:13:32,982 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:13:33,570 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:13:45,041 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:13:45,042 - INFO - s3a://bronze/corporerm/sfrequencia
# 2024-10-21 08:13:45,042 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:14:04,738 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:14:04,739 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:14:10,883 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:14:10,885 - INFO -
# 2024-10-21 08:14:10,886 - INFO - 005-dbo.sfrequencia
# 2024-10-21 08:14:10,887 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:14:10,887 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:14:10,888 - INFO - (select codcoligada, idhorarioturma, idturmadisc, ra, [data], presenca, justificada, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, idjustificativafalta from dbo.sfrequencia order by 1 offset 4000001 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:14:10,931 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:14:11,501 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:14:22,317 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:14:22,318 - INFO - s3a://bronze/corporerm/sfrequencia
# 2024-10-21 08:14:22,318 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:14:45,703 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:14:45,705 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:14:51,818 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:14:51,820 - INFO -
# 2024-10-21 08:14:51,820 - INFO - 006-dbo.sfrequencia
# 2024-10-21 08:14:51,821 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:14:51,822 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:14:51,822 - INFO - (select codcoligada, idhorarioturma, idturmadisc, ra, [data], presenca, justificada, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, idjustificativafalta from dbo.sfrequencia order by 1 offset 5000001 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:14:51,859 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:14:52,539 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:15:04,113 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:15:04,115 - INFO - s3a://bronze/corporerm/sfrequencia
# 2024-10-21 08:15:04,115 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:15:33,439 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:15:33,440 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:15:40,344 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:15:40,346 - INFO -
# 2024-10-21 08:15:40,347 - INFO - 007-dbo.sfrequencia
# 2024-10-21 08:15:40,348 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:15:40,348 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:15:40,349 - INFO - (select codcoligada, idhorarioturma, idturmadisc, ra, [data], presenca, justificada, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, idjustificativafalta from dbo.sfrequencia order by 1 offset 6000001 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:15:40,394 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:15:41,202 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:15:53,858 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:15:53,859 - INFO - s3a://bronze/corporerm/sfrequencia
# 2024-10-21 08:15:53,860 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:16:28,548 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:16:28,549 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:16:35,174 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:16:35,176 - INFO -
# 2024-10-21 08:16:35,177 - INFO - 008-dbo.sfrequencia
# 2024-10-21 08:16:35,177 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:16:35,178 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:16:35,179 - INFO - (select codcoligada, idhorarioturma, idturmadisc, ra, [data], presenca, justificada, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, idjustificativafalta from dbo.sfrequencia order by 1 offset 7000001 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:16:35,220 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:16:36,082 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:16:48,209 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:16:48,210 - INFO - s3a://bronze/corporerm/sfrequencia
# 2024-10-21 08:16:48,211 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:17:25,083 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:17:25,084 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:17:31,359 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:17:31,360 - INFO -
# 2024-10-21 08:17:31,361 - INFO - 009-dbo.sfrequencia
# 2024-10-21 08:17:31,362 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:17:31,363 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:17:31,364 - INFO - (select codcoligada, idhorarioturma, idturmadisc, ra, [data], presenca, justificada, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, idjustificativafalta from dbo.sfrequencia order by 1 offset 8000001 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:17:31,406 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:17:32,306 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:17:43,621 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:17:43,622 - INFO - s3a://bronze/corporerm/sfrequencia
# 2024-10-21 08:17:43,623 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:18:24,755 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:18:24,756 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:18:31,105 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:18:31,108 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:18:31,108 - INFO - s3a://bronze/corporerm/sfrequencia
# 2024-10-21 08:18:31,109 - INFO -
# 2024-10-21 08:18:31,115 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:18:31,117 - INFO - Validando extração completa (False)
# 2024-10-21 08:18:31,146 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:18:31,172 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:18:31,173 - INFO -
# 2024-10-21 08:18:31,174 - INFO - 001-dbo.sgrade
# 2024-10-21 08:18:31,175 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:18:31,175 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:18:31,176 - INFO - (select codcoligada, codcurso, codhabilitacao, codgrade, aplicacao, codformula, codformulacr, descricao, dtinicio, dtfim, maxcredperiodo, mincredperiodo, cargahoraria, controlevagas, regime, status, tipoatividadecurricular, tipoeletiva, tipooptativa, dtdou, codcursoprox, codhabilitacaoprox, codgradeprox, idft, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, totalcreditos, consminexigatvcurr, qtdminperiodoscursar, qtdminoptele, geraraprovestudo, percchextensao from dbo.sgrade order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:18:31,229 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:18:31,331 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:18:32,167 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:18:32,168 - INFO - s3a://bronze/corporerm/sgrade
# 2024-10-21 08:18:32,168 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:18:33,152 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:18:33,154 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:18:38,724 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:18:38,727 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:18:38,727 - INFO - s3a://bronze/corporerm/sgrade
# 2024-10-21 08:18:38,728 - INFO -
# 2024-10-21 08:18:38,733 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:18:38,734 - INFO - Validando extração completa (False)
# 2024-10-21 08:18:38,761 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:18:38,782 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:18:38,783 - INFO -
# 2024-10-21 08:18:38,783 - INFO - 001-dbo.shabilitacao
# 2024-10-21 08:18:38,785 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:18:38,785 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:18:38,786 - INFO - (select codcoligada, codcurso, codhabilitacao, codcursohist, codseriehist, nome, complemento, textoconclusao, decreto, descricao, integralizacao, codhabinep, dtprovao, complemento2, prioridade, juramento, idft, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, codtipohabilitacao, titulacaomasculina, titulacaofeminina from dbo.shabilitacao order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:18:38,828 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:18:38,927 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:18:39,590 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:18:39,591 - INFO - s3a://bronze/corporerm/shabilitacao
# 2024-10-21 08:18:39,592 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:18:40,566 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:18:40,567 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:18:45,983 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:18:45,986 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:18:45,988 - INFO - s3a://bronze/corporerm/shabilitacao
# 2024-10-21 08:18:45,988 - INFO -
# 2024-10-21 08:18:45,994 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:18:45,995 - INFO - Validando extração completa (False)
# 2024-10-21 08:18:46,033 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:18:46,060 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:18:46,061 - INFO -
# 2024-10-21 08:18:46,062 - INFO - 001-dbo.shabilitacaoaluno
# 2024-10-21 08:18:46,063 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:18:46,064 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:18:46,064 - INFO - (select codcoligada, idhabilitacaofilial, ra, codtipoingresso, codinst, codstatus, dtingresso, pontosvestibular, classificacaovestibular, mediavestibular, dtcolacaograu, dtemisdiploma, registroconclusao, livroregistro, paginaregistro, dtconclusaocurso, cr, mediaglobal, dtprovao, processoregistro, codinstdiploma, observacao, realizouprovao, idhabilitacaofilialorigem, codmotivotransferencia, motivotransferencia, indicecarencia, codcampus, localizacaofisica, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, codinstdestino, codmottransfext, dtprocessoseletivo, dtregistrodiploma, codsistec, pronatec, dtemissaodou, exibediplomaweb, desabilitaintegralizacao, idcertificado from dbo.shabilitacaoaluno order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:18:46,107 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:18:46,346 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:18:54,280 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:18:54,281 - INFO - s3a://bronze/corporerm/shabilitacaoaluno
# 2024-10-21 08:18:54,281 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:18:55,400 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:18:55,401 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:19:00,976 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:19:00,978 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:19:00,979 - INFO - s3a://bronze/corporerm/shabilitacaoaluno
# 2024-10-21 08:19:00,979 - INFO -
# 2024-10-21 08:19:00,985 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:19:00,986 - INFO - Validando extração completa (False)
# 2024-10-21 08:19:01,010 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:19:01,028 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:19:01,028 - INFO -
# ...
# 2024-10-21 08:51:22,346 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:51:22,591 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:52:46,638 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:52:46,640 - INFO - s3a://bronze/corporerm/tmov
# 2024-10-21 08:52:46,640 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:52:47,659 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:52:47,660 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:52:53,200 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:52:53,203 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:52:53,204 - INFO - s3a://bronze/corporerm/tmov
# 2024-10-21 08:52:53,204 - INFO -
# 2024-10-21 08:52:53,212 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:52:53,214 - INFO - Validando extração completa (True)
# 2024-10-21 08:52:53,214 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:52:53,241 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:52:53,242 - INFO -
# 2024-10-21 08:52:53,242 - INFO - 001-dbo.tprd
# 2024-10-21 08:52:53,244 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:52:53,244 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:52:53,245 - INFO - (select codcoligada, idprd, codigoprd, nomefantasia, codigoreduzido, ultimonivel, tipo, descricao, descricaoaux, codigoauxiliar, referenciaccf, numeroccf, referenciacp, descricaocp, pesoliquido, pesobruto, comprimento, espessura, largura, cor, observacao, dtcadastramento, campolivre, campolivre2, campolivre3, idprodutorelac, tempo, inativo, pesavel, dataultalteracao, idimagem, diametro, dataprimeiraalt, codusuario, tempovalidade, usuariocriacao, qtdevolume, codigoex, servicoprodutormofficina, produtoepi, produtobase, numerotributos, eperiodico, block, dataextra1, dataextra2, controladoporlote, mascaranumserie, usanumserie, validademinima, id, codfab, numnofabric, preco1, preco2, preco3, idgrd, codgrd, codcoluna, codlinha, preco4, preco5, databasepreco1, databasepreco2, databasepreco3, databasepreco4, databasepreco5, codmoepreco1, codmoepreco2, codmoepreco3, codmoepreco4, codmoepreco5, codundcontrole, codcpg, estoqueminimo1, estoquemaximo1, estoqueminimo2, estoquemaximo2, estoqueminimo3, estoquemaximo3, pontodepedido1, pontodepedido2, pontodepedido3, percentcomissao, descontocompra, descontovenda, custounitario, dtcustounitario, codtip, codtb1fat, codtb2fat, codtb3fat, codtb4fat, codtb5fat, margembrutalucro, saldogeralfisico, percentcomissao2, codundcompra, codundvenda, recalccustomedio, customedio, datacustomedio, dtultimacompra, tipoconta, saldogeralfinanc, dtultimacomprab, custoreposicaob, percentcomissao3, custoreposicao, localdescarga, codcolcontager, codcontager, usanumdecpreco, numdecpreco, multiploprd, codtipoapl, coddief, toleranciasup, toleranciainf, codgrupo, tributacaoecf, tipocalculocusto, custopadrao, codgrupobem, grpfaturamento, tolinfpreco, tolsuppreco, multiploqtdecomprada, multiploprdvenda, codtborcamento, idprdfiscals, repassefabric, idprdfiscale, codcoltborcamento, recalcsaldo1, recalcsaldo2, recalcsaldo3, recalcsaldo4, recalcsaldo5, recalcsaldo6, recalcsaldo7, recalcsaldo8, recalcsaldo9, recalcsaldo10, codigoirrf, deducaoirrf, issdevidomunicipiocliente, percentbaseinss, percbaseinssempregado, incentivofiscalms, codapuracao, indespecial, codapuracaoe, codigoservicofederal, margemlucrofisc, fatorreducaoicms, inventariofiscal, classefiscalecf, perigoso from dbo.tprd order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:52:53,316 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:52:53,591 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:53:08,268 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:53:08,269 - INFO - s3a://bronze/corporerm/tprd
# 2024-10-21 08:53:08,269 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:53:09,216 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:53:09,216 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:53:14,538 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:53:14,541 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:53:14,541 - INFO - s3a://bronze/corporerm/tprd
# 2024-10-21 08:53:14,542 - INFO -
# 2024-10-21 08:53:14,548 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:53:14,549 - INFO - Validando extração completa (False)
# 2024-10-21 08:53:14,571 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:53:14,588 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:53:14,589 - INFO -
# 2024-10-21 08:53:14,589 - INFO - 001-dbo.ttborcamento
# 2024-10-21 08:53:14,590 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:53:14,591 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:53:14,591 - INFO - (select codcoligada, codtborcamento, descricao, campolivre, inativo, naopermitetransf, natureza, sinteticoanalitico, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon from dbo.ttborcamento order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:53:14,619 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:53:14,699 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:53:15,202 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:53:15,203 - INFO - s3a://bronze/corporerm/ttborcamento
# 2024-10-21 08:53:15,204 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:53:16,074 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:53:16,075 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:53:22,199 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:53:22,201 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:53:22,202 - INFO - s3a://bronze/corporerm/ttborcamento
# 2024-10-21 08:53:22,202 - INFO -
# 2024-10-21 08:53:22,211 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:53:22,212 - INFO - Validando extração completa (False)
# 2024-10-21 08:53:22,234 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:53:22,250 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:53:22,251 - INFO -
# 2024-10-21 08:53:22,252 - INFO - 001-dbo.ttmv
# 2024-10-21 08:53:22,253 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:53:22,253 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:53:22,254 - INFO - (select codtmv, nome, codigomovfixo, tipoemitente, codcfoemissao, nomelocalsaida, edicaolocalsaida, tipodestin, edicaodestin, codcfodestin, tipoidentific, mascaranumeromov, edicaonumeromov, buscarnumeromov, edicaoserie, segnumsequencial, labelnumpedido, edicaonumpedido, numeropedido, labelnumpedcf, edicaonumpedcf, numeropedcf, edicaonatureza, tiponaturezanota, edicaonatureza2, codmodelodocfisc, tipoicms, tipoipi, nomedatasaida, edicaosaida, datasaida, nomedatadigit, edicaodigit, datadigit, nomedata, edicaodata, datadata, edicaorepr, codrpr, edicaocomisrepr, perccomisrepr, edicaotransp, edicaotransp2, codtra, codtra2, edicaoviatransp, viatransporte, editadadosplaca, edicaoobservacao, observacao, usamensagemmov1, codmenmov1, usamensagemmov2, codmenmov2, edicaohistormov, edicaomarcavol, marcavol, edicaoqtdevol, qtdemoveasoma, edicaoespecievol, especievol, edicaopesoliq, edicaopesobru, pesoliqmoveasoma, pesobrumoveasoma, confitempesozero, edicaocondpgto, alteracondpgto, codcpg, edicaotb1fatmov, codtb1fatmov, edicaotb2fatmov, codtb2fatmov, edicaotb3fatmov, codtb3fatmov, edicaotb4fatmov, codtb4fatmov, edicaotb5fatmov, codtb5fatmov, edicaotb1flxmov, codtb1flxmov, edicaotb2flxmov, codtb2flxmov, edicaotb3flxmov, codtb3flxmov, edicaotb4flxmov, codtb4flxmov, edicaotb5flxmov, codtb5flxmov, usacampolivmov1, nomecampolivmov1, campolivmov1, usacampolivmov2, nomecampolivmov2, campolivmov2, usacampolivmov3, nomecampolivmov3, campolivmov3, edicaofrete, tipofrete, informaciffob, codmenfretecif, codmenfretefob, edicaoseguro, tiposeguro, edicaodescmov, tipodescmov, descmaximomov, codmendescmov, edicaodespmov, tipodespmov, codmendespmov, usadespfinanc, nomeextra1, edicaoextra1, tipoextra1, nomeextra2, edicaoextra2, tipoextra2, edicaoadiantped, databasemov, codmoeda, nomesubtotal, editavalfinlivre, usatrbmov, editatrbmov, editabctrbmov, numtrbselecmov, tipolancamento, fatura, faturamanutencao, edicaolan, tipodocgerado, idrelatfat, idrelatdup, idrelatmov, impinstfat, impinstdup, impinstdoc, dataemissaolan, dataprevisaolan, data1lan, data2lan, data3lan, numeracaolan, contabillan, historicolan, codmoedalan, codindexadorlan, buscarcaixalan, baixarlan, percentdesclan, percentjuroslan, statuscnablan, comandocnablan, aceitecnablan, instcod1cnablan, instcod2cnablan, carteiracnablan, associasegnumlan, databasevenclan, capitalmensallan, pagoureclan, numeroprecovend, flagdatamov, geramovped, geramovautoped, codtmvped, baixageracaoped, confirmabaixaped, cancelalctped, controlasenhaped, precocomdescped, precomovgerped, cancelacommovped, numeroversaotmov, alteratipolan, codtrbrateiolan, usavorcccusto, usavorcfisccttip, avivorcccusto, avivorcfisccttip, avicreditoclifor, editatroco, codven1, codven2, codven3, codven4, edicaoven1, edicaocomisven1, perccomisven1, edicaoven2, edicaocomisven2, perccomisven2, edicaoven3, edicaocomisven3, perccomisven3, edicaoven4, edicaocomisven4, perccomisven4, codcolcfoemissao, codcolcfodestin, aplicacaofrm, afetacustorep, afetacustorepb, codcolcxa, editaccusto, tipotransffat, codccusto, codfrmliquido, codfrmsubtotal, codfrmbruto, codfrmcustorep, codfrmcustorepb, codfrmprecovend, codfrmrateiolan, codcxalan, codcoligada, codtdolannf, codtdolandup, renumerarimpressao, usarevc, codevento, editaeventocont, cadastracheqlan, edicaoentrega, dataentrega, integradofactor, edicaodepartamento, marcaritensfatped, naoagruparitensped, edicaolocalestoque, codfilial, codloc, tipohistorico, tipomovtransf, numeromaxparcelas, valorminparcela, usardevolucao, tipodevolucao, relacitensfaturamento, dataorcamento, tabbaseorcamento, aceitanumserie, usanumserieseq, coddeptodefaultmov, coddeptodefaultitem, codcolreldup, codcolrelfat, codcolrelmov, idnat, idnat2, classificacao, codmenfreteterceiro, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon, idformapagtobaixarlan, edicaoendcoletaentregadest, desconsiderarsn from dbo.ttmv order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:53:22,321 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:53:22,415 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:53:23,499 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:53:23,502 - INFO - s3a://bronze/corporerm/ttmv
# 2024-10-21 08:53:23,502 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:53:24,506 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:53:24,507 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:53:29,877 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:53:29,879 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:53:29,880 - INFO - s3a://bronze/corporerm/ttmv
# 2024-10-21 08:53:29,880 - INFO -
# 2024-10-21 08:53:29,886 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:53:29,887 - INFO - Validando extração completa (False)
# 2024-10-21 08:53:29,907 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:53:29,924 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:53:29,924 - INFO -
# 2024-10-21 08:53:29,925 - INFO - 001-dbo.tven
# 2024-10-21 08:53:29,926 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:53:29,926 - INFO - Aguarde... Executando Query (Database)
# 2024-10-21 08:53:29,927 - INFO - (select codcoligada, codven, nome, cargo, codfilial, codloc, comissao1, comissao2, comissao3, codpessoa, vendecompra, codusuario, senha, inativo, pfvendedor, pfcaixa, pfsupervisor, pfgerente, idfuncionario, comissao4, descmaximo, reccreatedby, reccreatedon, recmodifiedby, recmodifiedon from dbo.tven order by 1 offset 1 rows fetch next 1000000 rows only)temp
# 2024-10-21 08:53:29,964 - INFO - Query (Database) executada com sucesso
# 2024-10-21 08:53:30,044 - INFO - Aguarde... Persistindo dados (append)
# 2024-10-21 08:53:30,740 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:53:30,741 - INFO - s3a://bronze/corporerm/tven
# 2024-10-21 08:53:30,741 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:53:31,701 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:53:31,702 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:53:36,986 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:53:36,999 - INFO - Extração do banco dados com sucesso
# 2024-10-21 08:53:37,000 - INFO - s3a://bronze/corporerm/tven
# 2024-10-21 08:53:37,000 - INFO - Extração de dados camada bronze concluida com sucesso
# 2024-10-21 08:53:37,287 - INFO - Sessão Spark finalizada.

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-10-21 08:53:37,304 - INFO - Sessão Spark finalizada.
