# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
bucket = "bronze"
datamart = "dynamicscrm"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-11-07 18:13:42,344 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Realiza extração e gravação no datalake

# %%
extrator_bronze.extrair_dados_bronze()
# Out:
# 2024-11-07 18:13:44,329 - INFO - Aguarde... Iniciando extração de dados camada Bronze
# 2024-11-07 18:13:44,330 - INFO - Lista de yaml carregada com sucesso
# 2024-11-07 18:13:44,332 - INFO -
# Extraindo dados api
# Total de registros acumulados: 5000
# Total de registros acumulados: 10000
# Total de registros acumulados: 15000
# Total de registros acumulados: 20000
# Total de registros acumulados: 20993
# 2024-11-07 18:15:02,171 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-11-07 18:15:11,495 - INFO - Dados persistidos com sucesso
# 2024-11-07 18:15:11,496 - INFO - s3a://bronze/dynamicscrm/accounts
# 2024-11-07 18:15:11,496 - INFO - Aguarde... Realizando optimize
# 2024-11-07 18:15:20,864 - INFO - Optimize executado com sucesso.
# 2024-11-07 18:15:20,865 - INFO - Aguarde... Realizando vacuum
# 2024-11-07 18:15:36,053 - INFO - Vacuum executado com sucesso.
# 2024-11-07 18:15:36,054 - INFO - Extração concluída com sucesso
# 2024-11-07 18:15:36,055 - INFO -
# Extraindo dados api
# Total de registros acumulados: 3140
# 2024-11-07 18:15:43,595 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-11-07 18:15:45,826 - INFO - Dados persistidos com sucesso
# 2024-11-07 18:15:45,826 - INFO - s3a://bronze/dynamicscrm/products
# 2024-11-07 18:15:45,827 - INFO - Aguarde... Realizando optimize
# 2024-11-07 18:15:47,881 - INFO - Optimize executado com sucesso.
# 2024-11-07 18:15:47,882 - INFO - Aguarde... Realizando vacuum
# 2024-11-07 18:15:57,047 - INFO - Vacuum executado com sucesso.
# 2024-11-07 18:15:57,048 - INFO - Extração concluída com sucesso
# 2024-11-07 18:15:57,048 - INFO -
# Extraindo dados api
# Total de registros acumulados: 5000
# Total de registros acumulados: 10000
# Total de registros acumulados: 15000
# Total de registros acumulados: 20000
# Total de registros acumulados: 25000
# Total de registros acumulados: 30000
# Total de registros acumulados: 35000
# Total de registros acumulados: 40000
# Total de registros acumulados: 45000
# Total de registros acumulados: 50000
# Total de registros acumulados: 55000
# Total de registros acumulados: 60000
# Total de registros acumulados: 65000
# Total de registros acumulados: 70000
# Total de registros acumulados: 75000
# Total de registros acumulados: 80000
# Total de registros acumulados: 85000
# Total de registros acumulados: 90000
# Total de registros acumulados: 95000
# Total de registros acumulados: 100000
# Total de registros acumulados: 105000
# Total de registros acumulados: 110000
# Total de registros acumulados: 110455
# 2024-11-07 18:21:00,482 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-11-07 18:21:04,042 - INFO - Dados persistidos com sucesso
# 2024-11-07 18:21:04,043 - INFO - s3a://bronze/dynamicscrm/quotedetails
# 2024-11-07 18:21:04,043 - INFO - Aguarde... Realizando optimize
# 2024-11-07 18:21:11,255 - INFO - Optimize executado com sucesso.
# 2024-11-07 18:21:11,255 - INFO - Aguarde... Realizando vacuum
# 2024-11-07 18:21:19,018 - INFO - Vacuum executado com sucesso.
# 2024-11-07 18:21:19,018 - INFO - Extração concluída com sucesso
# 2024-11-07 18:21:19,019 - INFO -
# Extraindo dados api
# Total de registros acumulados: 5000
# Total de registros acumulados: 10000
# Total de registros acumulados: 15000
# Total de registros acumulados: 20000
# Total de registros acumulados: 25000
# Total de registros acumulados: 30000
# Total de registros acumulados: 35000
# Total de registros acumulados: 40000
# Total de registros acumulados: 45000
# Total de registros acumulados: 50000
# Total de registros acumulados: 54548
# 2024-11-07 18:24:13,527 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-11-07 18:24:16,005 - INFO - Dados persistidos com sucesso
# 2024-11-07 18:24:16,005 - INFO - s3a://bronze/dynamicscrm/quotes
# 2024-11-07 18:24:16,006 - INFO - Aguarde... Realizando optimize
# 2024-11-07 18:24:22,582 - INFO - Optimize executado com sucesso.
# 2024-11-07 18:24:22,583 - INFO - Aguarde... Realizando vacuum
# 2024-11-07 18:24:29,857 - INFO - Vacuum executado com sucesso.
# 2024-11-07 18:24:29,858 - INFO - Extração concluída com sucesso
# 2024-11-07 18:24:29,859 - INFO - Extração de dados camada bronze concluida com sucesso
# 2024-11-07 18:24:30,846 - INFO - Sessão Spark finalizada.
