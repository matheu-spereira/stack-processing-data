# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "bronze"
datamart = "gd_alinhar"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-11-19 14:57:33,907 - INFO - Iniciando Sessão Spark.
# 24/11/19 14:57:34 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/11/19 14:57:35 WARN Utils: spark.executor.instances less than spark.dynamicAllocation.minExecutors is invalid, ignoring its setting, please update your configs.

# %%
extrator_bronze.conexao_banco_de_dados('sqlserver',
                                       'sqlserver',
                                       '1433',
                                       'sa',
                                       'SqlServer2019!',
                                       'Pessoas',
                                       '')
# Out:
# 2024-11-19 14:57:35,979 - INFO - Aguarde... Configurando conexao banco de dados

# %%
extrator_bronze.extrair_dados_bronze()
# Out:
# 2024-11-19 14:57:35,987 - INFO - Aguarde... Iniciando extração de dados camada Bronze
# 2024-11-19 14:57:35,989 - INFO - Lista de yaml carregada com sucesso
# 2024-11-19 14:57:35,989 - INFO -
# 2024-11-19 14:57:35,994 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-11-19 14:57:35,995 - INFO - Validando extração completa (True)
# 2024-11-19 14:57:35,996 - INFO - Preparando SQL para banco de dados
# 2024-11-19 14:57:35,997 - INFO - Aguarde... Executando Query (Database)
# 2024-11-19 14:57:35,997 - INFO - (SELECT cargo_id, descricao, nivel FROM Pessoas.Cargos)temp
# 2024-11-19 14:57:37,154 - INFO - Query (Database) executada com sucesso
# 2024-11-19 14:57:39,096 - INFO - Aguarde... Persistindo dados (overwrite)
# 24/11/19 14:57:39 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# 24/11/19 14:57:42 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 2024-11-19 14:57:49,484 - INFO - Dados persistidos com sucesso
# 2024-11-19 14:57:49,485 - INFO - s3a://bronze/pessoas/cargos
# 2024-11-19 14:57:49,485 - INFO - Aguarde... Realizando optimize
# 2024-11-19 14:57:52,850 - INFO - Optimize executado com sucesso.
# 2024-11-19 14:57:52,850 - INFO - Aguarde... Realizando vacuum
# 2024-11-19 14:58:05,773 - INFO - Vacuum executado com sucesso.
# 2024-11-19 14:58:05,778 - INFO - Extração do banco dados com sucesso
# 2024-11-19 14:58:05,778 - INFO - s3a://bronze/pessoas/cargos
# 2024-11-19 14:58:05,779 - INFO -
# 2024-11-19 14:58:05,782 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-11-19 14:58:05,783 - INFO - Validando extração completa (True)
# 2024-11-19 14:58:05,783 - INFO - Preparando SQL para banco de dados
# 2024-11-19 14:58:05,784 - INFO - Aguarde... Executando Query (Database)
# 2024-11-19 14:58:05,784 - INFO - (SELECT departamento_id, nome, localizacao FROM Pessoas.Departamentos)temp
# 2024-11-19 14:58:05,807 - INFO - Query (Database) executada com sucesso
# Deleted 0 files and directories in a total of 1 directories.
# 2024-11-19 14:58:06,050 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-11-19 14:58:07,182 - INFO - Dados persistidos com sucesso
# 2024-11-19 14:58:07,183 - INFO - s3a://bronze/pessoas/departamentos
# 2024-11-19 14:58:07,184 - INFO - Aguarde... Realizando optimize
# 2024-11-19 14:58:08,345 - INFO - Optimize executado com sucesso.
# 2024-11-19 14:58:08,346 - INFO - Aguarde... Realizando vacuum
# 2024-11-19 14:58:17,898 - INFO - Vacuum executado com sucesso.
# 2024-11-19 14:58:17,899 - INFO - Extração do banco dados com sucesso
# 2024-11-19 14:58:17,900 - INFO - s3a://bronze/pessoas/departamentos
# 2024-11-19 14:58:17,900 - INFO -
# 2024-11-19 14:58:17,904 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-11-19 14:58:17,905 - INFO - Validando extração completa (True)
# 2024-11-19 14:58:17,906 - INFO - Preparando SQL para banco de dados
# 2024-11-19 14:58:17,906 - INFO - Aguarde... Executando Query (Database)
# 2024-11-19 14:58:17,907 - INFO - (SELECT funcionario_id, nome, data_nascimento, cargo_id, departamento_id, data_admissao, salario FROM Pessoas.Funcionários)temp
# 2024-11-19 14:58:17,932 - INFO - Query (Database) executada com sucesso
# 2024-11-19 14:58:17,983 - INFO - Aguarde... Persistindo dados (overwrite)
# Deleted 0 files and directories in a total of 1 directories.
# 2024-11-19 14:58:19,434 - INFO - Dados persistidos com sucesso
# 2024-11-19 14:58:19,435 - INFO - s3a://bronze/pessoas/funcionarios
# 2024-11-19 14:58:19,435 - INFO - Aguarde... Realizando optimize
# 2024-11-19 14:58:20,277 - INFO - Optimize executado com sucesso.
# 2024-11-19 14:58:20,278 - INFO - Aguarde... Realizando vacuum
# 2024-11-19 14:58:29,992 - INFO - Vacuum executado com sucesso.
# 2024-11-19 14:58:29,994 - INFO - Extração do banco dados com sucesso
# 2024-11-19 14:58:29,995 - INFO - s3a://bronze/pessoas/funcionarios
# 2024-11-19 14:58:29,996 - INFO -
# 2024-11-19 14:58:30,000 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-11-19 14:58:30,001 - INFO - Validando extração completa (True)
# 2024-11-19 14:58:30,001 - INFO - Preparando SQL para banco de dados
# 2024-11-19 14:58:30,002 - INFO - Aguarde... Executando Query (Database)
# 2024-11-19 14:58:30,002 - INFO - (SELECT funcionario_id, projeto_id, papel FROM Pessoas.Funcionários_Projetos)temp
# 2024-11-19 14:58:30,026 - INFO - Query (Database) executada com sucesso
# 2024-11-19 14:58:30,075 - INFO - Aguarde... Persistindo dados (overwrite)
# Deleted 0 files and directories in a total of 1 directories.
# 2024-11-19 14:58:31,087 - INFO - Dados persistidos com sucesso
# 2024-11-19 14:58:31,087 - INFO - s3a://bronze/pessoas/funcionarios_projetos
# 2024-11-19 14:58:31,088 - INFO - Aguarde... Realizando optimize
# 2024-11-19 14:58:31,915 - INFO - Optimize executado com sucesso.
# 2024-11-19 14:58:31,916 - INFO - Aguarde... Realizando vacuum
# 2024-11-19 14:58:41,724 - INFO - Vacuum executado com sucesso.
# 2024-11-19 14:58:41,728 - INFO - Extração do banco dados com sucesso
# 2024-11-19 14:58:41,729 - INFO - s3a://bronze/pessoas/funcionarios_projetos
# 2024-11-19 14:58:41,730 - INFO -
# 2024-11-19 14:58:41,734 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-11-19 14:58:41,735 - INFO - Validando extração completa (True)
# 2024-11-19 14:58:41,736 - INFO - Preparando SQL para banco de dados
# 2024-11-19 14:58:41,736 - INFO - Aguarde... Executando Query (Database)
# 2024-11-19 14:58:41,737 - INFO - (SELECT projeto_id, nome, data_inicio, data_fim FROM Pessoas.Projetos)temp
# 2024-11-19 14:58:41,760 - INFO - Query (Database) executada com sucesso
# 2024-11-19 14:58:41,810 - INFO - Aguarde... Persistindo dados (overwrite)
# Deleted 0 files and directories in a total of 1 directories.
# 2024-11-19 14:58:42,779 - INFO - Dados persistidos com sucesso
# 2024-11-19 14:58:42,779 - INFO - s3a://bronze/pessoas/projetos
# 2024-11-19 14:58:42,780 - INFO - Aguarde... Realizando optimize
# 2024-11-19 14:58:43,601 - INFO - Optimize executado com sucesso.
# 2024-11-19 14:58:43,602 - INFO - Aguarde... Realizando vacuum
# 2024-11-19 14:58:53,249 - INFO - Vacuum executado com sucesso.
# 2024-11-19 14:58:53,250 - INFO - Extração do banco dados com sucesso
# 2024-11-19 14:58:53,251 - INFO - s3a://bronze/pessoas/projetos
# 2024-11-19 14:58:53,252 - INFO - Extração de dados camada bronze concluida com sucesso
# Deleted 0 files and directories in a total of 1 directories.
# 2024-11-19 14:58:53,449 - INFO - Sessão Spark finalizada.

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-11-19 14:58:53,459 - INFO - Sessão Spark finalizada.
