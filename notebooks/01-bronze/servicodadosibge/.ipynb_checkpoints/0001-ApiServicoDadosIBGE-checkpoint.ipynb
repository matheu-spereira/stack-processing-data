# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "bronze"
datamart = "apiservicodadosibge"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2025-01-12 10:20:43,558 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Extração e gravação no datalake

# %%
extrator_bronze.extrair_dados_bronze()
# Out:
# 2025-01-12 10:20:46,285 - INFO - Aguarde... Iniciando extração de dados camada Bronze
# 2025-01-12 10:20:46,286 - INFO - Lista de yaml carregada com sucesso
# 2025-01-12 10:20:46,287 - INFO -
# Extraindo dados api
# 2025-01-12 10:20:51,782 - INFO - Aguarde... Persistindo dados (overwrite)
# 2025-01-12 10:21:00,632 - INFO - Dados persistidos com sucesso
# 2025-01-12 10:21:00,633 - INFO - s3a://bronze/servicodadosibge/cnaeclasses
# 2025-01-12 10:21:00,633 - INFO - Aguarde... Realizando optimize
# 2025-01-12 10:21:09,208 - INFO - Optimize executado com sucesso.
# 2025-01-12 10:21:09,209 - INFO - Aguarde... Realizando vacuum
# 2025-01-12 10:21:41,244 - INFO - Vacuum executado com sucesso.
# 2025-01-12 10:21:41,245 - INFO - Extração concluída com sucesso
# 2025-01-12 10:21:41,245 - INFO -
# Extraindo dados api
# 2025-01-12 10:21:42,685 - INFO - Aguarde... Persistindo dados (overwrite)
# 2025-01-12 10:21:45,198 - INFO - Dados persistidos com sucesso
# 2025-01-12 10:21:45,199 - INFO - s3a://bronze/servicodadosibge/cnaedivisoes
# 2025-01-12 10:21:45,200 - INFO - Aguarde... Realizando optimize
# 2025-01-12 10:21:47,832 - INFO - Optimize executado com sucesso.
# 2025-01-12 10:21:47,832 - INFO - Aguarde... Realizando vacuum
# 2025-01-12 10:22:03,220 - INFO - Vacuum executado com sucesso.
# 2025-01-12 10:22:03,220 - INFO - Extração concluída com sucesso
# 2025-01-12 10:22:03,222 - INFO -
# Extraindo dados api
# 2025-01-12 10:22:04,161 - INFO - Aguarde... Persistindo dados (overwrite)
# 2025-01-12 10:22:05,031 - INFO - Dados persistidos com sucesso
# 2025-01-12 10:22:05,032 - INFO - s3a://bronze/servicodadosibge/cnaegrupos
# 2025-01-12 10:22:05,032 - INFO - Aguarde... Realizando optimize
# 2025-01-12 10:22:07,047 - INFO - Optimize executado com sucesso.
# 2025-01-12 10:22:07,048 - INFO - Aguarde... Realizando vacuum
# 2025-01-12 10:22:21,043 - INFO - Vacuum executado com sucesso.
# 2025-01-12 10:22:21,044 - INFO - Extração concluída com sucesso
# 2025-01-12 10:22:21,045 - INFO -
# Extraindo dados api
# 2025-01-12 10:22:21,942 - INFO - Aguarde... Persistindo dados (overwrite)
# 2025-01-12 10:22:23,138 - INFO - Dados persistidos com sucesso
# 2025-01-12 10:22:23,140 - INFO - s3a://bronze/servicodadosibge/cnaesecoes
# 2025-01-12 10:22:23,141 - INFO - Aguarde... Realizando optimize
# 2025-01-12 10:22:25,768 - INFO - Optimize executado com sucesso.
# 2025-01-12 10:22:25,768 - INFO - Aguarde... Realizando vacuum
# 2025-01-12 10:22:38,401 - INFO - Vacuum executado com sucesso.
# 2025-01-12 10:22:38,402 - INFO - Extração concluída com sucesso
# 2025-01-12 10:22:38,404 - INFO -
# Extraindo dados api
# 2025-01-12 10:22:52,571 - INFO - Aguarde... Persistindo dados (overwrite)
# 2025-01-12 10:22:56,140 - INFO - Dados persistidos com sucesso
# 2025-01-12 10:22:56,142 - INFO - s3a://bronze/servicodadosibge/cnaesubclasses
# 2025-01-12 10:22:56,143 - INFO - Aguarde... Realizando optimize
# 2025-01-12 10:22:58,898 - INFO - Optimize executado com sucesso.
# 2025-01-12 10:22:58,899 - INFO - Aguarde... Realizando vacuum
# 2025-01-12 10:23:16,375 - INFO - Vacuum executado com sucesso.
# 2025-01-12 10:23:16,376 - INFO - Extração concluída com sucesso
# 2025-01-12 10:23:16,377 - INFO - Extração de dados camada bronze concluida com sucesso
# 2025-01-12 10:23:17,104 - INFO - Sessão Spark finalizada.
