# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
bucket = "bronze"
datamart = "sgt"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-11-19 15:20:11,291 - INFO - Iniciando Sessão Spark.
# 24/11/19 15:20:12 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/11/19 15:20:12 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 24/11/19 15:20:13 WARN Utils: spark.executor.instances less than spark.dynamicAllocation.minExecutors is invalid, ignoring its setting, please update your configs.

# %% [markdown]
# # Realiza extração e gravação no datalake

# %%
extrator_bronze.extrair_dados_bronze()
# Out:
# 2024-11-19 15:20:13,254 - INFO - Aguarde... Iniciando extração de dados camada Bronze
# 2024-11-19 15:20:13,256 - INFO - Lista de yaml carregada com sucesso
# 2024-11-19 15:20:13,257 - INFO -
# Extraindo dados api
# 24/11/19 15:20:38 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 24/11/19 15:20:51 WARN TaskSetManager: Stage 0 contains a task of very large size (3029 KiB). The maximum recommended task size is 1000 KiB.
# 2024-11-19 15:20:52,408 - INFO - Aguarde... Persistindo dados (overwrite)
# 24/11/19 15:20:52 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# DataFrame criado.
# 24/11/19 15:20:52 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# 24/11/19 15:21:00 WARN TaskSetManager: Stage 9 contains a task of very large size (3029 KiB). The maximum recommended task size is 1000 KiB.
# 2024-11-19 15:21:02,248 - INFO - Dados persistidos com sucesso
# 2024-11-19 15:21:02,249 - INFO - s3a://bronze/sgt/atendimentosintegracoes
# 2024-11-19 15:21:02,250 - INFO - Aguarde... Realizando optimize
# 2024-11-19 15:21:04,706 - INFO - Optimize executado com sucesso.
# 2024-11-19 15:21:04,706 - INFO - Aguarde... Realizando vacuum
# 2024-11-19 15:21:20,282 - INFO - Vacuum executado com sucesso.
# 2024-11-19 15:21:20,283 - INFO - Extração concluída com sucesso
# 2024-11-19 15:21:20,283 - INFO -
# Deleted 0 files and directories in a total of 1 directories.
# Extraindo dados api
# 2024-11-19 15:21:21,245 - INFO - Aguarde... Persistindo dados (overwrite)
# DataFrame criado.
# 2024-11-19 15:21:23,982 - INFO - Dados persistidos com sucesso
# 2024-11-19 15:21:23,983 - INFO - s3a://bronze/sgt/atendimento
# 2024-11-19 15:21:23,983 - INFO - Aguarde... Realizando optimize
# 2024-11-19 15:21:25,672 - INFO - Optimize executado com sucesso.
# 2024-11-19 15:21:25,672 - INFO - Aguarde... Realizando vacuum
# 2024-11-19 15:21:38,777 - INFO - Vacuum executado com sucesso.
# 2024-11-19 15:21:38,777 - INFO - Extração concluída com sucesso
# 2024-11-19 15:21:38,778 - INFO -
# Deleted 0 files and directories in a total of 1 directories.
# Extraindo dados api
# 2024-11-19 15:21:39,131 - INFO - Aguarde... Persistindo dados (overwrite)
# DataFrame criado.
# 2024-11-19 15:21:41,275 - INFO - Dados persistidos com sucesso
# 2024-11-19 15:21:41,276 - INFO - s3a://bronze/sgt/clientes
# 2024-11-19 15:21:41,276 - INFO - Aguarde... Realizando optimize
# 2024-11-19 15:21:42,607 - INFO - Optimize executado com sucesso.
# 2024-11-19 15:21:42,608 - INFO - Aguarde... Realizando vacuum
# 2024-11-19 15:21:55,415 - INFO - Vacuum executado com sucesso.
# 2024-11-19 15:21:55,416 - INFO - Extração concluída com sucesso
# 2024-11-19 15:21:55,416 - INFO -
# Deleted 0 files and directories in a total of 1 directories.
# Extraindo dados api
# 24/11/19 15:21:58 WARN TaskSetManager: Stage 295 contains a task of very large size (1110 KiB). The maximum recommended task size is 1000 KiB.
# 2024-11-19 15:21:58,440 - INFO - Aguarde... Persistindo dados (overwrite)
# DataFrame criado.
# 24/11/19 15:21:59 WARN TaskSetManager: Stage 303 contains a task of very large size (1110 KiB). The maximum recommended task size is 1000 KiB.
# 2024-11-19 15:22:00,397 - INFO - Dados persistidos com sucesso
# 2024-11-19 15:22:00,398 - INFO - s3a://bronze/sgt/producaohh
# 2024-11-19 15:22:00,398 - INFO - Aguarde... Realizando optimize
# 2024-11-19 15:22:01,698 - INFO - Optimize executado com sucesso.
# 2024-11-19 15:22:01,699 - INFO - Aguarde... Realizando vacuum
# 2024-11-19 15:22:14,803 - INFO - Vacuum executado com sucesso.
# 2024-11-19 15:22:14,803 - INFO - Extração concluída com sucesso
# 2024-11-19 15:22:14,804 - INFO -
# Deleted 0 files and directories in a total of 1 directories.
# Extraindo dados api
# 24/11/19 15:22:29 WARN TaskSetManager: Stage 397 contains a task of very large size (2750 KiB). The maximum recommended task size is 1000 KiB.
# 2024-11-19 15:22:29,458 - INFO - Aguarde... Persistindo dados (overwrite)
# DataFrame criado.
# 24/11/19 15:22:30 WARN TaskSetManager: Stage 405 contains a task of very large size (2750 KiB). The maximum recommended task size is 1000 KiB.
# 2024-11-19 15:22:31,548 - INFO - Dados persistidos com sucesso
# 2024-11-19 15:22:31,548 - INFO - s3a://bronze/sgt/producoes
# 2024-11-19 15:22:31,549 - INFO - Aguarde... Realizando optimize
# 2024-11-19 15:22:32,881 - INFO - Optimize executado com sucesso.
# 2024-11-19 15:22:32,881 - INFO - Aguarde... Realizando vacuum
# 2024-11-19 15:22:44,161 - INFO - Vacuum executado com sucesso.
# 2024-11-19 15:22:44,161 - INFO - Extração concluída com sucesso
# 2024-11-19 15:22:44,161 - INFO -
# Deleted 0 files and directories in a total of 1 directories.
# Extraindo dados api
# 2024-11-19 15:22:44,577 - INFO - Aguarde... Persistindo dados (overwrite)
# DataFrame criado.
# 2024-11-19 15:22:46,377 - INFO - Dados persistidos com sucesso
# 2024-11-19 15:22:46,378 - INFO - s3a://bronze/sgt/produtosregionais
# 2024-11-19 15:22:46,378 - INFO - Aguarde... Realizando optimize
# 2024-11-19 15:22:47,495 - INFO - Optimize executado com sucesso.
# 2024-11-19 15:22:47,495 - INFO - Aguarde... Realizando vacuum
# 2024-11-19 15:22:59,996 - INFO - Vacuum executado com sucesso.
# 2024-11-19 15:22:59,996 - INFO - Extração concluída com sucesso
# 2024-11-19 15:22:59,997 - INFO -
# Deleted 0 files and directories in a total of 1 directories.
# Extraindo dados api
# 2024-11-19 15:23:03,065 - INFO - Aguarde... Persistindo dados (overwrite)
# DataFrame criado.
# 2024-11-19 15:23:04,886 - INFO - Dados persistidos com sucesso
# 2024-11-19 15:23:04,887 - INFO - s3a://bronze/sgt/receitas
# 2024-11-19 15:23:04,888 - INFO - Aguarde... Realizando optimize
# 2024-11-19 15:23:06,101 - INFO - Optimize executado com sucesso.
# 2024-11-19 15:23:06,101 - INFO - Aguarde... Realizando vacuum
# 2024-11-19 15:23:18,761 - INFO - Vacuum executado com sucesso.
# 2024-11-19 15:23:18,761 - INFO - Extração concluída com sucesso
# 2024-11-19 15:23:18,762 - INFO -
# Deleted 0 files and directories in a total of 1 directories.
# Extraindo dados api
# 2024-11-19 15:23:19,075 - INFO - Aguarde... Persistindo dados (overwrite)
# DataFrame criado.
# 2024-11-19 15:23:20,898 - INFO - Dados persistidos com sucesso
# 2024-11-19 15:23:20,899 - INFO - s3a://bronze/sgt/relatorios
# 2024-11-19 15:23:20,899 - INFO - Aguarde... Realizando optimize
# 2024-11-19 15:23:22,064 - INFO - Optimize executado com sucesso.
# 2024-11-19 15:23:22,064 - INFO - Aguarde... Realizando vacuum
# 2024-11-19 15:23:35,146 - INFO - Vacuum executado com sucesso.
# 2024-11-19 15:23:35,147 - INFO - Extração concluída com sucesso
# 2024-11-19 15:23:35,148 - INFO - Extração de dados camada bronze concluida com sucesso
# Deleted 0 files and directories in a total of 1 directories.
# 2024-11-19 15:23:35,935 - INFO - Sessão Spark finalizada.
