# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "bronze"
datamart = "sors"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 08:05:47,201 - INFO - Iniciando Sessão Spark.

# %%
extrator_bronze.conexao_banco_de_dados(os.getenv("DB_SORS_DBMS"),
                                       os.getenv("DB_SORS_HOST"),
                                       os.getenv("DB_SORS_PORT"),
                                       os.getenv("DB_SORS_USER"),
                                       os.getenv("DB_SORS_PASSWORD"),
                                       os.getenv("DB_SORS_DATABASE"),
                                       '')
# Out:
# 2024-10-21 08:05:51,512 - INFO - Aguarde... Configurando conexao banco de dados

# %%
extrator_bronze.extrair_dados_bronze()
# Out:
# 2024-10-21 08:05:51,518 - INFO - Aguarde... Iniciando extração de dados camada Bronze
# 2024-10-21 08:05:51,520 - INFO - Lista de yaml carregada com sucesso
# 2024-10-21 08:05:51,520 - INFO -
# 2024-10-21 08:05:51,528 - INFO - Aguarde... Extraindo dados do banco de dados
# 2024-10-21 08:05:51,529 - INFO - Validando extração completa (False)
# 2024-10-21 08:05:54,227 - INFO - Aguarde... Excluindo registros
# 2024-10-21 08:05:54,270 - INFO - Registros excluidos com sucesso
# 2024-10-21 08:05:54,271 - INFO -
# 2024-10-21 08:05:54,271 - INFO - 001-dbo.centrocusto
# 2024-10-21 08:05:54,273 - INFO - Preparando SQL para banco de dados
# 2024-10-21 08:05:54,273 - INFO - Aguarde... Executando Query (Database)
# ...

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-10-21 08:09:52,749 - INFO - Sessão Spark finalizada.
