# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "silver"
datamart = "CaravelAL"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-09-25 18:51:58,364 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Leitura da tabela

# %%
df_compliance_cni_rlc= extrator_bronze.criar_view_temporaria('bronze/CaravelAL/CNIRlc/','compliance_cni_rlc')
# Out:
# 2024-09-25 18:52:02,321 - INFO - Aguarde... Criando View (bronze/CaravelAL/CNIRlc/)
# 2024-09-25 18:52:11,450 - INFO - View criada com sucesso

# %% [markdown]
# # Gravação no datalake

# %%
extrator_bronze.caminho_tabela_delta = 's3a://silver/CaravelAL/CNIRlc'

# %%
extrator_bronze.salvar_delta(df_compliance_cni_rlc, 'overwrite')
# Out:
# 2024-09-25 18:52:11,466 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-09-25 18:52:21,061 - INFO - Dados persistidos com sucesso
# 2024-09-25 18:52:21,062 - INFO - s3a://silver/CaravelAL/CNIRlc
# 2024-09-25 18:52:21,063 - INFO - Aguarde... Realizando optimize
# 2024-09-25 18:52:23,387 - INFO - Optimize executado com sucesso.
# 2024-09-25 18:52:23,389 - INFO - Aguarde... Realizando vacuum
# 2024-09-25 18:52:54,280 - INFO - Vacuum executado com sucesso.

# %% [markdown]
# # Encerra sessão spark

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-09-25 18:52:54,668 - INFO - Sessão Spark finalizada.
