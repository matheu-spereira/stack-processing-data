# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "silver"
datamart = "CaravelAL"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-09-25 18:52:04,074 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Leitura da tabela

# %%
df_compliance_tcurlcacordaos= extrator_bronze.criar_view_temporaria('bronze/CaravelAL/TCURlcAcordaos','compliance_tcurlcacordaos')
# Out:
# 2024-09-25 18:52:09,100 - INFO - Aguarde... Criando View (bronze/CaravelAL/TCURlcAcordaos)
# 2024-09-25 18:52:18,618 - INFO - View criada com sucesso

# %% [markdown]
# # Gravação no datalake

# %%
extrator_bronze.caminho_tabela_delta = 's3a://silver/CaravelAL/TCURlcAcordaos'

# %%
extrator_bronze.salvar_delta(df_compliance_tcurlcacordaos, 'overwrite')
# Out:
# 2024-09-25 18:52:18,635 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-09-25 18:52:29,211 - INFO - Dados persistidos com sucesso
# 2024-09-25 18:52:29,212 - INFO - s3a://silver/CaravelAL/TCURlcAcordaos
# 2024-09-25 18:52:29,213 - INFO - Aguarde... Realizando optimize
# 2024-09-25 18:52:32,482 - INFO - Optimize executado com sucesso.
# 2024-09-25 18:52:32,483 - INFO - Aguarde... Realizando vacuum
# 2024-09-25 18:53:05,375 - INFO - Vacuum executado com sucesso.

# %% [markdown]
# # Encerra sessão spark

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-09-25 18:53:05,836 - INFO - Sessão Spark finalizada.
