# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "silver"
datamart = "corporerm"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 08:55:49,484 - INFO - Iniciando Sessão Spark.

# %%
extrator.atualizar_tabela_delta('dim_pessoa')
# Out:
# 2024-10-21 08:55:53,599 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-21 08:55:53,602 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 08:55:53,602 - INFO - ['/home/jovyan/work/yaml/silver/corporerm/dim_pessoa.yaml']
# 2024-10-21 08:55:53,613 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-21 08:55:53,614 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 08:55:53,614 - INFO - ['/home/jovyan/work/yaml/silver/corporerm/dim_pessoa.yaml']
# 2024-10-21 08:55:53,620 - INFO - Aguarde... Criando View (bronze/corporerm/ppessoa)
# 2024-10-21 08:56:04,893 - INFO - View criada com sucesso
# 2024-10-21 08:56:04,894 - INFO - Aguarde... Criando View (bronze/corporerm/pcodsexo)
# 2024-10-21 08:56:05,334 - INFO - View criada com sucesso
# 2024-10-21 08:56:05,335 - INFO - Aguarde... Criando View (bronze/corporerm/pcodinstrucao)
# 2024-10-21 08:56:05,703 - INFO - View criada com sucesso
# 2024-10-21 08:56:05,704 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-21 08:56:05,720 - INFO -  select ppessoa.codigo as id_pessoa, ppessoa.nome as nm_pessoa, ppessoa.cep as nr_cep, ppessoa.cpf as nr_cpf, ppessoa.naturalidade as ds_naturalidade, pcodsexo.descricao as ds_sexo, ppessoa.email as ds_email, ppessoa.telefone1 as nr_telefone1, ppessoa.telefone2 as nr_telefone2, pcodinstrucao.descricao as ds_grau_instrucao from ppessoa left join pcodsexo on ppessoa.sexo = pcodsexo.codcliente left join pcodinstrucao on ppessoa.grauinstrucao = pcodinstrucao.codcliente
# 2024-10-21 08:56:05,941 - INFO - Query (Delta) executada com sucesso
# 2024-10-21 08:56:05,942 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-21 08:56:05,943 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-21 08:56:54,438 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:56:54,439 - INFO - s3a://silver/corporerm/dim_pessoa
# 2024-10-21 08:56:54,440 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:56:57,426 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:56:57,427 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:57:14,881 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:57:14,882 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator.parar_sessao()
# Out:
# 2024-10-21 08:57:15,063 - INFO - Sessão Spark finalizada.
