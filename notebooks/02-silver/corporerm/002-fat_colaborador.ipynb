# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "silver"
datamart = "corporerm"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 08:55:56,200 - INFO - Iniciando Sessão Spark.

# %%
extrator.atualizar_tabela_delta('fat_colaborador')
# Out:
# 2024-10-21 08:56:01,512 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-21 08:56:01,520 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 08:56:01,521 - INFO - ['/home/jovyan/work/yaml/silver/corporerm/fat_colaborador.yaml']
# 2024-10-21 08:56:01,535 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-21 08:56:01,536 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 08:56:01,537 - INFO - ['/home/jovyan/work/yaml/silver/corporerm/fat_colaborador.yaml']
# 2024-10-21 08:56:01,544 - INFO - Aguarde... Criando View (bronze/corporerm/ahorario)
# 2024-10-21 08:56:11,812 - INFO - View criada com sucesso
# 2024-10-21 08:56:11,813 - INFO - Aguarde... Criando View (bronze/corporerm/gcoligada)
# 2024-10-21 08:56:12,317 - INFO - View criada com sucesso
# 2024-10-21 08:56:12,318 - INFO - Aguarde... Criando View (bronze/corporerm/gfilial)
# 2024-10-21 08:56:12,757 - INFO - View criada com sucesso
# 2024-10-21 08:56:12,758 - INFO - Aguarde... Criando View (bronze/corporerm/pcodinstrucao)
# 2024-10-21 08:56:13,317 - INFO - View criada com sucesso
# 2024-10-21 08:56:13,318 - INFO - Aguarde... Criando View (bronze/corporerm/pcodsituacao)
# 2024-10-21 08:56:13,807 - INFO - View criada com sucesso
# 2024-10-21 08:56:13,811 - INFO - Aguarde... Criando View (bronze/corporerm/pfunc)
# 2024-10-21 08:56:14,591 - INFO - View criada com sucesso
# 2024-10-21 08:56:14,593 - INFO - Aguarde... Criando View (bronze/corporerm/pfuncao)
# 2024-10-21 08:56:15,159 - INFO - View criada com sucesso
# 2024-10-21 08:56:15,160 - INFO - Aguarde... Criando View (bronze/corporerm/psecao)
# 2024-10-21 08:56:15,756 - INFO - View criada com sucesso
# 2024-10-21 08:56:15,757 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-21 08:56:15,758 - INFO -  select pfunc.codpessoa as id_pessoa, concat(pfunc.codcoligada, '-', pfunc.chapa) as id_matricula, pcodsituacao.descricao as ds_situacao, pfuncao.nome as ds_cargo,gcoligada.codcoligada as cd_coligada, gfilial.nomefantasia as ds_unidade,ahorario.descricao as hr_trabalho, pfunc.dataadmissao as dt_admissao,pfunc.datademissao as dt_demissao, pfuncao.codigo as cd_cargo,pfuncao.descricao as ds_funcao, pfunc.jornadamensal / 60 / 5 as hr_semanais,pfunc.jornadamensal / 60 as hr_mensais from pfunc inner join gfilial on pfunc.codfilial = gfilial.codfilial and pfunc.codcoligada = gfilial.codcoligada inner join gcoligada on pfunc.codcoligada = gcoligada.codcoligada inner join psecao on pfunc.codsecao = psecao.codigo and pfunc.codcoligada = psecao.codcoligada inner join pfuncao on pfuncao.codigo = pfunc.codfuncao and pfuncao.codcoligada = pfunc.codcoligada left join ahorario on pfunc.codcoligada = ahorario.codcoligada and pfunc.codhorario = ahorario.codigo left join pcodsituacao on pfunc.codsituacao = pcodsituacao.codcliente
# 2024-10-21 08:56:16,358 - INFO - Query (Delta) executada com sucesso
# 2024-10-21 08:56:16,360 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-21 08:56:16,362 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-21 08:56:45,985 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:56:45,987 - INFO - s3a://silver/corporerm/fat_colaborador
# 2024-10-21 08:56:45,988 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:56:49,402 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:56:49,403 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:57:30,701 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:57:30,702 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator.parar_sessao()
# Out:
# 2024-10-21 08:57:30,870 - INFO - Sessão Spark finalizada.
