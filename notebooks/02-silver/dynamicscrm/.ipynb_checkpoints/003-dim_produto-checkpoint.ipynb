# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "silver"
datamart = "dynamicscrm"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-11-06 15:44:05,109 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Leitura da tabela

# %%
extrator_bronze.atualizar_tabela_delta('dim_produto')
# Out:
# 2024-11-06 15:44:08,467 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-11-06 15:44:08,468 - INFO - Arquivo yaml carregada com sucesso
# 2024-11-06 15:44:08,468 - INFO - ['/home/jovyan/work/yaml/silver/dynamicscrm/dim_produto.yaml']
# 2024-11-06 15:44:08,475 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-11-06 15:44:08,476 - INFO - Arquivo yaml carregada com sucesso
# 2024-11-06 15:44:08,476 - INFO - ['/home/jovyan/work/yaml/silver/dynamicscrm/dim_produto.yaml']
# 2024-11-06 15:44:08,480 - INFO - Aguarde... Criando View (bronze/dynamicscrm/products)
# 2024-11-06 15:44:15,392 - INFO - View criada com sucesso
# 2024-11-06 15:44:15,392 - INFO - Aguarde... Executando Query (Delta)
# 2024-11-06 15:44:15,393 - INFO - SELECT
#     p.productid as cod_produto,
#     p._findes_categoriaid_value_name AS dsc_classe_produto
# FROM products p
#
# 2024-11-06 15:44:15,482 - INFO - Query (Delta) executada com sucesso
# 2024-11-06 15:44:15,483 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-11-06 15:44:15,882 - INFO - Aguarde... Persistindo dados (upsert)
# 2024-11-06 15:44:15,883 - INFO - Aguarde... Persistindo dados (Merge)
# 2024-11-06 15:44:30,932 - INFO - Dados persistidos (Merge) com sucesso
# 2024-11-06 15:44:30,933 - INFO - s3a://silver/dynamicscrm/dim_produto
# 2024-11-06 15:44:30,934 - INFO - Aguarde... Realizando optimize
# 2024-11-06 15:44:33,059 - INFO - Optimize executado com sucesso.
# 2024-11-06 15:44:33,060 - INFO - Aguarde... Realizando vacuum
# 2024-11-06 15:44:51,887 - INFO - Vacuum executado com sucesso.
# 2024-11-06 15:44:51,889 - INFO - Tabela (Delta) atualizado com sucesso

# %% [markdown]
# # Encerra sessão spark

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-11-06 15:44:52,337 - INFO - Sessão Spark finalizada.
