# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "silver"
datamart = "dynamicscrm"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-11-06 15:48:34,709 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Leitura da tabela

# %%
extrator_bronze.atualizar_tabela_delta('dim_unidade_operacional')
# Out:
# 2024-11-06 15:48:37,005 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-11-06 15:48:37,007 - INFO - Arquivo yaml carregada com sucesso
# 2024-11-06 15:48:37,008 - INFO - ['/home/jovyan/work/yaml/silver/dynamicscrm/dim_unidade_operacional.yaml']
# 2024-11-06 15:48:37,014 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-11-06 15:48:37,015 - INFO - Arquivo yaml carregada com sucesso
# 2024-11-06 15:48:37,016 - INFO - ['/home/jovyan/work/yaml/silver/dynamicscrm/dim_unidade_operacional.yaml']
# 2024-11-06 15:48:37,019 - INFO - Aguarde... Criando View (bronze/dynamicscrm/quotedetails)
# 2024-11-06 15:48:42,678 - INFO - View criada com sucesso
# 2024-11-06 15:48:42,679 - INFO - Aguarde... Executando Query (Delta)
# 2024-11-06 15:48:42,679 - INFO - SELECT DISTINCT
#     quotedetails._findes_unidadeexecutoraid_value AS cod_unidade_operacional,
#     quotedetails._findes_unidadeexecutoraid_value_name AS dsc_unidade_operacional
# FROM quotedetails
# WHERE quotedetails._findes_unidadeexecutoraid_value != 'None'
#
# 2024-11-06 15:48:42,759 - INFO - Query (Delta) executada com sucesso
# 2024-11-06 15:48:42,759 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-11-06 15:48:42,761 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-11-06 15:48:50,854 - INFO - Dados persistidos com sucesso
# 2024-11-06 15:48:50,855 - INFO - s3a://silver/dynamicscrm/dim_unidade_operacional
# 2024-11-06 15:48:50,856 - INFO - Aguarde... Realizando optimize
# 2024-11-06 15:48:55,897 - INFO - Optimize executado com sucesso.
# 2024-11-06 15:48:55,899 - INFO - Aguarde... Realizando vacuum
# 2024-11-06 15:49:15,506 - INFO - Vacuum executado com sucesso.
# 2024-11-06 15:49:15,507 - INFO - Tabela (Delta) atualizado com sucesso

# %% [markdown]
# # Encerra sessão spark

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-11-06 15:49:15,911 - INFO - Sessão Spark finalizada.
