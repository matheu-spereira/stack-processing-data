# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "silver"
datamart = "dynamicscrm"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-11-06 15:11:21,097 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Leitura da tabela

# %%
extrator_bronze.atualizar_tabela_delta('fat_cotacao')
# Out:
# 2024-11-06 15:11:24,017 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-11-06 15:11:24,019 - INFO - Arquivo yaml carregada com sucesso
# 2024-11-06 15:11:24,020 - INFO - ['/home/jovyan/work/yaml/silver/dynamicscrm/fat_cotacao.yaml']
# 2024-11-06 15:11:24,029 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-11-06 15:11:24,030 - INFO - Arquivo yaml carregada com sucesso
# 2024-11-06 15:11:24,030 - INFO - ['/home/jovyan/work/yaml/silver/dynamicscrm/fat_cotacao.yaml']
# 2024-11-06 15:11:24,034 - INFO - Aguarde... Criando View (bronze/dynamicscrm/quotes)
# 2024-11-06 15:11:32,462 - INFO - View criada com sucesso
# 2024-11-06 15:11:32,463 - INFO - Aguarde... Executando Query (Delta)
# 2024-11-06 15:11:32,464 - INFO - SELECT
#     TO_DATE(closedon_name, 'dd/MM/yyyy') AS dt_finalizacao,
#     TO_DATE(SUBSTRING(createdon_name, 1, 10), 'dd/MM/yyyy') AS dt_inicio,
#     quoteid AS cod_proposta
# FROM quotes
#
# 2024-11-06 15:11:32,702 - INFO - Query (Delta) executada com sucesso
# 2024-11-06 15:11:32,703 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-11-06 15:11:32,704 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-11-06 15:11:44,666 - INFO - Dados persistidos com sucesso
# 2024-11-06 15:11:44,668 - INFO - s3a://silver/dynamicscrm/fat_cotacao
# 2024-11-06 15:11:44,668 - INFO - Aguarde... Realizando optimize
# 2024-11-06 15:11:47,060 - INFO - Optimize executado com sucesso.
# 2024-11-06 15:11:47,062 - INFO - Aguarde... Realizando vacuum
# 2024-11-06 15:12:12,948 - INFO - Vacuum executado com sucesso.
# 2024-11-06 15:12:12,948 - INFO - Tabela (Delta) atualizado com sucesso

# %% [markdown]
# # Encerra sessão spark

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-11-06 15:12:13,367 - INFO - Sessão Spark finalizada.
