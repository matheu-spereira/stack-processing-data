# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "silver"
datamart = "gd_alinhar"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-10-23 21:13:42,674 - INFO - Iniciando Sessão Spark.

# %%
extrator_bronze.atualizar_tabela_delta('dim_funcionarios')
# Out:
# 2024-10-23 21:13:44,698 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-23 21:13:44,700 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-23 21:13:44,701 - INFO - ['/home/jovyan/work/yaml/silver/gd_alinhar/dim_funcionarios.yaml']
# 2024-10-23 21:13:44,707 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-23 21:13:44,708 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-23 21:13:44,708 - INFO - ['/home/jovyan/work/yaml/silver/gd_alinhar/dim_funcionarios.yaml']
# 2024-10-23 21:13:44,711 - INFO - Aguarde... Criando View (bronze/pessoas/funcionarios)
# 2024-10-23 21:13:49,668 - INFO - View criada com sucesso
# 2024-10-23 21:13:49,669 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-23 21:13:49,669 - INFO - SELECT
#     funcionario_id,
#     nome,
#     data_nascimento,
#     cargo_id,
#     departamento_id
# FROM
#     funcionarios
#
# 2024-10-23 21:13:49,729 - INFO - Query (Delta) executada com sucesso
# 2024-10-23 21:13:49,729 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-23 21:13:49,730 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-23 21:14:05,207 - INFO - Dados persistidos com sucesso
# 2024-10-23 21:14:05,208 - INFO - s3a://silver/pessoas/dim_funcionarios
# 2024-10-23 21:14:05,208 - INFO - Aguarde... Realizando optimize
# 2024-10-23 21:14:12,368 - INFO - Optimize executado com sucesso.
# 2024-10-23 21:14:12,369 - INFO - Aguarde... Realizando vacuum
# 2024-10-23 21:14:34,000 - INFO - Vacuum executado com sucesso.
# 2024-10-23 21:14:34,001 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-10-23 21:14:34,619 - INFO - Sessão Spark finalizada.
