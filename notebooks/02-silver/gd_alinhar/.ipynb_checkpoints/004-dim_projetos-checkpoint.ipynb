# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "silver"
datamart = "gd_alinhar"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-10-24 06:45:11,889 - INFO - Iniciando Sessão Spark.

# %%
extrator_bronze.atualizar_tabela_delta('dim_projetos')
# Out:
# 2024-10-24 06:45:13,892 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-24 06:45:13,894 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-24 06:45:13,894 - INFO - ['/home/jovyan/work/yaml/silver/gd_alinhar/dim_projetos.yaml']
# 2024-10-24 06:45:13,900 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-24 06:45:13,900 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-24 06:45:13,901 - INFO - ['/home/jovyan/work/yaml/silver/gd_alinhar/dim_projetos.yaml']
# 2024-10-24 06:45:13,904 - INFO - Aguarde... Criando View (bronze/pessoas/projetos)
# 2024-10-24 06:45:20,097 - INFO - View criada com sucesso
# 2024-10-24 06:45:20,098 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-24 06:45:20,098 - INFO - SELECT
#     projeto_id,
#     nome,
#     data_inicio,
#     data_fim
# FROM
#     projetos;
#
# 2024-10-24 06:45:20,151 - INFO - Query (Delta) executada com sucesso
# 2024-10-24 06:45:20,152 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-24 06:45:20,152 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-24 06:45:32,485 - INFO - Dados persistidos com sucesso
# 2024-10-24 06:45:32,486 - INFO - s3a://silver/pessoas/dim_projetos
# 2024-10-24 06:45:32,486 - INFO - Aguarde... Realizando optimize
# 2024-10-24 06:45:35,765 - INFO - Optimize executado com sucesso.
# 2024-10-24 06:45:35,766 - INFO - Aguarde... Realizando vacuum
# 2024-10-24 06:45:52,433 - INFO - Vacuum executado com sucesso.
# 2024-10-24 06:45:52,434 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-10-24 06:45:52,812 - INFO - Sessão Spark finalizada.
