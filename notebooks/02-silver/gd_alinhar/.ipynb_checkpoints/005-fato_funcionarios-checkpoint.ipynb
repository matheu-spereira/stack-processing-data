# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "silver"
datamart = "gd_alinhar"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-10-23 22:48:31,042 - INFO - Iniciando Sessão Spark.

# %%
extrator_bronze.atualizar_tabela_delta('fato_funcionarios')
# Out:
# 2024-10-23 22:48:33,236 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-23 22:48:33,237 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-23 22:48:33,238 - INFO - ['/home/jovyan/work/yaml/silver/gd_alinhar/fato_funcionarios.yaml']
# 2024-10-23 22:48:33,245 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-23 22:48:33,246 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-23 22:48:33,247 - INFO - ['/home/jovyan/work/yaml/silver/gd_alinhar/fato_funcionarios.yaml']
# 2024-10-23 22:48:33,251 - INFO - Aguarde... Criando View (bronze/pessoas/funcionarios)
# 2024-10-23 22:48:38,517 - INFO - View criada com sucesso
# 2024-10-23 22:48:38,518 - INFO - Aguarde... Criando View (bronze/pessoas/funcionarios_projetos)
# 2024-10-23 22:48:38,749 - INFO - View criada com sucesso
# 2024-10-23 22:48:38,750 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-23 22:48:38,750 - INFO -
# SELECT
#     f.funcionario_id,
#     f.data_admissao,
#     f.salario,
#     fp.projeto_id
# FROM
#     funcionarios f
# LEFT JOIN
#     funcionarios_projetos fp ON f.funcionario_id = fp.funcionario_id;
#
# 2024-10-23 22:48:38,805 - INFO - Query (Delta) executada com sucesso
# 2024-10-23 22:48:38,806 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-23 22:48:38,806 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-23 22:48:51,134 - INFO - Dados persistidos com sucesso
# 2024-10-23 22:48:51,135 - INFO - s3a://silver/pessoas/fato_funcionarios
# 2024-10-23 22:48:51,136 - INFO - Aguarde... Realizando optimize
# 2024-10-23 22:48:52,787 - INFO - Optimize executado com sucesso.
# 2024-10-23 22:48:52,788 - INFO - Aguarde... Realizando vacuum
# 2024-10-23 22:49:06,326 - INFO - Vacuum executado com sucesso.
# 2024-10-23 22:49:06,326 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-10-23 22:49:06,625 - INFO - Sessão Spark finalizada.
