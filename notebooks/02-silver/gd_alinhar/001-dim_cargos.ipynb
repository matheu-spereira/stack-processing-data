# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "silver"
datamart = "gd_alinhar"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-10-23 23:43:26,394 - INFO - Iniciando Sessão Spark.

# %%
extrator_bronze.atualizar_tabela_delta('dim_cargos')
# Out:
# 2024-10-23 23:43:28,582 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-23 23:43:28,583 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-23 23:43:28,584 - INFO - ['/home/jovyan/work/yaml/silver/gd_alinhar/dim_cargos.yaml']
# 2024-10-23 23:43:28,590 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-23 23:43:28,591 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-23 23:43:28,591 - INFO - ['/home/jovyan/work/yaml/silver/gd_alinhar/dim_cargos.yaml']
# 2024-10-23 23:43:28,595 - INFO - Aguarde... Criando View (bronze/pessoas/cargos)
# 2024-10-23 23:43:33,880 - INFO - View criada com sucesso
# 2024-10-23 23:43:33,881 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-23 23:43:33,882 - INFO - SELECT
#     cargo_id,
#     descricao,
#     nivel
# FROM
#     cargos
#
# 2024-10-23 23:43:33,938 - INFO - Query (Delta) executada com sucesso
# 2024-10-23 23:43:33,939 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-23 23:43:33,939 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-23 23:43:45,425 - INFO - Dados persistidos com sucesso
# 2024-10-23 23:43:45,426 - INFO - s3a://silver/pessoas/dim_cargos
# 2024-10-23 23:43:45,426 - INFO - Aguarde... Realizando optimize
# 2024-10-23 23:43:47,954 - INFO - Optimize executado com sucesso.
# 2024-10-23 23:43:47,955 - INFO - Aguarde... Realizando vacuum
# 2024-10-23 23:44:02,175 - INFO - Vacuum executado com sucesso.
# 2024-10-23 23:44:02,175 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-10-23 23:44:02,468 - INFO - Sessão Spark finalizada.
