# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "silver"
datamart = "mtecbo"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-10-25 10:29:23,700 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Gravação no datalake

# %%
extrator_bronze.atualizar_tabela_delta('dim_cbo_familia')
# Out:
# 2024-10-25 10:29:25,660 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-25 10:29:25,661 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-25 10:29:25,663 - INFO - ['/home/jovyan/work/yaml/silver/mtecbo/dim_cbo_familia.yaml']
# 2024-10-25 10:29:25,668 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-25 10:29:25,669 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-25 10:29:25,670 - INFO - ['/home/jovyan/work/yaml/silver/mtecbo/dim_cbo_familia.yaml']
# 2024-10-25 10:29:25,674 - INFO - Aguarde... Criando View (bronze/mte/cbofamilia)
# 2024-10-25 10:29:30,488 - INFO - View criada com sucesso
# 2024-10-25 10:29:30,489 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-25 10:29:30,490 - INFO - SELECT
#     *
# FROM compliance_cbo_familia
#
# 2024-10-25 10:29:30,549 - INFO - Query (Delta) executada com sucesso
# 2024-10-25 10:29:30,550 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-25 10:29:30,551 - INFO - Aguarde... Persistindo dados (upsert)
# 2024-10-25 10:29:30,575 - ERROR - Erro ao persistir dados (upsert)
# 2024-10-25 10:29:30,585 - ERROR - Unknown save mode: upsert. Accepted save modes are 'overwrite', 'append', 'ignore', 'error', 'errorifexists', 'default'.
# 2024-10-25 10:29:31,029 - INFO - Sessão Spark finalizada.
# 2024-10-25 10:29:31,030 - ERROR - Erro ao atualizar tabela (Delta)
# 2024-10-25 10:29:31,037 - ERROR - Unknown save mode: upsert. Accepted save modes are 'overwrite', 'append', 'ignore', 'error', 'errorifexists', 'default'.
# 2024-10-25 10:29:31,041 - INFO - Sessão Spark finalizada.
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 extrator_bronze.atualizar_tabela_delta('dim_cbo_familia')
#
# File ~/work/utils/AlinharETL.py:778, in AlinharETL.atualizar_tabela_delta(self, arquivo)
#     776     extraiu_dados = True
#     777     df_dados = self.prepara_tabela_delta(arquivo)
# --> 778     self.salvar_delta_merge_teste(df_dados,'') ############### salvar_delta
#     780 if extraiu_dados:
#     781     self.logger.info("Tabela (Delta) atualizado com sucesso")
#
# File ~/work/utils/AlinharETL.py:912, in AlinharETL.salvar_delta_merge_teste(self, df, mode)
#     909 mode = self.leitor_yaml.busca_chave_sessao_valor("sink","mode")
#     911 self.logger.info(f"Aguarde... Persistindo dados ({mode})")
# --> 912 df.write.format("delta").mode(mode).option("mergeSchema", "true").save(self.caminho_tabela_delta)
#     913 self.logger.info("Dados persistidos com sucesso")
#     914 self.logger.info(f"{self.caminho_tabela_delta}")
#
# File /usr/local/spark/python/pyspark/sql/readwriter.py:1029, in DataFrameWriter.mode(self, saveMode)
#    1026 # At the JVM side, the default value of mode is already set to "error".
#    1027 # So, if the given saveMode is None, we will not call JVM-side's mode method.
#    1028 if saveMode is not None:
# -> 1029     self._jwrite = self._jwrite.mode(saveMode)
#    1030 return self
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /usr/local/spark/python/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# IllegalArgumentException: Unknown save mode: upsert. Accepted save modes are 'overwrite', 'append', 'ignore', 'error', 'errorifexists', 'default'.

# %% [markdown]
# # Encerra sessão spark

# %%
extrator_bronze.parar_sessao()
