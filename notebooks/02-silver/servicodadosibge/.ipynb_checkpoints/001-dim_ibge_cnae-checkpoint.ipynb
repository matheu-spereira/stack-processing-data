# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "silver"
datamart = "servicodadosibge"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-10-15 13:33:40,661 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Gravação no datalake

# %%
extrator_bronze.atualizar_tabela_delta('dim_ibge_cnae')
# Out:
# 2024-10-15 13:33:45,215 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-15 13:33:45,217 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-15 13:33:45,218 - INFO - ['/home/jovyan/work/yaml/silver/servicodadosibge/dim_ibge_cnae.yaml']
# 2024-10-15 13:33:45,234 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-15 13:33:45,235 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-15 13:33:45,236 - INFO - ['/home/jovyan/work/yaml/silver/servicodadosibge/dim_ibge_cnae.yaml']
# 2024-10-15 13:33:45,244 - INFO - Aguarde... Criando View (bronze/servicodadosibge/cnaeclasses)
# 2024-10-15 13:34:03,622 - INFO - View criada com sucesso
# 2024-10-15 13:34:03,624 - INFO - Aguarde... Criando View (bronze/servicodadosibge/cnaedivisoes)
# 2024-10-15 13:34:04,450 - INFO - View criada com sucesso
# 2024-10-15 13:34:04,451 - INFO - Aguarde... Criando View (bronze/servicodadosibge/cnaegrupos)
# 2024-10-15 13:34:05,145 - INFO - View criada com sucesso
# 2024-10-15 13:34:05,146 - INFO - Aguarde... Criando View (bronze/servicodadosibge/cnaesecoes)
# 2024-10-15 13:34:05,654 - INFO - View criada com sucesso
# 2024-10-15 13:34:05,655 - INFO - Aguarde... Criando View (bronze/servicodadosibge/cnaesubclasses)
# 2024-10-15 13:34:06,005 - INFO - View criada com sucesso
# 2024-10-15 13:34:06,006 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-15 13:34:06,006 - INFO - SELECT *
# FROM (
#     SELECT DISTINCT
#         id AS sk_cnae,
#         INITCAP(descricao) AS dsc_classe,
#         grupo.descricao AS dsc_grupo,
#         grupo.divisao.descricao AS dsc_divisao,
#         grupo.divisao.secao.descricao AS dsc_secao,
#         '' AS dsc_subclasse,
#         'CLASSE' AS dsc_nivel,
#         '' AS sk_cnae_longo,
#         '' AS dsc_contribuinte,
#         '' AS dsc_industria
#     FROM
#         compliance_cnae_classes
#
#     UNION ALL
#
#     SELECT DISTINCT
#         id AS sk_cnae,
#         '' AS dsc_classe,
#         '' AS dsc_grupo,
#         descricao AS dsc_divisao,
#         secao.descricao AS dsc_secao,
#         '' AS dsc_subclasse,
#         'DIVISÃO' AS dsc_nivel,
#         '' AS sk_cnae_longo,
#         '' AS dsc_contribuinte,
#         '' AS dsc_industria
#     FROM
#         compliance_cnae_divisoes
#
#     UNION ALL
#
#     SELECT DISTINCT
#         id AS sk_cnae,
#         '' AS dsc_classe,
#         descricao AS dsc_grupo,
#         divisao.descricao AS dsc_divisao,
#         divisao.secao.descricao AS dsc_secao,
#         '' AS dsc_subclasse,
#         'GRUPO' AS dsc_nivel,
#         '' AS sk_cnae_longo,
#         '' AS dsc_contribuinte,
#         '' AS dsc_industria
#     FROM
#         compliance_cnae_grupos
#
#     UNION ALL
#
#     SELECT DISTINCT
#         id AS sk_cnae,
#         '' AS dsc_classe,
#         '' AS dsc_grupo,
#         '' AS dsc_divisao,
#         descricao AS dsc_secao,
#         '' AS dsc_subclasse,
#         'SECAO' AS dsc_nivel,
#         '' AS sk_cnae_longo,
#         '' AS dsc_contribuinte,
#         '' AS dsc_industria
#     FROM
#         compliance_cnae_secoes
#
#     UNION ALL
#
#     SELECT DISTINCT
#         id AS sk_cnae,
#         INITCAP(classe.descricao) AS dsc_classe,
#         classe.grupo.descricao AS dsc_grupo,
#         classe.grupo.divisao.descricao AS dsc_divisao,
#         classe.grupo.divisao.secao.descricao AS dsc_secao,
#         INITCAP(descricao) AS dsc_subclasse,
#         'SUBCLASSE' AS dsc_nivel,
#         '' AS sk_cnae_longo,
#         '' AS dsc_contribuinte,
#         '' AS dsc_industria
#     FROM
#         compliance_cnae_subclasses
# ) AS combined_results
# WHERE sk_cnae IS NOT NULL;
#
# 2024-10-15 13:34:06,262 - INFO - Query (Delta) executada com sucesso
# 2024-10-15 13:34:06,263 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-15 13:34:06,264 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-15 13:34:29,088 - INFO - Dados persistidos com sucesso
# 2024-10-15 13:34:29,089 - INFO - s3a://silver/servicodadosibge/dim_ibge_cnae
# 2024-10-15 13:34:29,090 - INFO - Aguarde... Realizando optimize
# 2024-10-15 13:34:32,128 - INFO - Optimize executado com sucesso.
# 2024-10-15 13:34:32,129 - INFO - Aguarde... Realizando vacuum
# 2024-10-15 13:34:50,328 - INFO - Vacuum executado com sucesso.
# 2024-10-15 13:34:50,329 - INFO - Tabela (Delta) atualizado com sucesso

# %% [markdown]
# # Encerra sessão spark

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-10-15 13:34:50,595 - INFO - Sessão Spark finalizada.
