# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "silver"
datamart = "sgt"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-10-30 15:38:33,251 - INFO - Iniciando Sessão Spark.

# %%
extrator_bronze.atualizar_tabela_delta('dim_clientes')
# Out:
# 2024-10-30 15:38:36,424 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-30 15:38:36,426 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-30 15:38:36,426 - INFO - ['/home/jovyan/work/yaml/silver/sgt/dim_clientes.yaml']
# 2024-10-30 15:38:36,434 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-30 15:38:36,435 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-30 15:38:36,436 - INFO - ['/home/jovyan/work/yaml/silver/sgt/dim_clientes.yaml']
# 2024-10-30 15:38:36,439 - INFO - Aguarde... Criando View (bronze/sgt/clientes)
# 2024-10-30 15:38:42,837 - INFO - View criada com sucesso
# 2024-10-30 15:38:42,838 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-30 15:38:42,838 - INFO - SELECT distinct
#     cnae AS nr_cenae,
#     cpfCnpj AS nr_cpf_cnpj,
#     nome AS dsc_nome
# FROM
#     clientessgt
#
# 2024-10-30 15:38:42,899 - INFO - Query (Delta) executada com sucesso
# 2024-10-30 15:38:42,899 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-30 15:38:42,900 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-30 15:38:53,484 - INFO - Dados persistidos com sucesso
# 2024-10-30 15:38:53,485 - INFO - s3a://silver/sgt/dim_clientes
# 2024-10-30 15:38:53,485 - INFO - Aguarde... Realizando optimize
# 2024-10-30 15:38:57,307 - INFO - Optimize executado com sucesso.
# 2024-10-30 15:38:57,308 - INFO - Aguarde... Realizando vacuum
# 2024-10-30 15:39:14,608 - INFO - Vacuum executado com sucesso.
# 2024-10-30 15:39:14,609 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-10-30 15:39:14,786 - INFO - Sessão Spark finalizada.
