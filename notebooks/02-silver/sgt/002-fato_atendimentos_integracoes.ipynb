# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "silver"
datamart = "sgt"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-10-15 15:17:08,212 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Leitura da tabela

# %%
extrator_bronze.atualizar_tabela_delta('fato_atendimentos_integracoes')
# Out:
# 2024-10-15 15:17:12,715 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-15 15:17:12,717 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-15 15:17:12,718 - INFO - ['/home/jovyan/work/yaml/silver/sgt/fato_atendimentos_integracoes.yaml']
# 2024-10-15 15:17:12,731 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-15 15:17:12,732 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-15 15:17:12,733 - INFO - ['/home/jovyan/work/yaml/silver/sgt/fato_atendimentos_integracoes.yaml']
# 2024-10-15 15:17:12,739 - INFO - Aguarde... Criando View (bronze/sgt/atendimentosintegracoes)
# 2024-10-15 15:17:22,984 - INFO - View criada com sucesso
# 2024-10-15 15:17:22,985 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-15 15:17:22,986 - INFO - SELECT
#     idAtendimento as id_atendimento,
#     dataEmissao as dt_emissao,
#     dataNegociacao as dt_negociacao,
#     dataAceitacao as dt_aceitacao,
#     dataExecucao as dt_execucao,
#     dataRecusa as dt_recusa,
#     dataConclusao as dt_conclusao,
#     dataCancelamento as dt_cancelamento
# FROM
#     atendimentosintegracoessgt
# WHERE idAtendimento IS NOT NULL;
#
# 2024-10-15 15:17:23,115 - INFO - Query (Delta) executada com sucesso
# 2024-10-15 15:17:23,117 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-15 15:17:23,117 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-15 15:17:38,207 - INFO - Dados persistidos com sucesso
# 2024-10-15 15:17:38,209 - INFO - s3a://silver/sgt/fato_atendimentos_integracoes
# 2024-10-15 15:17:38,209 - INFO - Aguarde... Realizando optimize
# 2024-10-15 15:17:50,396 - INFO - Optimize executado com sucesso.
# 2024-10-15 15:17:50,398 - INFO - Aguarde... Realizando vacuum
# 2024-10-15 15:18:14,440 - INFO - Vacuum executado com sucesso.
# 2024-10-15 15:18:14,442 - INFO - Tabela (Delta) atualizado com sucesso

# %% [markdown]
# # Encerra sessão spark

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-10-15 15:18:14,586 - INFO - Sessão Spark finalizada.
