# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "silver"
datamart = "sgt"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-10-15 15:19:35,299 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Leitura da tabela

# %%
extrator_bronze.atualizar_tabela_delta('fato_producao_hh')
# Out:
# 2024-10-15 15:19:40,147 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-15 15:19:40,149 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-15 15:19:40,150 - INFO - ['/home/jovyan/work/yaml/silver/sgt/fato_producao_hh.yaml']
# 2024-10-15 15:19:40,163 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-15 15:19:40,164 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-15 15:19:40,165 - INFO - ['/home/jovyan/work/yaml/silver/sgt/fato_producao_hh.yaml']
# 2024-10-15 15:19:40,171 - INFO - Aguarde... Criando View (bronze/sgt/producaohh)
# 2024-10-15 15:19:52,099 - INFO - View criada com sucesso
# 2024-10-15 15:19:52,100 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-15 15:19:52,101 - INFO - SELECT
#      TO_DATE(CONCAT_WS('-', ano, mes, dia)) AS id_data_calendario,
#      CRProdutoRegional AS nr_cr_produto_regional,
#      ano AS ano,
#      cpfCnpjCliente AS nr_cpf_cnpj_cliente,
#      cpfColaborador AS nr_cpf_colaborador,
#      descricaoProdutoCategoria AS dsc_produto_categoria,
#      descricaoProdutoLinha AS dsc_produto_linha,
#      descricaoProdutoNacional AS dsc_produto_nacional,
#      descricaoProdutoRegional AS dsc_produto_regional,
#      dia AS dia,
#      emailColaborador AS dsc_email_colaborador,
#      id AS id,
#      idAtendimento AS id_atendimento,
#      CASE
#          WHEN idPorteCliente LIKE '%@nil%' THEN regexp_extract(idPorteCliente, '@nil":"([^"]+)', 1)
#          ELSE idPorteCliente
#      END AS id_porte_cliente,
#      isCompartilhado AS dsc_compartilhado,
#      isEmRede AS dsc_em_rede,
#      mes AS mes,
#      nomeCliente AS nm_cliente,
#      CASE
#          WHEN nomeColaborador LIKE '%@nil%' THEN regexp_extract(nomeColaborador, '@nil":"([^"]+)', 1)
#          ELSE nomeColaborador
#      END AS nm_colaborador,
#      CASE
#          WHEN numeroAtendimento LIKE '%@nil%' THEN regexp_extract(numeroAtendimento, '@nil":"([^"]+)', 1)
#          ELSE numeroAtendimento
#      END AS nr_atendimento,
#      CASE
#          WHEN porteCliente LIKE '%@nil%' THEN regexp_extract(porteCliente, '@nil":"([^"]+)', 1)
#          ELSE porteCliente
#      END AS dsc_porte_cliente,
#      producaoRealizada AS vlr_producao_realizada,
#      tituloAtendimento AS dsc_titulo_atendimento,
#      unidadeOperacional AS dsc_unidade_operacional
#  FROM
#      producaohh
#
# 2024-10-15 15:19:52,336 - INFO - Query (Delta) executada com sucesso
# 2024-10-15 15:19:52,337 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-15 15:19:52,338 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-15 15:20:12,029 - INFO - Dados persistidos com sucesso
# 2024-10-15 15:20:12,030 - INFO - s3a://silver/sgt/fato_producao_hh
# 2024-10-15 15:20:12,031 - INFO - Aguarde... Realizando optimize
# 2024-10-15 15:20:28,435 - INFO - Optimize executado com sucesso.
# 2024-10-15 15:20:28,437 - INFO - Aguarde... Realizando vacuum
# 2024-10-15 15:20:52,376 - INFO - Vacuum executado com sucesso.
# 2024-10-15 15:20:52,378 - INFO - Tabela (Delta) atualizado com sucesso

# %% [markdown]
# # Encerra sessão spark

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-10-15 15:20:52,544 - INFO - Sessão Spark finalizada.
