# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "silver"
datamart = "sgt"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-10-15 15:21:05,256 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Leitura da tabela

# %%
extrator_bronze.atualizar_tabela_delta('fato_receitas')
# Out:
# 2024-10-15 15:21:10,088 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-15 15:21:10,090 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-15 15:21:10,090 - INFO - ['/home/jovyan/work/yaml/silver/sgt/fato_receitas.yaml']
# 2024-10-15 15:21:10,105 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-15 15:21:10,106 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-15 15:21:10,107 - INFO - ['/home/jovyan/work/yaml/silver/sgt/fato_receitas.yaml']
# 2024-10-15 15:21:10,113 - INFO - Aguarde... Criando View (bronze/sgt/receitas)
# 2024-10-15 15:21:21,739 - INFO - View criada com sucesso
# 2024-10-15 15:21:21,740 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-15 15:21:21,741 - INFO - SELECT
#      TO_DATE(CONCAT_WS('-', ano, mes, dia)) AS id_data_calendario,
#      CRProdutoRegional AS cr_produto_regional,
#      ano AS ano,
#      cnpjFontePagadora AS nr_cnpj_fonte_pagadora,
#      cpfCnpjCliente AS nr_cpf_cnpj_colaborador,
#      descricaoProdutoCategoria AS dsc_produto_categoria,
#      descricaoProdutoLinha AS dsc_produto_linha,
#      descricaoProdutoNacional AS dsc_produto_nacional,
#      descricaoProdutoRegional AS dsc_produto_regional,
#      dia AS dia,
#      id AS id,
#      idAtendimento AS id_atendimento,
#      CASE
#          WHEN idPorteCliente LIKE '%@nil%' THEN regexp_extract(idPorteCliente, '@nil":"([^"]+)', 1)
#          ELSE idPorteCliente
#      END AS id_porte_cliente,
#      isCompartilhado AS dsc_compartilhado,
#      isEmRede AS dsc_em_rede,
#      mes AS mes,
#      nomeCliente AS nm_cliente,
#      CASE
#          WHEN nomeFontePagadora LIKE '%@nil%' THEN regexp_extract(nomeFontePagadora, '@nil":"([^"]+)', 1)
#          ELSE nomeFontePagadora
#      END AS nm_fonte_pagadora,
#      CASE
#          WHEN numeroAtendimento LIKE '%@nil%' THEN regexp_extract(numeroAtendimento, '@nil":"([^"]+)', 1)
#          ELSE numeroAtendimento
#      END AS nr_atendimento,
#      CASE
#          WHEN porteCliente LIKE '%@nil%' THEN regexp_extract(porteCliente, '@nil":"([^"]+)', 1)
#          ELSE porteCliente
#      END AS dsc_porte_cliente,
#      tituloAtendimento AS dsc_titulo_atendimento,
#      unidadeOperacional AS dsc_unidade_operacional,
#      CASE
#          WHEN valorReceitaRealizada LIKE '%@nil%' THEN regexp_extract(valorReceitaRealizada, '@nil":"([^"]+)', 1)
#          ELSE valorReceitaRealizada
#      END AS vlr_receita_realizada
#  FROM
#      receitas_sgt
#
# 2024-10-15 15:21:21,965 - INFO - Query (Delta) executada com sucesso
# 2024-10-15 15:21:21,966 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-15 15:21:21,967 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-15 15:21:40,450 - INFO - Dados persistidos com sucesso
# 2024-10-15 15:21:40,451 - INFO - s3a://silver/sgt/fato_receitas
# 2024-10-15 15:21:40,452 - INFO - Aguarde... Realizando optimize
# 2024-10-15 15:21:58,620 - INFO - Optimize executado com sucesso.
# 2024-10-15 15:21:58,622 - INFO - Aguarde... Realizando vacuum
# 2024-10-15 15:22:21,278 - INFO - Vacuum executado com sucesso.
# 2024-10-15 15:22:21,280 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-10-15 15:22:21,451 - INFO - Sessão Spark finalizada.
