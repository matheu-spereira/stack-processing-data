# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "silver"
datamart = "sgt"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-10-15 15:23:38,036 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Leitura da tabela

# %%
extrator_bronze.atualizar_tabela_delta('fato_relatorios')
# Out:
# 2024-10-15 15:23:42,714 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-15 15:23:42,716 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-15 15:23:42,717 - INFO - ['/home/jovyan/work/yaml/silver/sgt/fato_relatorios.yaml']
# 2024-10-15 15:23:42,731 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-15 15:23:42,732 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-15 15:23:42,733 - INFO - ['/home/jovyan/work/yaml/silver/sgt/fato_relatorios.yaml']
# 2024-10-15 15:23:42,739 - INFO - Aguarde... Criando View (bronze/sgt/relatorios)
# 2024-10-15 15:23:53,872 - INFO - View criada com sucesso
# 2024-10-15 15:23:53,873 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-15 15:23:53,874 - INFO - SELECT
#     distinct
#     TO_DATE(CONCAT_WS('-', ano, mes, dia)) AS id_data_calendario,
#     CRProdutoRegional AS cr_produto_regional,
#     ano AS ano,
#     cpfCnpjCliente AS nr_cnpj_cliente,
#     cpfColaborador AS nr_cpf_colaborador,
#     descricaoProdutoCategoria AS dsc_produto_categoria,
#     descricaoProdutoLinha AS dsc_produto_linha,
#     descricaoProdutoNacional AS dsc_produto_nacional,
#     descricaoProdutoRegional AS dsc_produto_regional,
#     dia AS dia,
#     emailColaborador AS nm_email_colaborador,
#     ensaiosRealizados AS nr_ensaios_realizados,
#     id AS id,
#     idAtendimento AS id_atendimento,
#     CASE
#         WHEN idPorteCliente LIKE '%@nil%' THEN regexp_extract(idPorteCliente, '@nil":"([^"]+)', 1)
#         ELSE idPorteCliente
#     END AS id_porte_cliente,
#     isCompartilhado AS dsc_compartilhamento,
#     isEmRede AS dsc_em_rede,
#     mes AS mes,
#     nomeCliente AS nm_cliente,
#     CASE
#         WHEN nomeColaborador LIKE '%@nil%' THEN regexp_extract(nomeColaborador, '@nil":"([^"]+)', 1)
#         ELSE nomeColaborador
#     END AS nm_colaborador,
#     CASE
#         WHEN numeroAtendimento LIKE '%@nil%' THEN regexp_extract(numeroAtendimento, '@nil":"([^"]+)', 1)
#         ELSE numeroAtendimento
#     END AS nr_atendimento,
#     CASE
#         WHEN porteCliente LIKE '%@nil%' THEN regexp_extract(porteCliente, '@nil":"([^"]+)', 1)
#         ELSE porteCliente
#     END AS nm_porte_cliente,
#     relatoriosRealizados AS nr_relatorios_realizados,
#     tituloAtendimento AS dsc_titulo_atendimento,
#     unidadeOperacional AS nm_unidade_operacional
# FROM
#     relatorios_sgt
#
# 2024-10-15 15:23:54,083 - INFO - Query (Delta) executada com sucesso
# 2024-10-15 15:23:54,084 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-15 15:23:54,085 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-15 15:24:12,872 - INFO - Dados persistidos com sucesso
# 2024-10-15 15:24:12,873 - INFO - s3a://silver/sgt/fato_relatorios
# 2024-10-15 15:24:12,874 - INFO - Aguarde... Realizando optimize
# 2024-10-15 15:24:23,505 - INFO - Optimize executado com sucesso.
# 2024-10-15 15:24:23,506 - INFO - Aguarde... Realizando vacuum
# 2024-10-15 15:24:47,935 - INFO - Vacuum executado com sucesso.
# 2024-10-15 15:24:47,936 - INFO - Tabela (Delta) atualizado com sucesso

# %% [markdown]
# # Encerra sessão spark

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-10-15 15:24:48,093 - INFO - Sessão Spark finalizada.
