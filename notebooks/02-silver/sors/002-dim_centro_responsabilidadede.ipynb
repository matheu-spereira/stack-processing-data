# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "silver"
datamart = "sors"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 09:24:30,423 - INFO - Iniciando Sessão Spark.

# %%
extrator.atualizar_tabela_delta('dim_centro_responsabilidade')
# Out:
# 2024-10-21 09:24:34,837 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-21 09:24:34,839 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:24:34,840 - INFO - ['/home/jovyan/work/yaml/silver/sors/dim_centro_responsabilidade.yaml']
# 2024-10-21 09:24:34,850 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-21 09:24:34,851 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:24:34,852 - INFO - ['/home/jovyan/work/yaml/silver/sors/dim_centro_responsabilidade.yaml']
# 2024-10-21 09:24:34,857 - INFO - Aguarde... Criando View (bronze/sors/itemcontabil)
# 2024-10-21 09:24:45,254 - INFO - View criada com sucesso
# 2024-10-21 09:24:45,255 - INFO - Aguarde... Criando View (bronze/sors/cr)
# 2024-10-21 09:24:45,709 - INFO - View criada com sucesso
# 2024-10-21 09:24:45,710 - INFO - Aguarde... Criando View (bronze/sors/centrocusto)
# 2024-10-21 09:24:46,120 - INFO - View criada com sucesso
# 2024-10-21 09:24:46,121 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-21 09:24:46,121 - INFO - select
# centrocusto.idcentrocusto,
# cr.codigoitemcontabil,
# itemcontabil.iditemcontabil,
# itemcontabil.nmitemcontabil,
# itemcontabil.iditemcontabilsuperior,
# itemcontabil.codigotipoitemcontabil
# from itemcontabil
# inner join cr on cr.codigoitemcontabil = itemcontabil.codigo and cr.dataexclusao is null
# inner join centrocusto on centrocusto.Codigo = cr.CodigoCentroCusto
#
# 2024-10-21 09:24:46,277 - INFO - Query (Delta) executada com sucesso
# 2024-10-21 09:24:46,278 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-21 09:24:46,279 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-21 09:25:11,571 - INFO - Dados persistidos com sucesso
# 2024-10-21 09:25:11,572 - INFO - s3a://silver/sors/dim_centro_responsabilidade
# 2024-10-21 09:25:11,572 - INFO - Aguarde... Realizando optimize
# 2024-10-21 09:25:16,083 - INFO - Optimize executado com sucesso.
# 2024-10-21 09:25:16,084 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 09:25:35,192 - INFO - Vacuum executado com sucesso.
# 2024-10-21 09:25:35,193 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator.parar_sessao()
# Out:
# 2024-10-21 09:25:35,683 - INFO - Sessão Spark finalizada.
