# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "silver"
datamart = "sors"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 09:25:55,270 - INFO - Iniciando Sessão Spark.

# %%
extrator.atualizar_tabela_delta('dim_conta_contabil')
# Out:
# 2024-10-21 09:25:59,652 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-21 09:25:59,654 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:25:59,654 - INFO - ['/home/jovyan/work/yaml/silver/sors/dim_conta_contabil.yaml']
# 2024-10-21 09:25:59,663 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-21 09:25:59,663 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:25:59,664 - INFO - ['/home/jovyan/work/yaml/silver/sors/dim_conta_contabil.yaml']
# 2024-10-21 09:25:59,668 - INFO - Aguarde... Criando View (bronze/sors/contacontabil)
# 2024-10-21 09:26:09,092 - INFO - View criada com sucesso
# 2024-10-21 09:26:09,093 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-21 09:26:09,093 - INFO - select distinct idcontacontabil,nmcontacontabil,idcontacontabilsuperior from contacontabil
# 2024-10-21 09:26:09,198 - INFO - Query (Delta) executada com sucesso
# 2024-10-21 09:26:09,199 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-21 09:26:09,200 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-21 09:26:21,572 - INFO - Dados persistidos com sucesso
# 2024-10-21 09:26:21,573 - INFO - s3a://silver/sors/dim_conta_contabil
# 2024-10-21 09:26:21,574 - INFO - Aguarde... Realizando optimize
# 2024-10-21 09:26:34,924 - INFO - Optimize executado com sucesso.
# 2024-10-21 09:26:34,925 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 09:26:54,108 - INFO - Vacuum executado com sucesso.
# 2024-10-21 09:26:54,109 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator.parar_sessao()
# Out:
# 2024-10-21 09:26:54,506 - INFO - Sessão Spark finalizada.
