# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "silver"
datamart = "sors"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 09:28:35,315 - INFO - Iniciando Sessão Spark.

# %%
extrator.atualizar_tabela_delta('dim_entidade')
# Out:
# 2024-10-21 09:28:42,369 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-21 09:28:42,370 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:28:42,371 - INFO - ['/home/jovyan/work/yaml/silver/sors/dim_entidade.yaml']
# 2024-10-21 09:28:42,381 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-21 09:28:42,382 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:28:42,382 - INFO - ['/home/jovyan/work/yaml/silver/sors/dim_entidade.yaml']
# 2024-10-21 09:28:42,387 - INFO - Aguarde... Criando View (bronze/sors/entidade)
# 2024-10-21 09:28:51,700 - INFO - View criada com sucesso
# 2024-10-21 09:28:51,702 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-21 09:28:51,702 - INFO - select codigo,nome,sigla,cnpj,codigoreservado,ativa from entidade
# 2024-10-21 09:28:51,799 - INFO - Query (Delta) executada com sucesso
# 2024-10-21 09:28:51,800 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-21 09:28:51,800 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-21 09:29:06,380 - INFO - Dados persistidos com sucesso
# 2024-10-21 09:29:06,381 - INFO - s3a://silver/sors/dim_entidade
# 2024-10-21 09:29:06,382 - INFO - Aguarde... Realizando optimize
# 2024-10-21 09:29:18,683 - INFO - Optimize executado com sucesso.
# 2024-10-21 09:29:18,684 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 09:29:38,375 - INFO - Vacuum executado com sucesso.
# 2024-10-21 09:29:38,376 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator.parar_sessao()
# Out:
# 2024-10-21 09:29:38,699 - INFO - Sessão Spark finalizada.
