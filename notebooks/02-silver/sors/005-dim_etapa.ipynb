# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "silver"
datamart = "sors"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 09:30:20,375 - INFO - Iniciando Sessão Spark.

# %%
extrator.atualizar_tabela_delta('dim_etapa')
# Out:
# 2024-10-21 09:30:24,898 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-21 09:30:24,900 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:30:24,901 - INFO - ['/home/jovyan/work/yaml/silver/sors/dim_etapa.yaml']
# 2024-10-21 09:30:24,912 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-21 09:30:24,913 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:30:24,914 - INFO - ['/home/jovyan/work/yaml/silver/sors/dim_etapa.yaml']
# 2024-10-21 09:30:24,920 - INFO - Aguarde... Criando View (bronze/sors/entidadeexercicioetapa)
# 2024-10-21 09:30:34,456 - INFO - View criada com sucesso
# 2024-10-21 09:30:34,458 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-21 09:30:34,458 - INFO - select distinct codigoetapa,nomeetapa from entidadeexercicioetapa
# 2024-10-21 09:30:34,562 - INFO - Query (Delta) executada com sucesso
# 2024-10-21 09:30:34,563 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-21 09:30:34,563 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-21 09:30:46,349 - INFO - Dados persistidos com sucesso
# 2024-10-21 09:30:46,350 - INFO - s3a://silver/sors/dim_etapa
# 2024-10-21 09:30:46,351 - INFO - Aguarde... Realizando optimize
# 2024-10-21 09:30:59,419 - INFO - Optimize executado com sucesso.
# 2024-10-21 09:30:59,422 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 09:31:18,789 - INFO - Vacuum executado com sucesso.
# 2024-10-21 09:31:18,791 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator.parar_sessao()
# Out:
# 2024-10-21 09:31:19,256 - INFO - Sessão Spark finalizada.
