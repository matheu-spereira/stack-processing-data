# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "silver"
datamart = "sors"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 09:32:07,659 - INFO - Iniciando Sessão Spark.

# %%
extrator.atualizar_tabela_delta('dim_status')
# Out:
# 2024-10-21 09:32:15,226 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-21 09:32:15,228 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:32:15,228 - INFO - ['/home/jovyan/work/yaml/silver/sors/dim_status.yaml']
# 2024-10-21 09:32:15,237 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-21 09:32:15,237 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:32:15,238 - INFO - ['/home/jovyan/work/yaml/silver/sors/dim_status.yaml']
# 2024-10-21 09:32:15,242 - INFO - Aguarde... Criando View (bronze/sors/exerciciostatus)
# 2024-10-21 09:32:24,985 - INFO - View criada com sucesso
# 2024-10-21 09:32:24,986 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-21 09:32:24,987 - INFO - select codigo,nome from exerciciostatus
# 2024-10-21 09:32:25,075 - INFO - Query (Delta) executada com sucesso
# 2024-10-21 09:32:25,076 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-21 09:32:25,076 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-21 09:32:39,217 - INFO - Dados persistidos com sucesso
# 2024-10-21 09:32:39,218 - INFO - s3a://silver/sors/dim_status
# 2024-10-21 09:32:39,219 - INFO - Aguarde... Realizando optimize
# 2024-10-21 09:32:50,596 - INFO - Optimize executado com sucesso.
# 2024-10-21 09:32:50,598 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 09:33:09,613 - INFO - Vacuum executado com sucesso.
# 2024-10-21 09:33:09,614 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator.parar_sessao()
# Out:
# 2024-10-21 09:33:10,048 - INFO - Sessão Spark finalizada.
