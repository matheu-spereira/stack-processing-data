# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "silver"
datamart = "sors"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 10:30:45,372 - INFO - Iniciando Sessão Spark.

# %%
extrator.atualizar_tabela_delta('fat_lancamento')
# Out:
# 2024-10-21 10:30:49,351 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-21 10:30:49,353 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 10:30:49,353 - INFO - ['/home/jovyan/work/yaml/silver/sors/fat_lancamento.yaml']
# 2024-10-21 10:30:49,366 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-21 10:30:49,367 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 10:30:49,367 - INFO - ['/home/jovyan/work/yaml/silver/sors/fat_lancamento.yaml']
# 2024-10-21 10:30:49,373 - INFO - Aguarde... Criando View (bronze/sors/orcamentovalor)
# 2024-10-21 10:30:59,069 - INFO - View criada com sucesso
# 2024-10-21 10:30:59,071 - INFO - Aguarde... Criando View (bronze/sors/orcamento)
# 2024-10-21 10:30:59,651 - INFO - View criada com sucesso
# 2024-10-21 10:30:59,652 - INFO - Aguarde... Criando View (bronze/sors/cr)
# 2024-10-21 10:31:00,019 - INFO - View criada com sucesso
# 2024-10-21 10:31:00,020 - INFO - Aguarde... Criando View (bronze/sors/centrocusto)
# 2024-10-21 10:31:00,343 - INFO - View criada com sucesso
# 2024-10-21 10:31:00,344 - INFO - Aguarde... Criando View (bronze/sors/entidadeexercicioetapa)
# 2024-10-21 10:31:00,664 - INFO - View criada com sucesso
# 2024-10-21 10:31:00,665 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-21 10:31:00,666 - INFO - select
#   entidadeexercicioetapa.codigoetapa,
#   entidadeexercicioetapa.codigostatus,
#   orcamento.codigoentidade,
#   centrocusto.idcentrocusto,
#   orcamento.codigocr,
#   orcamentovalor.codigoorcamento,
#   orcamento.ano,
#   orcamentovalor.mes,
#   orcamento.codigo,
#   orcamento.codigoconta,
#   cr.codigoitemcontabil,
#   concat(
#     lpad(cast(1 as string), 2, '0'), '/',
#     lpad(cast(orcamentovalor.mes as string), 2, '0'), '/',
#     cast(orcamento.ano as string)
#   ) as data_lancamento,
#   --right('0' + cast(1 as varchar(2)), 2) + '/' + right('0' + cast(orcamentovalor.mes as varchar(2)), 2) + '/' +  cast(orcamento.ano as varchar(4)) as data_lancamento,
#   orcamentovalor.valor
# from orcamentovalor
# inner join orcamento on orcamento.codigo = orcamentovalor.codigoorcamento and orcamento.dataexclusao is null and orcamento.tipo = 'OR'
# inner join cr on cr.codigo = orcamento.codigocr and cr.dataexclusao is null
# inner join centrocusto on centrocusto.Codigo = cr.CodigoCentroCusto
# inner join entidadeexercicioetapa ON entidadeexercicioetapa.codigoentidade = orcamento.codigoentidade
#     AND entidadeexercicioetapa.ano = orcamento.ano
#     AND entidadeexercicioetapa.codigoetapa = orcamento.etapainclusao
#     AND entidadeexercicioetapa.codigostatus <= 5
#
# 2024-10-21 10:31:00,900 - INFO - Query (Delta) executada com sucesso
# 2024-10-21 10:31:00,901 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-21 10:31:00,901 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-21 10:31:43,344 - INFO - Dados persistidos com sucesso
# 2024-10-21 10:31:43,345 - INFO - s3a://silver/sors/fat_lancamento
# 2024-10-21 10:31:43,346 - INFO - Aguarde... Realizando optimize
# 2024-10-21 10:31:45,994 - INFO - Optimize executado com sucesso.
# 2024-10-21 10:31:45,995 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 10:32:03,967 - INFO - Vacuum executado com sucesso.
# 2024-10-21 10:32:03,968 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator.parar_sessao()
# Out:
# 2024-10-21 10:32:04,215 - INFO - Sessão Spark finalizada.
