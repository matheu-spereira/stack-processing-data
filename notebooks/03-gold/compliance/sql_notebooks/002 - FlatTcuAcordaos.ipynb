# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "silver"
datamart = "compliance"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-09-25 19:21:10,734 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Leitura da tabela

# %%
df_compliance_tcu = extrator_bronze.criar_view_temporaria('silver/Tcu/TcuAcordaos','compliance_flat_tcu')
# Out:
# 2024-09-25 19:21:13,887 - INFO - Aguarde... Criando View (silver/Tcu/TcuAcordaos)
# 2024-09-25 19:21:19,135 - INFO - View criada com sucesso

# %% [markdown]
# # Gravação no datalake

# %%
extrator_bronze.caminho_tabela_delta = 's3a://gold/Tcu/FlatTcuAcordaos'

# %%
extrator_bronze.salvar_delta(df_compliance_tcu, 'overwrite')
# Out:
# 2024-09-25 19:21:19,148 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-09-25 19:21:30,343 - INFO - Dados persistidos com sucesso
# 2024-09-25 19:21:30,343 - INFO - s3a://gold/Tcu/FlatTcuAcordaos
# 2024-09-25 19:21:30,344 - INFO - Aguarde... Realizando optimize
# 2024-09-25 19:21:33,417 - INFO - Optimize executado com sucesso.
# 2024-09-25 19:21:33,418 - INFO - Aguarde... Realizando vacuum
# 2024-09-25 19:21:48,900 - INFO - Vacuum executado com sucesso.

# %% [markdown]
# # Encerra sessão spark

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-09-25 19:21:49,205 - INFO - Sessão Spark finalizada.
