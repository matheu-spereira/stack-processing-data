# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "silver"
datamart = "compliance"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-09-25 19:26:57,590 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Leitura da tabela

# %%
df = extrator_bronze.criar_view_temporaria('silver/CaravelAL/CNIRlc','compliance_flat_cni_rlc')
# Out:
# 2024-09-25 19:27:00,542 - INFO - Aguarde... Criando View (silver/CaravelAL/CNIRlc)
# 2024-09-25 19:27:05,516 - INFO - View criada com sucesso

# %% [markdown]
# # Gravação no datalake

# %%
extrator_bronze.caminho_tabela_delta = 's3a://gold/CaravelAL/FlatCNIRlc'

# %%
extrator_bronze.salvar_delta(df, 'overwrite')
# Out:
# 2024-09-25 19:27:05,531 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-09-25 19:27:12,391 - INFO - Dados persistidos com sucesso
# 2024-09-25 19:27:12,392 - INFO - s3a://gold/CaravelAL/FlatCNIRlc
# 2024-09-25 19:27:12,392 - INFO - Aguarde... Realizando optimize
# 2024-09-25 19:27:16,675 - INFO - Optimize executado com sucesso.
# 2024-09-25 19:27:16,676 - INFO - Aguarde... Realizando vacuum
# 2024-09-25 19:27:30,239 - INFO - Vacuum executado com sucesso.

# %% [markdown]
# # Encerra sessão spark

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-09-25 19:27:30,390 - INFO - Sessão Spark finalizada.
