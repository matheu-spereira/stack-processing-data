# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "gold"
datamart = "gd_alinhar"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-23 10:23:41,999 - INFO - Iniciando Sessão Spark.

# %%
extrator.atualizar_tabela_delta('dim_projetos')
# Out:
# 2024-10-23 10:23:43,989 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-23 10:23:43,990 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-23 10:23:43,991 - INFO - ['/home/jovyan/work/yaml/gold/gd_alinhar/dim_projetos.yaml']
# 2024-10-23 10:23:43,999 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-23 10:23:43,999 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-23 10:23:44,000 - INFO - ['/home/jovyan/work/yaml/gold/gd_alinhar/dim_projetos.yaml']
# 2024-10-23 10:23:44,003 - INFO - Aguarde... Criando View (silver/pessoas/dim_projetos)
# 2024-10-23 10:23:49,928 - INFO - View criada com sucesso
# 2024-10-23 10:23:49,929 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-23 10:23:49,930 - INFO - SELECT
#     *
# FROM
#     projetos;
#
# 2024-10-23 10:23:49,998 - INFO - Query (Delta) executada com sucesso
# 2024-10-23 10:23:49,999 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-23 10:23:50,000 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-23 10:23:57,055 - INFO - Dados persistidos com sucesso
# 2024-10-23 10:23:57,056 - INFO - s3a://gold/pessoas/dim_projetos
# 2024-10-23 10:23:57,056 - INFO - Aguarde... Realizando optimize
# 2024-10-23 10:23:59,799 - INFO - Optimize executado com sucesso.
# 2024-10-23 10:23:59,800 - INFO - Aguarde... Realizando vacuum
# 2024-10-23 10:24:25,293 - INFO - Vacuum executado com sucesso.
# 2024-10-23 10:24:25,295 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator.parar_sessao()
# Out:
# 2024-10-23 10:24:25,899 - INFO - Sessão Spark finalizada.
