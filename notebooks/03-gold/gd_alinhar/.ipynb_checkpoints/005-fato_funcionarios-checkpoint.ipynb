# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "gold"
datamart = "gd_alinhar"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-23 10:24:41,743 - INFO - Iniciando Sessão Spark.

# %%
extrator.atualizar_tabela_delta('fato_funcionarios')
# Out:
# 2024-10-23 10:24:44,539 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-23 10:24:44,541 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-23 10:24:44,541 - INFO - ['/home/jovyan/work/yaml/gold/gd_alinhar/fato_funcionarios.yaml']
# 2024-10-23 10:24:44,547 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-23 10:24:44,548 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-23 10:24:44,549 - INFO - ['/home/jovyan/work/yaml/gold/gd_alinhar/fato_funcionarios.yaml']
# 2024-10-23 10:24:44,552 - INFO - Aguarde... Criando View (silver/pessoas/fato_funcionarios)
# 2024-10-23 10:24:50,353 - INFO - View criada com sucesso
# 2024-10-23 10:24:50,354 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-23 10:24:50,354 - INFO -
# SELECT
#     *
# FROM
#     funcionarios
#
# 2024-10-23 10:24:50,408 - INFO - Query (Delta) executada com sucesso
# 2024-10-23 10:24:50,409 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-23 10:24:50,410 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-23 10:25:00,175 - INFO - Dados persistidos com sucesso
# 2024-10-23 10:25:00,175 - INFO - s3a://gold/pessoas/fato_funcionarios
# 2024-10-23 10:25:00,176 - INFO - Aguarde... Realizando optimize
# 2024-10-23 10:25:02,974 - INFO - Optimize executado com sucesso.
# 2024-10-23 10:25:02,975 - INFO - Aguarde... Realizando vacuum
# 2024-10-23 10:25:18,080 - INFO - Vacuum executado com sucesso.
# 2024-10-23 10:25:18,080 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator.parar_sessao()
# Out:
# 2024-10-23 10:25:18,375 - INFO - Sessão Spark finalizada.
