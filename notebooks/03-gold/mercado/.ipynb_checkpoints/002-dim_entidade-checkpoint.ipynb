# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "gold"
datamart = "mercado"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-11-06 15:13:09,286 - INFO - Iniciando Sessão Spark.

# %%
extrator_bronze.atualizar_tabela_delta('dim_entidade')
# Out:
# 2024-11-06 15:13:12,001 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-11-06 15:13:12,003 - INFO - Arquivo yaml carregada com sucesso
# 2024-11-06 15:13:12,003 - INFO - ['/home/jovyan/work/yaml/gold/mercado/dim_entidade.yaml']
# 2024-11-06 15:13:12,012 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-11-06 15:13:12,013 - INFO - Arquivo yaml carregada com sucesso
# 2024-11-06 15:13:12,013 - INFO - ['/home/jovyan/work/yaml/gold/mercado/dim_entidade.yaml']
# 2024-11-06 15:13:12,018 - INFO - Aguarde... Criando View (silver/dynamicscrm/dim_entidade)
# 2024-11-06 15:13:21,029 - INFO - View criada com sucesso
# 2024-11-06 15:13:21,030 - INFO - Aguarde... Executando Query (Delta)
# 2024-11-06 15:13:21,033 - INFO - SELECT
#     *
# FROM dim_entidade
#
# 2024-11-06 15:13:21,170 - INFO - Query (Delta) executada com sucesso
# 2024-11-06 15:13:21,171 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-11-06 15:13:21,172 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-11-06 15:13:33,485 - INFO - Dados persistidos com sucesso
# 2024-11-06 15:13:33,487 - INFO - s3a://gold/mercado/dim_entidade
# 2024-11-06 15:13:33,488 - INFO - Aguarde... Realizando optimize
# 2024-11-06 15:13:36,264 - INFO - Optimize executado com sucesso.
# 2024-11-06 15:13:36,265 - INFO - Aguarde... Realizando vacuum
# 2024-11-06 15:14:01,677 - INFO - Vacuum executado com sucesso.
# 2024-11-06 15:14:01,677 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-11-06 15:14:01,913 - INFO - Sessão Spark finalizada.
