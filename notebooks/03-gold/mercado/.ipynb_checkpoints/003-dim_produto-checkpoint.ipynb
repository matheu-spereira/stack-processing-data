# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "gold"
datamart = "mercado"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-11-06 15:25:29,133 - INFO - Iniciando Sessão Spark.

# %%
extrator_bronze.atualizar_tabela_delta('dim_produto')
# Out:
# 2024-11-06 15:25:31,194 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-11-06 15:25:31,195 - INFO - Arquivo yaml carregada com sucesso
# 2024-11-06 15:25:31,196 - INFO - ['/home/jovyan/work/yaml/gold/mercado/dim_produto.yaml']
# 2024-11-06 15:25:31,202 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-11-06 15:25:31,202 - INFO - Arquivo yaml carregada com sucesso
# 2024-11-06 15:25:31,203 - INFO - ['/home/jovyan/work/yaml/gold/mercado/dim_produto.yaml']
# 2024-11-06 15:25:31,205 - INFO - Aguarde... Criando View (silver/dynamicscrm/dim_produto)
# 2024-11-06 15:25:36,081 - INFO - View criada com sucesso
# 2024-11-06 15:25:36,081 - INFO - Aguarde... Executando Query (Delta)
# 2024-11-06 15:25:36,082 - INFO - SELECT
#     *
# FROM products
#
# 2024-11-06 15:25:36,134 - INFO - Query (Delta) executada com sucesso
# 2024-11-06 15:25:36,134 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-11-06 15:25:36,246 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-11-06 15:25:45,913 - INFO - Dados persistidos com sucesso
# 2024-11-06 15:25:45,913 - INFO - s3a://gold/mercado/dim_produto
# 2024-11-06 15:25:45,914 - INFO - Aguarde... Realizando optimize
# 2024-11-06 15:25:49,782 - INFO - Optimize executado com sucesso.
# 2024-11-06 15:25:49,783 - INFO - Aguarde... Realizando vacuum
# 2024-11-06 15:26:05,220 - INFO - Vacuum executado com sucesso.
# 2024-11-06 15:26:05,221 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-11-06 15:26:05,612 - INFO - Sessão Spark finalizada.
