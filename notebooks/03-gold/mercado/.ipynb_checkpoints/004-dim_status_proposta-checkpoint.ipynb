# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "gold"
datamart = "mercado"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-11-06 15:13:13,940 - INFO - Iniciando Sessão Spark.

# %%
extrator_bronze.atualizar_tabela_delta('dim_status_proposta')
# Out:
# 2024-11-06 15:13:17,520 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-11-06 15:13:17,522 - INFO - Arquivo yaml carregada com sucesso
# 2024-11-06 15:13:17,523 - INFO - ['/home/jovyan/work/yaml/gold/mercado/dim_status_proposta.yaml']
# 2024-11-06 15:13:17,537 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-11-06 15:13:17,539 - INFO - Arquivo yaml carregada com sucesso
# 2024-11-06 15:13:17,540 - INFO - ['/home/jovyan/work/yaml/gold/mercado/dim_status_proposta.yaml']
# 2024-11-06 15:13:17,548 - INFO - Aguarde... Criando View (silver/dynamicscrm/dim_status_proposta)
# 2024-11-06 15:14:07,271 - INFO - View criada com sucesso
# 2024-11-06 15:14:07,272 - INFO - Aguarde... Executando Query (Delta)
# 2024-11-06 15:14:07,274 - INFO - SELECT
#     *
# FROM dim_status_proposta
#
# 2024-11-06 15:14:07,394 - INFO - Query (Delta) executada com sucesso
# 2024-11-06 15:14:07,395 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-11-06 15:14:07,396 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-11-06 15:14:17,114 - INFO - Dados persistidos com sucesso
# 2024-11-06 15:14:17,115 - INFO - s3a://gold/mercado/dim_status_proposta
# 2024-11-06 15:14:17,116 - INFO - Aguarde... Realizando optimize
# 2024-11-06 15:14:19,758 - INFO - Optimize executado com sucesso.
# 2024-11-06 15:14:19,759 - INFO - Aguarde... Realizando vacuum
# 2024-11-06 15:14:46,793 - INFO - Vacuum executado com sucesso.
# 2024-11-06 15:14:46,794 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-11-06 15:14:46,891 - INFO - Sessão Spark finalizada.
