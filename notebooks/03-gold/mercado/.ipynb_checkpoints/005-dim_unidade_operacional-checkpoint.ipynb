# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "gold"
datamart = "mercado"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-11-06 15:50:07,168 - INFO - Iniciando Sessão Spark.

# %%
extrator_bronze.atualizar_tabela_delta('dim_unidade_operacional')
# Out:
# 2024-11-06 15:50:09,650 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-11-06 15:50:09,651 - INFO - Arquivo yaml carregada com sucesso
# 2024-11-06 15:50:09,651 - INFO - ['/home/jovyan/work/yaml/gold/mercado/dim_unidade_operacional.yaml']
# 2024-11-06 15:50:09,658 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-11-06 15:50:09,658 - INFO - Arquivo yaml carregada com sucesso
# 2024-11-06 15:50:09,659 - INFO - ['/home/jovyan/work/yaml/gold/mercado/dim_unidade_operacional.yaml']
# 2024-11-06 15:50:09,662 - INFO - Aguarde... Criando View (silver/dynamicscrm/dim_unidade_operacional)
# 2024-11-06 15:50:15,480 - INFO - View criada com sucesso
# 2024-11-06 15:50:15,481 - INFO - Aguarde... Executando Query (Delta)
# 2024-11-06 15:50:15,481 - INFO - SELECT
#     *
# FROM dim_unidade_operacional
#
# 2024-11-06 15:50:15,539 - INFO - Query (Delta) executada com sucesso
# 2024-11-06 15:50:15,539 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-11-06 15:50:15,541 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-11-06 15:50:28,795 - INFO - Dados persistidos com sucesso
# 2024-11-06 15:50:28,796 - INFO - s3a://gold/mercado/dim_unidade_operacional
# 2024-11-06 15:50:28,797 - INFO - Aguarde... Realizando optimize
# 2024-11-06 15:50:31,613 - INFO - Optimize executado com sucesso.
# 2024-11-06 15:50:31,614 - INFO - Aguarde... Realizando vacuum
# 2024-11-06 15:50:48,983 - INFO - Vacuum executado com sucesso.
# 2024-11-06 15:50:48,984 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-11-06 15:50:49,519 - INFO - Sessão Spark finalizada.
