# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "gold"
datamart = "orcamento"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 11:23:09,566 - INFO - Iniciando Sessão Spark.

# %%
extrator.atualizar_tabela_delta('dim_centro_custo')
# Out:
# 2024-10-21 11:23:13,536 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-21 11:23:13,537 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 11:23:13,538 - INFO - ['/home/jovyan/work/yaml/gold/orcamento/dim_centro_custo.yaml']
# 2024-10-21 11:23:13,546 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-21 11:23:13,547 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 11:23:13,547 - INFO - ['/home/jovyan/work/yaml/gold/orcamento/dim_centro_custo.yaml']
# 2024-10-21 11:23:13,552 - INFO - Aguarde... Criando View (silver/sors/dim_centro_custo)
# 2024-10-21 11:23:23,298 - INFO - View criada com sucesso
# 2024-10-21 11:23:23,299 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-21 11:23:23,299 - INFO -  select idcentrocusto,codigoentidade,nmcentrocusto,sigla from dim_centro_custo
# 2024-10-21 11:23:23,396 - INFO - Query (Delta) executada com sucesso
# 2024-10-21 11:23:23,397 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-21 11:23:23,398 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-21 11:23:43,305 - INFO - Dados persistidos com sucesso
# 2024-10-21 11:23:43,306 - INFO - s3a://gold/orcamento/dim_centro_custo
# 2024-10-21 11:23:43,307 - INFO - Aguarde... Realizando optimize
# 2024-10-21 11:23:49,695 - INFO - Optimize executado com sucesso.
# 2024-10-21 11:23:49,696 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 11:24:09,502 - INFO - Vacuum executado com sucesso.
# 2024-10-21 11:24:09,503 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator.parar_sessao()
# Out:
# 2024-10-21 11:24:09,912 - INFO - Sessão Spark finalizada.
