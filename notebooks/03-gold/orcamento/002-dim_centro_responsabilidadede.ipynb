# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "gold"
datamart = "orcamento"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 11:10:34,411 - INFO - Iniciando Sessão Spark.

# %%
extrator.atualizar_tabela_delta('dim_centro_responsabilidade')
# Out:
# 2024-10-21 11:10:38,535 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-21 11:10:38,537 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 11:10:38,538 - INFO - ['/home/jovyan/work/yaml/gold/orcamento/dim_centro_responsabilidade.yaml']
# 2024-10-21 11:10:38,549 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-21 11:10:38,550 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 11:10:38,551 - INFO - ['/home/jovyan/work/yaml/gold/orcamento/dim_centro_responsabilidade.yaml']
# 2024-10-21 11:10:38,556 - INFO - Aguarde... Criando View (silver/sors/dim_centro_responsabilidade)
# 2024-10-21 11:10:48,693 - INFO - View criada com sucesso
# 2024-10-21 11:10:48,694 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-21 11:10:48,694 - INFO - select idcentrocusto,codigoitemcontabil,iditemcontabil,nmitemcontabil,iditemcontabilsuperior,codigotipoitemcontabil from dim_centro_responsabilidade
# 2024-10-21 11:10:48,788 - INFO - Query (Delta) executada com sucesso
# 2024-10-21 11:10:48,789 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-21 11:10:48,790 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-21 11:11:15,341 - INFO - Dados persistidos com sucesso
# 2024-10-21 11:11:15,342 - INFO - s3a://gold/orcamento/dim_centro_responsabilidade
# 2024-10-21 11:11:15,342 - INFO - Aguarde... Realizando optimize
# 2024-10-21 11:11:27,595 - INFO - Optimize executado com sucesso.
# 2024-10-21 11:11:27,596 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 11:11:48,380 - INFO - Vacuum executado com sucesso.
# 2024-10-21 11:11:48,419 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator.parar_sessao()
# Out:
# 2024-10-21 11:11:48,877 - INFO - Sessão Spark finalizada.
