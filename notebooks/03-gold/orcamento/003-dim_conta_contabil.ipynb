# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "gold"
datamart = "orcamento"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 09:55:04,311 - INFO - Iniciando Sessão Spark.

# %%
extrator.atualizar_tabela_delta('dim_conta_contabil')
# Out:
# 2024-10-21 09:55:08,282 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-21 09:55:08,284 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:55:08,284 - INFO - ['/home/jovyan/work/yaml/gold/orcamento/dim_conta_contabil.yaml']
# 2024-10-21 09:55:08,293 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-21 09:55:08,294 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:55:08,295 - INFO - ['/home/jovyan/work/yaml/gold/orcamento/dim_conta_contabil.yaml']
# 2024-10-21 09:55:08,299 - INFO - Aguarde... Criando View (silver/sors/dim_conta_contabil)
# 2024-10-21 09:55:17,642 - INFO - View criada com sucesso
# 2024-10-21 09:55:17,644 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-21 09:55:17,644 - INFO - select idcontacontabil,nmcontacontabil,idcontacontabilsuperior from dim_conta_contabil
# 2024-10-21 09:55:17,745 - INFO - Query (Delta) executada com sucesso
# 2024-10-21 09:55:17,746 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-21 09:55:17,747 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-21 09:55:31,235 - INFO - Dados persistidos com sucesso
# 2024-10-21 09:55:31,237 - INFO - s3a://gold/orcamento/dim_conta_contabil
# 2024-10-21 09:55:31,238 - INFO - Aguarde... Realizando optimize
# 2024-10-21 09:55:41,744 - INFO - Optimize executado com sucesso.
# 2024-10-21 09:55:41,747 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 09:56:03,025 - INFO - Vacuum executado com sucesso.
# 2024-10-21 09:56:03,027 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator.parar_sessao()
# Out:
# 2024-10-21 09:56:03,155 - INFO - Sessão Spark finalizada.
