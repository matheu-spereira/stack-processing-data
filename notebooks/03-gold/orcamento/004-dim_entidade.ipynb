# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "gold"
datamart = "orcamento"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 09:56:14,964 - INFO - Iniciando Sessão Spark.

# %%
extrator.atualizar_tabela_delta('dim_entidade')
# Out:
# 2024-10-21 09:56:19,106 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-21 09:56:19,108 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:56:19,109 - INFO - ['/home/jovyan/work/yaml/gold/orcamento/dim_entidade.yaml']
# 2024-10-21 09:56:19,118 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-21 09:56:19,119 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:56:19,119 - INFO - ['/home/jovyan/work/yaml/gold/orcamento/dim_entidade.yaml']
# 2024-10-21 09:56:19,124 - INFO - Aguarde... Criando View (silver/sors/dim_entidade)
# 2024-10-21 09:56:28,319 - INFO - View criada com sucesso
# 2024-10-21 09:56:28,320 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-21 09:56:28,321 - INFO - select codigo,nome,sigla,cnpj,codigoreservado,ativa from dim_entidade
# 2024-10-21 09:56:28,410 - INFO - Query (Delta) executada com sucesso
# 2024-10-21 09:56:28,411 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-21 09:56:28,411 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-21 09:56:39,679 - INFO - Dados persistidos com sucesso
# 2024-10-21 09:56:39,681 - INFO - s3a://gold/orcamento/dim_entidade
# 2024-10-21 09:56:39,682 - INFO - Aguarde... Realizando optimize
# 2024-10-21 09:56:50,534 - INFO - Optimize executado com sucesso.
# 2024-10-21 09:56:50,536 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 09:57:10,186 - INFO - Vacuum executado com sucesso.
# 2024-10-21 09:57:10,187 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator.parar_sessao()
# Out:
# 2024-10-21 09:57:10,434 - INFO - Sessão Spark finalizada.
