# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "gold"
datamart = "orcamento"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 09:58:08,770 - INFO - Iniciando Sessão Spark.

# %%
extrator.atualizar_tabela_delta('dim_etapa')
# Out:
# 2024-10-21 09:58:12,770 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-21 09:58:12,771 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:58:12,772 - INFO - ['/home/jovyan/work/yaml/gold/orcamento/dim_etapa.yaml']
# 2024-10-21 09:58:12,782 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-21 09:58:12,782 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:58:12,783 - INFO - ['/home/jovyan/work/yaml/gold/orcamento/dim_etapa.yaml']
# 2024-10-21 09:58:12,788 - INFO - Aguarde... Criando View (silver/sors/dim_etapa)
# 2024-10-21 09:58:21,932 - INFO - View criada com sucesso
# 2024-10-21 09:58:21,933 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-21 09:58:21,933 - INFO - select codigoetapa,nomeetapa from dim_etapa
# 2024-10-21 09:58:22,026 - INFO - Query (Delta) executada com sucesso
# 2024-10-21 09:58:22,027 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-21 09:58:22,027 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-21 09:58:35,290 - INFO - Dados persistidos com sucesso
# 2024-10-21 09:58:35,292 - INFO - s3a://gold/orcamento/dim_etapa
# 2024-10-21 09:58:35,292 - INFO - Aguarde... Realizando optimize
# 2024-10-21 09:58:46,005 - INFO - Optimize executado com sucesso.
# 2024-10-21 09:58:46,007 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 09:59:05,338 - INFO - Vacuum executado com sucesso.
# 2024-10-21 09:59:05,339 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator.parar_sessao()
# Out:
# 2024-10-21 09:59:05,622 - INFO - Sessão Spark finalizada.
