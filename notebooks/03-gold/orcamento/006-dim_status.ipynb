# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "gold"
datamart = "orcamento"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 09:59:21,228 - INFO - Iniciando Sessão Spark.

# %%
extrator.atualizar_tabela_delta('dim_status')
# Out:
# 2024-10-21 09:59:25,389 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-21 09:59:25,390 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:59:25,391 - INFO - ['/home/jovyan/work/yaml/gold/orcamento/dim_status.yaml']
# 2024-10-21 09:59:25,400 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-21 09:59:25,401 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:59:25,402 - INFO - ['/home/jovyan/work/yaml/gold/orcamento/dim_status.yaml']
# 2024-10-21 09:59:25,406 - INFO - Aguarde... Criando View (silver/sors/dim_status)
# 2024-10-21 09:59:35,044 - INFO - View criada com sucesso
# 2024-10-21 09:59:35,045 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-21 09:59:35,046 - INFO - select codigo,nome from dim_status
# 2024-10-21 09:59:35,134 - INFO - Query (Delta) executada com sucesso
# 2024-10-21 09:59:35,135 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-21 09:59:35,136 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-21 09:59:49,003 - INFO - Dados persistidos com sucesso
# 2024-10-21 09:59:49,004 - INFO - s3a://gold/orcamento/dim_status
# 2024-10-21 09:59:49,005 - INFO - Aguarde... Realizando optimize
# 2024-10-21 10:00:00,628 - INFO - Optimize executado com sucesso.
# 2024-10-21 10:00:00,629 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 10:00:20,711 - INFO - Vacuum executado com sucesso.
# 2024-10-21 10:00:20,712 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator.parar_sessao()
# Out:
# 2024-10-21 10:00:21,242 - INFO - Sessão Spark finalizada.
