# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "gold"
datamart = "pessoas"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 08:58:36,004 - INFO - Iniciando Sessão Spark.

# %%
extrator.atualizar_tabela_delta('dim_pessoa')
# Out:
# 2024-10-21 08:58:40,472 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-21 08:58:40,473 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 08:58:40,474 - INFO - ['/home/jovyan/work/yaml/gold/pessoas/dim_pessoa.yaml']
# 2024-10-21 08:58:40,484 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-21 08:58:40,485 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 08:58:40,485 - INFO - ['/home/jovyan/work/yaml/gold/pessoas/dim_pessoa.yaml']
# 2024-10-21 08:58:40,490 - INFO - Aguarde... Criando View (silver/corporerm/dim_pessoa)
# 2024-10-21 08:58:52,276 - INFO - View criada com sucesso
# 2024-10-21 08:58:52,277 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-21 08:58:52,278 - INFO -  select dim_pessoa.id_pessoa, dim_pessoa.nm_pessoa, dim_pessoa.ds_naturalidade, dim_pessoa.ds_sexo, dim_pessoa.ds_email, dim_pessoa.nr_cep, dim_pessoa.nr_cpf, dim_pessoa.nr_telefone1, dim_pessoa.nr_telefone2, dim_pessoa.ds_grau_instrucao from dim_pessoa
# 2024-10-21 08:58:52,461 - INFO - Query (Delta) executada com sucesso
# 2024-10-21 08:58:52,462 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-21 08:58:52,462 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-21 08:59:19,546 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:59:19,551 - INFO - s3a://gold/pessoas/dim_pessoa
# 2024-10-21 08:59:19,552 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:59:22,737 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:59:22,738 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 08:59:41,377 - INFO - Vacuum executado com sucesso.
# 2024-10-21 08:59:41,378 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator.parar_sessao()
# Out:
# 2024-10-21 08:59:41,839 - INFO - Sessão Spark finalizada.
