# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "gold"
datamart = "pessoas"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 08:58:43,139 - INFO - Iniciando Sessão Spark.

# %%
extrator.atualizar_tabela_delta('fat_colaborador')
# Out:
# 2024-10-21 08:58:48,569 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-21 08:58:48,570 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 08:58:48,570 - INFO - ['/home/jovyan/work/yaml/gold/pessoas/fat_colaborador.yaml']
# 2024-10-21 08:58:48,581 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-21 08:58:48,581 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 08:58:48,582 - INFO - ['/home/jovyan/work/yaml/gold/pessoas/fat_colaborador.yaml']
# 2024-10-21 08:58:48,586 - INFO - Aguarde... Criando View (silver/corporerm/fat_colaborador)
# 2024-10-21 08:59:00,299 - INFO - View criada com sucesso
# 2024-10-21 08:59:00,302 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-21 08:59:00,303 - INFO -  select fat_colaborador.id_matricula, fat_colaborador.id_pessoa, fat_colaborador.cd_coligada, fat_colaborador.ds_unidade, fat_colaborador.ds_situacao, fat_colaborador.ds_funcao, fat_colaborador.cd_cargo, fat_colaborador.ds_cargo, fat_colaborador.hr_trabalho, fat_colaborador.dt_admissao, fat_colaborador.dt_demissao, fat_colaborador.hr_semanais, fat_colaborador.hr_mensais from fat_colaborador
# 2024-10-21 08:59:00,466 - INFO - Query (Delta) executada com sucesso
# 2024-10-21 08:59:00,467 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-21 08:59:00,468 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-21 08:59:30,351 - INFO - Dados persistidos com sucesso
# 2024-10-21 08:59:30,353 - INFO - s3a://gold/pessoas/fat_colaborador
# 2024-10-21 08:59:30,353 - INFO - Aguarde... Realizando optimize
# 2024-10-21 08:59:38,937 - INFO - Optimize executado com sucesso.
# 2024-10-21 08:59:38,938 - INFO - Aguarde... Realizando vacuum
# 2024-10-21 09:00:00,060 - INFO - Vacuum executado com sucesso.
# 2024-10-21 09:00:00,061 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator.parar_sessao()
# Out:
# 2024-10-21 09:00:00,396 - INFO - Sessão Spark finalizada.
