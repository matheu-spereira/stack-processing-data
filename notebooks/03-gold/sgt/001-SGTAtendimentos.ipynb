# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
# Out:
# .::Métodos disponíveis::.
# ------------------------------------------------------
# extrair_dados_bronze(self,arquivo='')
# encontrar_ano_mes(caminho_prefixo)
# criar_view_temporaria_arquivo(local, nome, schema=None, aba=None, **config)
# atualizar_tabela_delta(arquivo)
# criar_view_temporaria(df, nome)
# historico_tabela()
# carrega_lista_yaml()
# salvar_delta(df, mode)
# parar_sessao()

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "gold"
datamart = "SGT"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-09-26 18:09:27,420 - INFO - Iniciando Sessão Spark.

# %%
extrator_bronze.atualizar_tabela_delta('FatoAtendimentosSgt')
# Out:
# 2024-09-26 18:09:30,789 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-09-26 18:09:30,790 - INFO - Arquivo yaml carregada com sucesso
# 2024-09-26 18:09:30,791 - INFO - ['/home/jovyan/work/yaml/gold/sgt/FatoAtendimentosSgt.yaml']
# 2024-09-26 18:09:30,801 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-09-26 18:09:30,802 - INFO - Arquivo yaml carregada com sucesso
# 2024-09-26 18:09:30,803 - INFO - ['/home/jovyan/work/yaml/gold/sgt/FatoAtendimentosSgt.yaml']
# 2024-09-26 18:09:30,807 - INFO - Aguarde... Criando View (silver/SGT/AtendimentosIntegracoesSgt)
# 2024-09-26 18:09:36,431 - INFO - View criada com sucesso
# 2024-09-26 18:09:36,431 - INFO - Aguarde... Criando View (silver/SGT/AtendimentoSgt)
# 2024-09-26 18:09:36,654 - INFO - View criada com sucesso
# 2024-09-26 18:09:36,654 - INFO - Aguarde... Executando Query (Delta)
# 2024-09-26 18:09:36,655 - INFO - SELECT
#     c.id,
#     c.id_atendimento,
#     c.nr_atendimento,
#     c.dsc_titulo_atendimento,
#     c.dsc_status_atendimento,
#     c.dia,
#     c.mes,
#     c.ano,
#     c.nr_cpf_cnpj_cliente,
#     c.nm_cliente,
#     c.id_porte_cliente,
#     c.dsc_porte_cliente,
#     CASE WHEN c.nr_de_funcionario = TRUE THEN 0 ELSE c.nr_de_funcionario END AS nr_de_funcionario,
#     c.dsc_produto_regional,
#     c.cr_produto_regional,
#     c.nr_dn_produto_nacional,
#     c.dsc_produto_nacional,
#     c.nr_dn_produto_categoria,
#     c.dsc_produto_categoria,
#     c.nr_dn_produto_linha,
#     c.dsc_produto_linha,
#     c.nr_oab_unidade_operacional,
#     c.dsc_unidade_operacional,
#     c.nr_de_producao_estimada,
#     c.nr_de_relatorio_estimado,
#     c.nr_de_receitas_estimada,
#     c.vlr_financeiro,
#     c.vlr_economico,
#     c.dsc_compartilhamento,
#     c.dsc_em_rede,
#     c.dsc_escopo_indefinido,
#     c.dsc_valor_hora,
#     --c.dt_carga,
#     TO_DATE(a.dt_emissao) AS id_data_calendario,
#     a.dt_emissao,
#     a.dt_negociacao,
#     a.dt_aceitacao,
#     a.dt_execucao,
#     a.dt_recusa,
#     a.dt_conclusao,
#     a.dt_cancelamento
# FROM sgt_atendimentos c
# LEFT JOIN sgt_atendimentos_integracoes a
# ON c.id_atendimento = a.id_atendimento
# WHERE id IS NOT NULL;
#
# 2024-09-26 18:09:36,773 - INFO - Query (Delta) executada com sucesso
# 2024-09-26 18:09:36,774 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-09-26 18:09:36,775 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-09-26 18:09:50,181 - INFO - Dados persistidos com sucesso
# 2024-09-26 18:09:50,183 - INFO - s3a://gold/SGT/FatoAtendimentosSgt
# 2024-09-26 18:09:50,183 - INFO - Aguarde... Realizando optimize
# 2024-09-26 18:09:52,368 - INFO - Optimize executado com sucesso.
# 2024-09-26 18:09:52,369 - INFO - Aguarde... Realizando vacuum
# 2024-09-26 18:10:10,575 - INFO - Vacuum executado com sucesso.
# 2024-09-26 18:10:10,576 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-09-26 18:10:11,150 - INFO - Sessão Spark finalizada.
