# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "gold"
datamart = "SGT"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-10-29 15:22:23,115 - INFO - Iniciando Sessão Spark.

# %%
extrator_bronze.atualizar_tabela_delta('DimClientesSgt')
# Out:
# 2024-10-29 15:22:25,076 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-10-29 15:22:25,078 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-29 15:22:25,079 - INFO - ['/home/jovyan/work/yaml/gold/SGT/DimClientesSgt.yaml']
# 2024-10-29 15:22:25,085 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-10-29 15:22:25,086 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-29 15:22:25,087 - INFO - ['/home/jovyan/work/yaml/gold/SGT/DimClientesSgt.yaml']
# 2024-10-29 15:22:25,090 - INFO - Aguarde... Criando View (silver/sgt/dim_clientes)
# 2024-10-29 15:22:30,012 - INFO - View criada com sucesso
# 2024-10-29 15:22:30,012 - INFO - Aguarde... Executando Query (Delta)
# 2024-10-29 15:22:30,013 - INFO - SELECT
#     *
# FROM sgt_clientes
#
# 2024-10-29 15:22:30,065 - INFO - Query (Delta) executada com sucesso
# 2024-10-29 15:22:30,065 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-10-29 15:22:30,066 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-10-29 15:22:39,282 - INFO - Dados persistidos com sucesso
# 2024-10-29 15:22:39,283 - INFO - s3a://gold/sgt/dim_clientes
# 2024-10-29 15:22:39,283 - INFO - Aguarde... Realizando optimize
# 2024-10-29 15:22:41,874 - INFO - Optimize executado com sucesso.
# 2024-10-29 15:22:41,875 - INFO - Aguarde... Realizando vacuum
# 2024-10-29 15:22:56,205 - INFO - Vacuum executado com sucesso.
# 2024-10-29 15:22:56,206 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-10-29 15:22:56,491 - INFO - Sessão Spark finalizada.
