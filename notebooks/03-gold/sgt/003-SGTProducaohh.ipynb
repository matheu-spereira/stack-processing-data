# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "gold"
datamart = "SGT"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-09-26 17:04:50,711 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Leitura da tabela

# %%
extrator_bronze.atualizar_tabela_delta('FatoProducaoHHSgt')
# Out:
# 2024-09-26 17:04:56,612 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-09-26 17:04:56,614 - INFO - Arquivo yaml carregada com sucesso
# 2024-09-26 17:04:56,615 - INFO - ['/home/jovyan/work/yaml/gold/sgt/FatoProducaoHHSgt.yaml']
# 2024-09-26 17:04:56,624 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-09-26 17:04:56,625 - INFO - Arquivo yaml carregada com sucesso
# 2024-09-26 17:04:56,626 - INFO - ['/home/jovyan/work/yaml/gold/sgt/FatoProducaoHHSgt.yaml']
# 2024-09-26 17:04:56,631 - INFO - Aguarde... Criando View (silver/SGT/ProducaoHHSgt)
# 2024-09-26 17:05:56,465 - INFO - View criada com sucesso
# 2024-09-26 17:05:56,466 - INFO - Aguarde... Executando Query (Delta)
# 2024-09-26 17:05:56,466 - INFO - SELECT
#     *
# FROM
#     sgt_producaohh
#
# 2024-09-26 17:05:56,554 - INFO - Query (Delta) executada com sucesso
# 2024-09-26 17:05:56,554 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-09-26 17:05:56,555 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-09-26 17:06:06,076 - INFO - Dados persistidos com sucesso
# 2024-09-26 17:06:06,076 - INFO - s3a://gold/SGT/FatoProducaoHHSgt
# 2024-09-26 17:06:06,078 - INFO - Aguarde... Realizando optimize
# 2024-09-26 17:06:09,246 - INFO - Optimize executado com sucesso.
# 2024-09-26 17:06:09,248 - INFO - Aguarde... Realizando vacuum
# 2024-09-26 17:06:37,809 - INFO - Vacuum executado com sucesso.
# 2024-09-26 17:06:37,810 - INFO - Tabela (Delta) atualizado com sucesso

# %% [markdown]
# # Encerra sessão spark

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-09-26 17:06:38,400 - INFO - Sessão Spark finalizada.
