# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "gold"
datamart = "SGT"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-09-26 17:04:52,396 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Leitura da tabela

# %%
extrator_bronze.atualizar_tabela_delta('FatoReceitasSgt')
# Out:
# 2024-09-26 17:04:59,709 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-09-26 17:04:59,711 - INFO - Arquivo yaml carregada com sucesso
# 2024-09-26 17:04:59,712 - INFO - ['/home/jovyan/work/yaml/gold/sgt/FatoReceitasSgt.yaml']
# 2024-09-26 17:04:59,722 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-09-26 17:04:59,730 - INFO - Arquivo yaml carregada com sucesso
# 2024-09-26 17:04:59,731 - INFO - ['/home/jovyan/work/yaml/gold/sgt/FatoReceitasSgt.yaml']
# 2024-09-26 17:04:59,737 - INFO - Aguarde... Criando View (silver/SGT/ReceitasSgt)
# 2024-09-26 17:05:58,313 - INFO - View criada com sucesso
# 2024-09-26 17:05:58,314 - INFO - Aguarde... Executando Query (Delta)
# 2024-09-26 17:05:58,315 - INFO - SELECT
# *
# FROM
#     sgt_receitas
#
# 2024-09-26 17:05:58,434 - INFO - Query (Delta) executada com sucesso
# 2024-09-26 17:05:58,435 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-09-26 17:05:58,436 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-09-26 17:06:11,573 - INFO - Dados persistidos com sucesso
# 2024-09-26 17:06:11,574 - INFO - s3a://gold/SGT/FatoReceitasSgt
# 2024-09-26 17:06:11,575 - INFO - Aguarde... Realizando optimize
# 2024-09-26 17:06:14,661 - INFO - Optimize executado com sucesso.
# 2024-09-26 17:06:14,663 - INFO - Aguarde... Realizando vacuum
# 2024-09-26 17:06:44,543 - INFO - Vacuum executado com sucesso.
# 2024-09-26 17:06:44,544 - INFO - Tabela (Delta) atualizado com sucesso

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-09-26 17:06:44,941 - INFO - Sessão Spark finalizada.
