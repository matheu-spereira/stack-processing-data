# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
# Out:
# .::Métodos disponíveis::.
# ------------------------------------------------------
# extrair_dados_bronze(self,arquivo='')
# encontrar_ano_mes(caminho_prefixo)
# criar_view_temporaria_arquivo(local, nome, schema=None, aba=None, **config)
# atualizar_tabela_delta(arquivo)
# criar_view_temporaria(df, nome)
# historico_tabela()
# carrega_lista_yaml()
# salvar_delta(df, mode)
# parar_sessao()

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "gold"
datamart = "SGT"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-09-26 18:00:19,486 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Leitura da tabela

# %%
extrator_bronze.atualizar_tabela_delta('DimEmpresasSgt')
# Out:
# 2024-09-26 18:00:22,779 - INFO - Aguarde... Atualizando tabela (Delta)
# 2024-09-26 18:00:22,781 - INFO - Arquivo yaml carregada com sucesso
# 2024-09-26 18:00:22,781 - INFO - ['/home/jovyan/work/yaml/gold/sgt/DimEmpresasSgt.yaml']
# 2024-09-26 18:00:22,791 - INFO - Aguarde... Preparando tabela (Delta)
# 2024-09-26 18:00:22,793 - INFO - Arquivo yaml carregada com sucesso
# 2024-09-26 18:00:22,794 - INFO - ['/home/jovyan/work/yaml/gold/sgt/DimEmpresasSgt.yaml']
# 2024-09-26 18:00:22,798 - INFO - Aguarde... Criando View (silver/SGT/RelatoriosSgt)
# 2024-09-26 18:00:30,420 - INFO - View criada com sucesso
# 2024-09-26 18:00:30,420 - INFO - Aguarde... Criando View (silver/SGT/ClientesSgt)
# 2024-09-26 18:00:30,663 - INFO - View criada com sucesso
# 2024-09-26 18:00:30,664 - INFO - Aguarde... Criando View (silver/SGT/AtendimentoSgt)
# 2024-09-26 18:00:30,857 - INFO - View criada com sucesso
# 2024-09-26 18:00:30,857 - INFO - Aguarde... Executando Query (Delta)
# 2024-09-26 18:00:30,858 - INFO - SELECT cpf_cnpj, nome_cliente
# FROM (
#     SELECT
#         cpf_cnpj,
#         nome_cliente,
#         ROW_NUMBER() OVER(PARTITION BY cpf_cnpj ORDER BY cpf_cnpj) as row_num
#     FROM (
#         SELECT nr_cnpj_cliente AS cpf_cnpj, nm_cliente AS nome_cliente
#         FROM sgt_relatorios
#
#         UNION ALL
#
#         SELECT nr_cpf_cnpj_cliente AS cpf_cnpj, nm_cliente AS nome_cliente
#         FROM sgt_atendimentos
#
#         UNION ALL
#
#         SELECT nr_cpf_cnpj AS cpf_cnpj, dsc_nome AS nome_cliente
#         FROM sgt_clientes
#     ) as combined_data
# ) as numbered_rows
# WHERE row_num = 1 and cpf_cnpj IS NOT NULL;
#
# 2024-09-26 18:00:30,966 - INFO - Query (Delta) executada com sucesso
# 2024-09-26 18:00:30,967 - INFO - Tabela (Delta) preparada com sucesso.
# 2024-09-26 18:00:30,967 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-09-26 18:00:56,662 - INFO - Dados persistidos com sucesso
# 2024-09-26 18:00:56,663 - INFO - s3a://gold/SGT/DimEmpresasSgt
# 2024-09-26 18:00:56,664 - INFO - Aguarde... Realizando optimize
# 2024-09-26 18:00:58,147 - INFO - Optimize executado com sucesso.
# 2024-09-26 18:00:58,147 - INFO - Aguarde... Realizando vacuum
# 2024-09-26 18:01:14,748 - INFO - Vacuum executado com sucesso.
# 2024-09-26 18:01:14,749 - INFO - Tabela (Delta) atualizado com sucesso

# %% [markdown]
# # Encerra sessão spark

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-09-26 18:01:15,160 - INFO - Sessão Spark finalizada.
