# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL

# %% [markdown]
# # Crie uma instância da classe AlinharETL

# %%
# Crie uma instância da classe
bucket = "gold"
datamart = "sgt"
extrator_bronze = AlinharETL(bucket,datamart)
# Out:
# 2024-09-25 17:09:20,705 - INFO - Iniciando Sessão Spark.

# %% [markdown]
# # Leitura da tabela

# %%
df_relatorios_sgt = extrator_bronze.criar_view_temporaria('silver/SGT/RelatoriosSgt','sgt_relatorios')
# Out:
# 2024-09-25 17:09:27,008 - INFO - Aguarde... Criando View (silver/SGT/RelatoriosSgt)
# 2024-09-25 17:11:02,836 - INFO - View criada com sucesso

# %% [markdown]
# # Gravação no datalake

# %%
extrator_bronze.caminho_tabela_delta = 's3a://gold/SGT/FatoRelatoriosSgt'

# %%
extrator_bronze.salvar_delta(df_relatorios_sgt, 'overwrite')
# Out:
# 2024-09-25 17:11:02,848 - INFO - Aguarde... Persistindo dados (overwrite)
# 2024-09-25 17:11:12,165 - INFO - Dados persistidos com sucesso
# 2024-09-25 17:11:12,166 - INFO - s3a://gold/SGT/FatoRelatoriosSgt
# 2024-09-25 17:11:12,167 - INFO - Aguarde... Realizando optimize
# 2024-09-25 17:11:14,781 - INFO - Optimize executado com sucesso.
# 2024-09-25 17:11:14,783 - INFO - Aguarde... Realizando vacuum
# 2024-09-25 17:11:44,516 - INFO - Vacuum executado com sucesso.

# %% [markdown]
# # Encerra sessão spark

# %%
extrator_bronze.parar_sessao()
# Out:
# 2024-09-25 17:11:44,861 - INFO - Sessão Spark finalizada.
