# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
# Crie uma instância da classe
bucket = "gold"
datamart = "mercado"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-11-06 15:21:02,494 - INFO - Iniciando Sessão Spark.

# %%
extrator.carrega_dados_delta('dim_status_proposta')
# Out:
# 2024-11-06 15:21:06,011 - INFO - Arquivo yaml carregada com sucesso
# 2024-11-06 15:21:06,013 - INFO - ['/home/jovyan/work/yaml/gold/mercado/dim_status_proposta.yaml']
# 2024-11-06 15:21:06,023 - INFO - Aguarde... Carregando dados
# 2024-11-06 15:21:13,895 - INFO - Dados carregado com sucesso
# DataFrame[cod_status: string, dsc_status: string, dt_atualizacao: timestamp]

# %%
extrator.conexao_banco_de_dados('sqlserver','sqlserver','1433','sa','SqlServer2019!','ALINHAR','DW')
# Out:
# 2024-11-06 15:21:13,922 - INFO - Aguarde... Configurando conexao banco de dados

# %%
extrator.persistencia_consume('mercado_dim_status_proposta')
# Out:
# 2024-11-06 15:21:13,929 - INFO - Aguarde... Persistindo os dados camada Consume
# 2024-11-06 15:21:23,162 - INFO - Camada Consume persistida com sucesso
# 2024-11-06 15:21:23,163 - INFO - DW.mercado_dim_status_proposta

# %%
extrator.parar_sessao()
# Out:
# 2024-11-06 15:21:23,326 - INFO - Sessão Spark finalizada.
