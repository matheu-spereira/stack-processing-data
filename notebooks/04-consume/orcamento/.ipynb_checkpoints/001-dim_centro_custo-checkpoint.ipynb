# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "gold"
datamart = "orcamento"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 11:24:21,123 - INFO - Iniciando Sessão Spark.

# %%
df = extrator.carrega_dados_delta('dim_centro_custo')
# Out:
# 2024-10-21 11:24:24,941 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 11:24:24,942 - INFO - ['/home/jovyan/work/yaml/gold/orcamento/dim_centro_custo.yaml']
# 2024-10-21 11:24:24,951 - INFO - Aguarde... Carregando dados
# 2024-10-21 11:24:34,179 - INFO - Dados carregado com sucesso

# %%
extrator.conexao_banco_de_dados(os.getenv("DB_DESTINO_DBMS"),
                                os.getenv("DB_DESTINO_HOST"),
                                os.getenv("DB_DESTINO_PORT"),
                                os.getenv("DB_DESTINO_USER"),
                                os.getenv("DB_DESTINO_PASSWORD"),
                                os.getenv("DB_DESTINO_DATABASE"),
                                os.getenv("DB_DESTINO_SCHEMA"))
# Out:
# 2024-10-21 11:24:34,185 - INFO - Aguarde... Configurando conexao banco de dados

# %%
extrator.persistencia_consume('orcamento_dim_centro_custo')
# Out:
# 2024-10-21 11:24:34,224 - INFO - Aguarde... Persistindo os dados camada Consume
# 2024-10-21 11:24:44,945 - INFO - Camada Consume persistida com sucesso
# 2024-10-21 11:24:44,947 - INFO - dw.orcamento_dim_centro_custo

# %%
extrator.parar_sessao()
# Out:
# 2024-10-21 11:24:45,238 - INFO - Sessão Spark finalizada.
