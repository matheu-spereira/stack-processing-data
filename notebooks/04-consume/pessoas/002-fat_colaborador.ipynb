# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
bucket = "gold"
datamart = "pessoas"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-10-21 09:01:34,198 - INFO - Iniciando Sessão Spark.

# %%
df = extrator.carrega_dados_delta('fat_colaborador')
# Out:
# 2024-10-21 09:01:39,260 - INFO - Arquivo yaml carregada com sucesso
# 2024-10-21 09:01:39,261 - INFO - ['/home/jovyan/work/yaml/gold/pessoas/fat_colaborador.yaml']
# 2024-10-21 09:01:39,271 - INFO - Aguarde... Carregando dados
# 2024-10-21 09:01:50,063 - INFO - Dados carregado com sucesso

# %%
extrator.conexao_banco_de_dados(os.getenv("DB_DESTINO_DBMS"),
                                os.getenv("DB_DESTINO_HOST"),
                                os.getenv("DB_DESTINO_PORT"),
                                os.getenv("DB_DESTINO_USER"),
                                os.getenv("DB_DESTINO_PASSWORD"),
                                os.getenv("DB_DESTINO_DATABASE"),
                                os.getenv("DB_DESTINO_SCHEMA"))
# Out:
# 2024-10-21 09:01:50,070 - INFO - Aguarde... Configurando conexao banco de dados

# %%
extrator.persistencia_consume('pessoas_fat_colaborador')
# Out:
# 2024-10-21 09:01:50,077 - INFO - Aguarde... Persistindo os dados camada Consume
# 2024-10-21 09:02:12,234 - INFO - Camada Consume persistida com sucesso
# 2024-10-21 09:02:12,236 - INFO - dw.pessoas_fat_colaborador

# %%
extrator.parar_sessao()
# Out:
# 2024-10-21 09:02:12,557 - INFO - Sessão Spark finalizada.
