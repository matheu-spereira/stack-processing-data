# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *
# Out:
# .::Métodos disponíveis::.
# ------------------------------------------------------
# extrair_dados_bronze(self,arquivo='')
# encontrar_ano_mes(caminho_prefixo)
# criar_view_temporaria_arquivo(local, nome, schema=None, aba=None, **config)
# atualizar_tabela_delta(arquivo)
# criar_view_temporaria(df, nome)
# historico_tabela()
# carrega_lista_yaml()
# salvar_delta(df, mode)
# parar_sessao()

# %%
# Crie uma instância da classe
bucket = "gold"
datamart = "sgt"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-09-26 18:01:26,096 - INFO - Iniciando Sessão Spark.

# %%
extrator.carrega_dados_delta('DimEmpresasSgt')
# Out:
# 2024-09-26 18:01:30,652 - INFO - Arquivo yaml carregada com sucesso
# 2024-09-26 18:01:30,654 - INFO - ['/home/jovyan/work/yaml/gold/sgt/DimEmpresasSgt.yaml']
# 2024-09-26 18:01:30,661 - INFO - Aguarde... Carregando dados
# 2024-09-26 18:02:08,409 - INFO - Dados carregado com sucesso
# DataFrame[cpf_cnpj: string, nome_cliente: string, dt_atualizacao: timestamp]

# %%
extrator.conexao_banco_de_dados('sqlserver','sqlserver','1433','sa','SqlServer2019!','ALINHAR','DW')
# Out:
# 2024-09-26 18:02:08,435 - INFO - Aguarde... Configurando conexao banco de dados

# %%
extrator.persistencia_consume('sgt_dim_empresas')
# Out:
# 2024-09-26 18:02:08,447 - INFO - Aguarde... Persistindo os dados camada Consume
# 2024-09-26 18:02:15,848 - INFO - Camada Consume persistida com sucesso
# 2024-09-26 18:02:15,849 - INFO - DW.sgt_dim_empresas

# %%
extrator.parar_sessao()
# Out:
# 2024-09-26 18:02:16,017 - INFO - Sessão Spark finalizada.
