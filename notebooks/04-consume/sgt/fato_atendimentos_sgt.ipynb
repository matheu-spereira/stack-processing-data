# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *

# %%
# Crie uma instância da classe
bucket = "gold"
datamart = "sgt"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-09-26 18:10:31,561 - INFO - Iniciando Sessão Spark.

# %%
extrator.carrega_dados_delta('FatoAtendimentosSgt')
# Out:
# 2024-09-26 18:10:32,529 - INFO - Arquivo yaml carregada com sucesso
# 2024-09-26 18:10:32,530 - INFO - ['/home/jovyan/work/yaml/gold/sgt/FatoAtendimentosSgt.yaml']
# 2024-09-26 18:10:32,539 - INFO - Aguarde... Carregando dados
# 2024-09-26 18:10:38,281 - INFO - Dados carregado com sucesso
# DataFrame[id: string, id_atendimento: string, nr_atendimento: string, dsc_titulo_atendimento: string, dsc_status_atendimento: string, dia: string, mes: string, ano: string, nr_cpf_cnpj_cliente: string, nm_cliente: string, id_porte_cliente: string, dsc_porte_cliente: string, nr_de_funcionario: string, dsc_produto_regional: string, cr_produto_regional: string, nr_dn_produto_nacional: string, dsc_produto_nacional: string, nr_dn_produto_categoria: string, dsc_produto_categoria: string, nr_dn_produto_linha: string, dsc_produto_linha: string, nr_oab_unidade_operacional: string, dsc_unidade_operacional: string, nr_de_producao_estimada: string, nr_de_relatorio_estimado: string, nr_de_receitas_estimada: string, vlr_financeiro: string, vlr_economico: string, dsc_compartilhamento: string, dsc_em_rede: string, dsc_escopo_indefinido: string, dsc_valor_hora: string, id_data_calendario: date, dt_emissao: timestamp, dt_negociacao: timestamp, dt_aceitacao: timestamp, dt_execucao: timestamp, dt_recusa: timestamp, dt_conclusao: timestamp, dt_cancelamento: timestamp, dt_atualizacao: timestamp]

# %%
extrator.conexao_banco_de_dados('sqlserver','sqlserver','1433','sa','SqlServer2019!','ALINHAR','DW')
# Out:
# 2024-09-26 18:10:48,698 - INFO - Aguarde... Configurando conexao banco de dados

# %%
extrator.persistencia_consume('sgt_fato_atendimentos')
# Out:
# 2024-09-26 18:10:49,345 - INFO - Aguarde... Persistindo os dados camada Consume
# 2024-09-26 18:10:54,823 - INFO - Camada Consume persistida com sucesso
# 2024-09-26 18:10:54,824 - INFO - DW.sgt_fato_atendimentos

# %%
extrator.parar_sessao()
# Out:
# 2024-09-26 18:10:55,373 - INFO - Sessão Spark finalizada.
