# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *
# Out:
# .::Métodos disponíveis::.
# ------------------------------------------------------
# extrair_dados_bronze(self,arquivo='')
# encontrar_ano_mes(caminho_prefixo)
# criar_view_temporaria_arquivo(local, nome, schema=None, aba=None, **config)
# atualizar_tabela_delta(arquivo)
# criar_view_temporaria(df, nome)
# historico_tabela()
# carrega_lista_yaml()
# salvar_delta(df, mode)
# parar_sessao()

# %%
# Crie uma instância da classe
bucket = "gold"
datamart = "sgt"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-09-26 18:12:53,577 - INFO - Iniciando Sessão Spark.

# %%
extrator.carrega_dados_delta('FatoProducaoHHSgt')
# Out:
# 2024-09-26 18:12:57,187 - INFO - Arquivo yaml carregada com sucesso
# 2024-09-26 18:12:57,188 - INFO - ['/home/jovyan/work/yaml/gold/sgt/FatoProducaoHHSgt.yaml']
# 2024-09-26 18:12:57,194 - INFO - Aguarde... Carregando dados
# 2024-09-26 18:13:03,156 - INFO - Dados carregado com sucesso
# DataFrame[id_data_calendario: date, nr_cr_produto_regional: string, ano: string, nr_cpf_cnpj_cliente: string, nr_cpf_colaborador: string, dsc_produto_categoria: string, dsc_produto_linha: string, dsc_produto_nacional: string, dsc_produto_regional: string, dia: string, dsc_email_colaborador: string, id: string, id_atendimento: string, id_porte_cliente: string, dsc_compartilhado: string, dsc_em_rede: string, mes: string, nm_cliente: string, nm_colaborador: string, nr_atendimento: string, dsc_porte_cliente: string, vlr_producao_realizada: string, dsc_titulo_atendimento: string, dsc_unidade_operacional: string, dt_atualizacao: timestamp]

# %%
extrator.conexao_banco_de_dados('sqlserver','sqlserver','1433','sa','SqlServer2019!','ALINHAR','DW')
# Out:
# 2024-09-26 18:13:03,183 - INFO - Aguarde... Configurando conexao banco de dados

# %%
extrator.persistencia_consume('sgt_fato_producao_hh')
# Out:
# 2024-09-26 18:13:03,190 - INFO - Aguarde... Persistindo os dados camada Consume
# 2024-09-26 18:13:10,698 - INFO - Camada Consume persistida com sucesso
# 2024-09-26 18:13:10,699 - INFO - DW.sgt_fato_producao_hh

# %%
extrator.parar_sessao()
# Out:
# 2024-09-26 18:13:10,999 - INFO - Sessão Spark finalizada.
