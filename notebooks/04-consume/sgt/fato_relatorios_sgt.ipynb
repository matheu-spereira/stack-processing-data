# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.AlinharETL import AlinharETL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from delta import *
# Out:
# .::Métodos disponíveis::.
# ------------------------------------------------------
# extrair_dados_bronze(self,arquivo='')
# encontrar_ano_mes(caminho_prefixo)
# criar_view_temporaria_arquivo(local, nome, schema=None, aba=None, **config)
# atualizar_tabela_delta(arquivo)
# criar_view_temporaria(df, nome)
# historico_tabela()
# carrega_lista_yaml()
# salvar_delta(df, mode)
# parar_sessao()

# %%
# Crie uma instância da classe
bucket = "gold"
datamart = "sgt"
extrator = AlinharETL(bucket,datamart)
# Out:
# 2024-09-26 18:16:28,916 - INFO - Iniciando Sessão Spark.

# %%
extrator.carrega_dados_delta('FatoRelatoriosSgt')
# Out:
# 2024-09-26 18:16:29,748 - INFO - Arquivo yaml carregada com sucesso
# 2024-09-26 18:16:29,750 - INFO - ['/home/jovyan/work/yaml/gold/sgt/FatoRelatoriosSgt.yaml']
# 2024-09-26 18:16:29,757 - INFO - Aguarde... Carregando dados
# 2024-09-26 18:16:34,452 - INFO - Dados carregado com sucesso
# DataFrame[id_data_calendario: date, cr_produto_regional: string, ano: string, nr_cnpj_cliente: string, nr_cpf_colaborador: string, dsc_produto_categoria: string, dsc_produto_linha: string, dsc_produto_nacional: string, dsc_produto_regional: string, dia: string, nm_email_colaborador: string, nr_ensaios_realizados: string, id: string, id_atendimento: string, id_porte_cliente: string, dsc_compartilhamento: string, dsc_em_rede: string, mes: string, nm_cliente: string, nm_colaborador: string, nr_atendimento: string, nm_porte_cliente: string, nr_relatorios_realizados: string, dsc_titulo_atendimento: string, nm_unidade_operacional: string, dt_atualizacao: timestamp]

# %%
extrator.conexao_banco_de_dados('sqlserver','sqlserver','1433','sa','SqlServer2019!','ALINHAR','DW')
# Out:
# 2024-09-26 18:16:34,482 - INFO - Aguarde... Configurando conexao banco de dados

# %%
extrator.persistencia_consume('sgt_fato_relatorios')
# Out:
# 2024-09-26 18:16:42,563 - INFO - Aguarde... Persistindo os dados camada Consume
# 2024-09-26 18:16:49,016 - INFO - Camada Consume persistida com sucesso
# 2024-09-26 18:16:49,018 - INFO - DW.sgt_fato_relatorios

# %%
extrator.parar_sessao()
# Out:
# 2024-09-26 18:16:49,195 - INFO - Sessão Spark finalizada.
