# %%
import os
import sys
sys.path.append('/home/jovyan/work')
from utils.ValidacaoCriacaoDicionarioFinal import ValidadorDW

# %%
db_schema   = 'DW'
db_dbms     = 'sqlserver'
db_username = 'sa'
db_password = 'SqlServer2019!'
db_host     = 'sqlserver'
db_port     = '1433'
db_database = 'ALINHAR' 

validacao = ValidadorDW(db_dbms,db_host,db_username,db_password,db_database,db_port,db_schema)

# %%
tables = ["sgt_dim_clientes"]

validacao.fetch_data(tables, 'Matheus Oliveira Mendes Pereira', '1', '29/10/2024', 'STI_DW')
