# %%
import sys
import os
sys.path.append('/home/jovyan/work')

from utils.ValidacaoListaTabelasMinio import MinioMarkdownGenerator

# %%
bucket_directory_pairs = [
    ("bronze", "sgt/"),
    ("silver", "sgt/"),
    ("gold", "sgt/")
    
]

generator = MinioMarkdownGenerator()
generator.save_markdown(bucket_directory_pairs, 'sti')
# Out:
# Tabela Markdown gerada e salva
