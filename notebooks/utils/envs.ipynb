# %%
import os
os.environ['PATH_RAIZ'] = '/home/jovyan/work'


os.environ['MINIO_ACCESS_KEY'] = 'minio'
os.environ['MINIO_SECRET_KEY'] = 'minio123'
os.environ['MINIO_HOST'] = 'http://minio:9000'

os.environ['TZ'] = 'America/Sao_Paulo'

os.environ['B_TOKEN'] = 'Bearer 29cc7f1d-75bf-3344-89e9-a1ba56680e0e'
os.environ['SPARK_MASTER'] = 'spark://spark-master:7077'

# %%
a = os.getenv("PATH_RAIZ")
a
# Out:
# '/home/jovyan/work'

# %%
os.environ['DB_DESTINO_SCHEMA'] = 'spark://spark-master:7077'
os.environ['DB_DESTINO_DATABASE'] = 'spark://spark-master:7077'
os.environ['DB_DESTINO_USER'] = 'spark://spark-master:7077'
os.environ['DB_DESTINO_HOST'] = 'spark://spark-master:7077'
os.environ['DB_DESTINO_PASSWORD'] = 'spark://spark-master:7077'
os.environ['DB_DESTINO_PORT'] = 'spark://spark-master:7077'
os.environ['DB_DESTINO_DBMS'] = 'sqlserver'
